# %%
#imports
import csv
import requests
from collections import deque
import os

# %%
# Read the API key from a file and remove any leading/trailing whitespace.
with open('../API_Keys/NOAA_Token.txt', 'r') as file:
    api_key = file.read().strip()

# Base URL for the API calls.
url = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/'

# Headers required for the API call, including the authorization token.
headers = {
    'token': api_key  # API key is passed as a token in the header.
}

def api_call(url, endpoint, headers, parameters):
    """
    Make an API call to the specified URL and endpoint with given headers and parameters.
    
    Args:
        url (str): The base URL for the API.
        endpoint (str): The specific endpoint to access data from the API.
        headers (dict): Headers to include in the request (e.g., authorization tokens).
        parameters (dict): Query parameters to customize the request.
    
    Returns:
        dict: The JSON response from the API if the call is successful, None otherwise.
    """
    try:
        print(parameters['offset'])  # Debugging: print the current offset before making the call.
        response = requests.get(url + endpoint, headers=headers, params=parameters)  # Perform the GET request.
        response.raise_for_status()  # Check for HTTP errors and raise exceptions for them.
        print("API Called")  # Debugging: confirm the API was called.
        return response.json()  # Return the parsed JSON response.
    except requests.exceptions.RequestException as e:
        print(f"API call failed: {e}")  # Handle exceptions (e.g., network issues, 4xx and 5xx errors).
        return None

def append_to_csv(file_path, data, fieldnames):
    """
    Append data to a CSV file. If the file doesn't exist, create it and write the headers.
    
    Args:
        file_path (str): Path to the CSV file.
        data (list): A list of dictionaries representing the rows to append.
        fieldnames (list): Headers or fieldnames for the CSV.
    """
    with open(file_path, mode='a', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        if file.tell() == 0:  # Check if the file is empty to decide if headers need to be written.
            writer.writeheader()
        writer.writerows(data)  # Append the data rows to the CSV file.

def append_metadata_to_csv(metadata_file_path, metadata):
    """
    Append metadata to a CSV file.
    
    Args:
        metadata_file_path (str): Path to the CSV file where metadata is stored.
        metadata (dict): Metadata to be appended.
    """
    with open(metadata_file_path, mode='a', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=metadata['resultset'].keys())
        if file.tell() == 0:  # Check if the file is empty to decide if headers need to be written.
            writer.writeheader()
        writer.writerow(metadata['resultset'])  # Append metadata to the metadata CSV.
        
def execute_api_calls_with_retries(base_url, endpoint, headers, initial_parameters, file_path, metadata_file_path, error_log_path, max_retries=3):
    """
    Execute API calls with a mechanism for retries on failure, appending successful results to a CSV file
    and metadata to another CSV file.
    
    Args:
        base_url (str): The base URL for the API calls.
        endpoint (str): The specific endpoint to access data from the API.
        headers (dict): Headers to include in the request.
        initial_parameters (dict): Initial query parameters for the API call.
        file_path (str): Path to the CSV file where results are stored.
        metadata_file_path (str): Path to the CSV file where metadata is stored.
        error_log_path (str): Path to the CSV file where failed attempts are logged.
        max_retries (int): Maximum number of retry attempts for a failed API call.
    """
    if os.path.exists(file_path):
        print(f"CSV file {file_path} already exists. Operation cancelled to prevent overwriting.")
        return  # Prevents overwriting existing data by aborting if the file already exists.
    
    stack = deque([initial_parameters])  # Use a stack to manage API call parameters, starting with the initial parameters.
    failed_attempts = []  # Track parameters that fail to succeed after the maximum number of retries.
    
    while stack:
        parameters = stack.pop()  # Pop the last set of parameters to make an API call.
        retries = parameters.pop('retries', 0)  # Extract or initialize the retry counter for these parameters.
        data = api_call(base_url, endpoint, headers, parameters)  # Attempt the API call.
        
        if data and 'results' in data:  # Check if the call was successful and data was returned.
            append_to_csv(file_path, data['results'], data['results'][0].keys())  # Append successful results to the CSV.
            append_metadata_to_csv(metadata_file_path, data['metadata'])  # Append metadata to the metadata CSV
            
            # Check if there are more results to fetch and prepare the next set of parameters.
            if parameters.get('offset', 1) + parameters.get('limit', 10) - 1 < data['metadata']['resultset']['count']:
                next_params = parameters.copy()
                next_params['offset'] += parameters.get('limit', 10)
                stack.append(next_params)  # Add the next parameters to the stack for subsequent API calls.
        else:
            # Retry logic for failed attempts.
            if retries < max_retries:
                parameters['retries'] = retries + 1  # Increment the retry counter.
                stack.append(parameters)  # Re-add the parameters to the stack for retry.
            else:
                print(f"Max retries reached for parameters: {parameters}")
                failed_attempts.append(parameters)  # Log parameters that exceeded retry attempts.
    
    # Optionally log failed attempts to a specified CSV for troubleshooting.
    if failed_attempts:
        append_to_csv(error_log_path, failed_attempts, ['locationid', 'limit', 'offset', 'retries'])

# %%
# Example of how to call the function
endpoint = "/stations/"
parameters = {
    "locationid": "FIPS:27",
    "limit": 1000,
    "offset": 1
}
file_path = "stations.csv"
error_log_path = "error_log.csv"
metadata_path = "stations_meta.csv"

execute_api_calls_with_retries(url, endpoint, headers, parameters, file_path, metadata_path, error_log_path, max_retries=3)
# Out:
# 1
# API Called
# 1001
# API Called
# 2001
# API Called

# %%
#Test downloading data from all stations
endpoint = '/data/'

#Get list of station codes for the Minnesota stations
parameters = {
    'datasetid': 'GHCND',
    'locationid': 'FIPS:27',
    'limit': 100, # max is 1000 for a single request
    'offset': 498801,
    'startdate': '2023-01-01',
    'enddate': '2023-12-31'
}

file_path = "data_498801_on.csv"
error_log_path = "error_log.csv"

execute_api_calls_with_retries(url, endpoint, headers, parameters, file_path, error_log_path, max_retries=3)
# Out:
# 498801
# API Called
# 498901
# API Called
# 499001
# API Called
# 499101
# API Called
# 499201
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=499201&startdate=2023-01-01&enddate=2023-12-31
# 499201
# API Called
# 499301
# API Called
# 499401
# API Called
# 499501
# API Called
# 499601
# API Called
# 499701
# API Called
# 499801
# API Called
# 499901
# API Called
# 500001
# API Called
# 500101
# API Called
# 500201
# API Called
# 500301
# API Called
# 500401
# API Called
# 500501
# API Called
# 500601
# API Called
# 500701
# API Called
# 500801
# API Called
# 500901
# API Called
# 501001
# API Called
# 501101
# API Called
# 501201
# API Called
# 501301
# API Called
# 501401
# API Called
# 501501
# API Called
# 501601
# API Called
# 501701
# API Called
# 501801
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=501801&startdate=2023-01-01&enddate=2023-12-31
# 501801
# API Called
# 501901
# API Called
# 502001
# API Called
# 502101
# API Called
# 502201
# API Called
# 502301
# API Called
# 502401
# API Called
# 502501
# API Called
# 502601
# API Called
# 502701
# API Called
# 502801
# API Called
# 502901
# API Called
# 503001
# API Called
# 503101
# API Called
# 503201
# API Called
# 503301
# API Called
# 503401
# API Called
# 503501
# API Called
# 503601
# API Called
# 503701
# API Called
# 503801
# API Called
# 503901
# API Called
# 504001
# API Called
# 504101
# API Called
# 504201
# API Called
# 504301
# API Called
# 504401
# API Called
# 504501
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=504501&startdate=2023-01-01&enddate=2023-12-31
# 504501
# API Called
# 504601
# API Called
# 504701
# API Called
# 504801
# API Called
# 504901
# API Called
# 505001
# API Called
# 505101
# API Called
# 505201
# API Called
# 505301
# API Called
# 505401
# API Called
# 505501
# API Called
# 505601
# API Called
# 505701
# API Called
# 505801
# API Called
# 505901
# API Called
# 506001
# API Called
# 506101
# API Called
# 506201
# API Called
# 506301
# API Called
# 506401
# API Called
# 506501
# API Called
# 506601
# API Called
# 506701
# API Called
# 506801
# API Called
# 506901
# API Called
# 507001
# API Called
# 507101
# API Called
# 507201
# API Called
# 507301
# API Called
# 507401
# API Called
# 507501
# API Called
# 507601
# API Called
# 507701
# API Called
# 507801
# API Called
# 507901
# API Called
# 508001
# API Called
# 508101
# API Called
# 508201
# API Called
# 508301
# API Called
# 508401
# API Called
# 508501
# API Called
# 508601
# API Called
# 508701
# API Called
# 508801
# API Called
# 508901
# API Called
# 509001
# API Called
# 509101
# API Called
# 509201
# API Called
# 509301
# API Called
# 509401
# API Called
# 509501
# API Called
# 509601
# API Called
# 509701
# API Called
# 509801
# API Called
# 509901
# API Called
# 510001
# API Called
# 510101
# API Called
# 510201
# API Called
# 510301
# API Called
# 510401
# API Called
# 510501
# API Called
# 510601
# API Called
# 510701
# API Called
# 510801
# API Called
# 510901
# API Called
# 511001
# API Called
# 511101
# API Called
# 511201
# API Called
# 511301
# API Called
# 511401
# API Called
# 511501
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=511501&startdate=2023-01-01&enddate=2023-12-31
# 511501
# API Called
# 511601
# API Called
# 511701
# API Called
# 511801
# API Called
# 511901
# API Called
# 512001
# API Called
# 512101
# API Called
# 512201
# API Called
# 512301
# API Called
# 512401
# API Called
# 512501
# API Called
# 512601
# API Called
# 512701
# API Called
# 512801
# API Called
# 512901
# API Called
# 513001
# API Called
# 513101
# API Called
# 513201
# API Called
# 513301
# API Called
# 513401
# API Called
# 513501
# API Called
# 513601
# API Called
# 513701
# API Called
# 513801
# API Called
# 513901
# API Called
# 514001
# API Called
# 514101
# API Called
# 514201
# API Called
# 514301
# API Called
# 514401
# API Called
# 514501
# API Called
# 514601
# API Called
# 514701
# API Called
# 514801
# API Called
# 514901
# API Called
# 515001
# API Called
# 515101
# API Called
# 515201
# API Called
# 515301
# API Called
# 515401
# API Called
# 515501
# API Called
# 515601
# API Called
# 515701
# API Called
# 515801
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=515801&startdate=2023-01-01&enddate=2023-12-31
# 515801
# API Called
# 515901
# API Called
# 516001
# API Called
# 516101
# API Called
# 516201
# API Called
# 516301
# API Called
# 516401
# API Called
# 516501
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=516501&startdate=2023-01-01&enddate=2023-12-31
# 516501
# API Called
# 516601
# API Called
# 516701
# API Called
# 516801
# API Called
# 516901
# API Called
# 517001
# API Called
# 517101
# API Called
# 517201
# API Called
# 517301
# API Called
# 517401
# API Called
# 517501
# API Called
# 517601
# API Called
# 517701
# API Called
# 517801
# API Called
# 517901
# API Called
# 518001
# API Called
# 518101
# API Called
# 518201
# API Called
# 518301
# API Called
# 518401
# API Called
# 518501
# API Called
# 518601
# API Called
# 518701
# API Called
# 518801
# API Called
# 518901
# API Called
# 519001
# API Called
# 519101
# API Called
# 519201
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=519201&startdate=2023-01-01&enddate=2023-12-31
# 519201
# API Called
# 519301
# API Called
# 519401
# API Called
# 519501
# API Called
# 519601
# API Called
# 519701
# API Called
# 519801
# API Called
# 519901
# API Called
# 520001
# API Called
# 520101
# API Called
# 520201
# API Called
# 520301
# API Called
# 520401
# API Called
# 520501
# API Called
# 520601
# API Called
# 520701
# API Called
# 520801
# API Called
# 520901
# API Called
# 521001
# API Called
# 521101
# API Called
# 521201
# API Called
# 521301
# API Called
# 521401
# API Called
# 521501
# API Called
# 521601
# API Called
# 521701
# API Called
# 521801
# API Called
# 521901
# API Called
# 522001
# API Called
# 522101
# API Called
# 522201
# API Called
# 522301
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=522301&startdate=2023-01-01&enddate=2023-12-31
# 522301
# API Called
# 522401
# API Called
# 522501
# API Called
# 522601
# API Called
# 522701
# API Called
# 522801
# API Called
# 522901
# API Called
# 523001
# API Called
# 523101
# API Called
# 523201
# API Called
# 523301
# API Called
# 523401
# API Called
# 523501
# API Called
# 523601
# API Called
# 523701
# API Called
# 523801
# API Called
# 523901
# API Called
# 524001
# API Called
# 524101
# API Called
# 524201
# API Called
# 524301
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=524301&startdate=2023-01-01&enddate=2023-12-31
# 524301
# API Called
# 524401
# API Called
# 524501
# API Called
# 524601
# API Called
# 524701
# API Called
# 524801
# API Called
# 524901
# API Called
# 525001
# API Called
# 525101
# API Called
# 525201
# API Called
# 525301
# API Called
# 525401
# API Called
# 525501
# API Called
# 525601
# API Called
# 525701
# API Called
# 525801
# API Called
# 525901
# API Called
# 526001
# API Called
# 526101
# API Called
# 526201
# API Called
# 526301
# API Called
# 526401
# API Called
# 526501
# API Called
# 526601
# API Called
# 526701
# API Called
# 526801
# API Called
# 526901
# API Called
# 527001
# API Called
# 527101
# API Called
# 527201
# API Called
# 527301
# API Called
# 527401
# API Called
# 527501
# API Called
# 527601
# API Called
# 527701
# API Called
# 527801
# API Called
# 527901
# API Called
# 528001
# API Called
# 528101
# API Called
# 528201
# API Called
# 528301
# API Called
# 528401
# API Called
# 528501
# API Called
# 528601
# API Called
# 528701
# API Called
# 528801
# API Called
# 528901
# API Called
# 529001
# API Called
# 529101
# API Called
# 529201
# API Called
# 529301
# API Called
# 529401
# API Called
# 529501
# API Called
# 529601
# API Called
# 529701
# API Called
# 529801
# API Called
# 529901
# API Called
# 530001
# API Called
# 530101
# API Called
# 530201
# API Called
# 530301
# API Called
# 530401
# API Called
# 530501
# API Called
# 530601
# API Called
# 530701
# API Called
# 530801
# API Called
# 530901
# API Called
# 531001
# API Called
# 531101
# API Called
# 531201
# API Called
# 531301
# API Called
# 531401
# API Called
# 531501
# API Called
# 531601
# API Called
# 531701
# API Called
# 531801
# API Called
# 531901
# API Called
# 532001
# API Called
# 532101
# API Called
# 532201
# API Called
# 532301
# API Called
# 532401
# API Called
# 532501
# API Called
# 532601
# API Called
# 532701
# API Called
# 532801
# API Called
# 532901
# API Called
# 533001
# API Called
# 533101
# API Called
# 533201
# API Called
# 533301
# API Called
# 533401
# API Called
# 533501
# API Called
# 533601
# API Called
# 533701
# API Called
# 533801
# API Called
# 533901
# API Called
# 534001
# API Called
# 534101
# API Called
# 534201
# API Called
# 534301
# API Called
# 534401
# API Called
# 534501
# API Called
# 534601
# API Called
# 534701
# API Called
# 534801
# API Called
# 534901
# API Called
# 535001
# API Called
# 535101
# API Called
# 535201
# API Called
# 535301
# API Called
# 535401
# API Called
# 535501
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=535501&startdate=2023-01-01&enddate=2023-12-31
# 535501
# API Called
# 535601
# API Called
# 535701
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=535701&startdate=2023-01-01&enddate=2023-12-31
# 535701
# API Called
# 535801
# API Called
# 535901
# API Called
# 536001
# API Called
# 536101
# API Called
# 536201
# API Called
# 536301
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=536301&startdate=2023-01-01&enddate=2023-12-31
# 536301
# API Called
# 536401
# API Called
# 536501
# API Called
# 536601
# API Called
# 536701
# API Called
# 536801
# API Called
# 536901
# API Called
# 537001
# API Called
# 537101
# API Called
# 537201
# API Called
# 537301
# API Called
# 537401
# API Called
# 537501
# API Called
# 537601
# API Called
# 537701
# API Called
# 537801
# API Called
# 537901
# API Called
# 538001
# API Called
# 538101
# API Called
# 538201
# API Called
# 538301
# API Called
# 538401
# API Called
# 538501
# API Called
# 538601
# API Called
# 538701
# API Called
# 538801
# API Called
# 538901
# API Called
# 539001
# API Called
# 539101
# API Called
# 539201
# API Called
# 539301
# API Called
# 539401
# API Called
# 539501
# API Called
# 539601
# API Called
# 539701
# API Called
# 539801
# API Called
# 539901
# API Called
# 540001
# API Called
# 540101
# API Called
# 540201
# API Called
# 540301
# API Called
# 540401
# API Called
# 540501
# API Called
# 540601
# API Called
# 540701
# API Called
# 540801
# API Called
# 540901
# API Called
# 541001
# API Called
# 541101
# API Called
# 541201
# API Called
# 541301
# API Called
# 541401
# API Called
# 541501
# API Called
# 541601
# API Called
# 541701
# API Called
# 541801
# API Called
# 541901
# API Called
# 542001
# API Called
# 542101
# API Called
# 542201
# API Called
# 542301
# API Called
# 542401
# API Called
# 542501
# API Called
# 542601
# API Called
# 542701
# API Called
# 542801
# API Called
# 542901
# API Called
# 543001
# API Called
# 543101
# API Called
# 543201
# API Called
# 543301
# API Called
# 543401
# API Called
# 543501
# API Called
# 543601
# API Called
# 543701
# API Called
# 543801
# API Called
# 543901
# API Called
# 544001
# API Called
# 544101
# API Called
# 544201
# API Called
# 544301
# API Called
# 544401
# API Called
# 544501
# API Called
# 544601
# API Called
# 544701
# API Called
# 544801
# API Called
# 544901
# API Called
# 545001
# API Called
# 545101
# API Called
# 545201
# API Called
# 545301
# API Called
# 545401
# API Called
# 545501
# API Called
# 545601
# API Called
# 545701
# API Called
# 545801
# API Called
# 545901
# API Called
# 546001
# API Called
# 546101
# API Called
# 546201
# API Called
# 546301
# API Called
# 546401
# API Called
# 546501
# API Called
# 546601
# API Called
# 546701
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=546701&startdate=2023-01-01&enddate=2023-12-31
# 546701
# API Called
# 546801
# API Called
# 546901
# API Called
# 547001
# API Called
# 547101
# API Called
# 547201
# API Called
# 547301
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=547301&startdate=2023-01-01&enddate=2023-12-31
# 547301
# API Called
# 547401
# API Called
# 547501
# API Called
# 547601
# API Called
# 547701
# API Called
# 547801
# API Called
# 547901
# API Called
# 548001
# API Called
# 548101
# API Called
# 548201
# API Called
# 548301
# API Called
# 548401
# API Called
# 548501
# API Called
# 548601
# API Called
# 548701
# API Called
# 548801
# API Called
# 548901
# API Called
# 549001
# API Called
# 549101
# API Called
# 549201
# API Called
# 549301
# API Called
# 549401
# API Called
# 549501
# API Called
# 549601
# API Called
# 549701
# API Called
# 549801
# API Called
# 549901
# API Called
# 550001
# API Called
# 550101
# API Called
# 550201
# API Called
# 550301
# API Called
# 550401
# API Called
# 550501
# API Called
# 550601
# API Called
# 550701
# API Called
# 550801
# API Called
# 550901
# API Called
# 551001
# API Called
# 551101
# API Called
# 551201
# API Called
# 551301
# API Called
# 551401
# API Called
# 551501
# API Called
# 551601
# API Called
# 551701
# API Called
# 551801
# API Called
# 551901
# API Called
# 552001
# API Called
# 552101
# API Called
# 552201
# API Called
# 552301
# API Called
# 552401
# API Called
# 552501
# API Called
# 552601
# API Called
# 552701
# API Called
# 552801
# API Called
# 552901
# API Called
# 553001
# API Called
# 553101
# API Called
# 553201
# API Called
# 553301
# API Called
# 553401
# API Called
# 553501
# API Called
# 553601
# API Called
# 553701
# API Called
# 553801
# API Called
# 553901
# API Called
# 554001
# API Called
# 554101
# API Called
# 554201
# API Called
# 554301
# API Called
# 554401
# API Called
# 554501
# API Called
# 554601
# API Called
# 554701
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=554701&startdate=2023-01-01&enddate=2023-12-31
# 554701
# API Called
# 554801
# API Called
# 554901
# API Called
# 555001
# API Called
# 555101
# API Called
# 555201
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=555201&startdate=2023-01-01&enddate=2023-12-31
# 555201
# API Called
# 555301
# API Called
# 555401
# API Called
# 555501
# API Called
# 555601
# API Called
# 555701
# API Called
# 555801
# API Called
# 555901
# API Called
# 556001
# API Called
# 556101
# API Called
# 556201
# API Called
# 556301
# API Called
# 556401
# API Called
# 556501
# API Called
# 556601
# API Called
# 556701
# API Called
# 556801
# API Called
# 556901
# API Called
# 557001
# API Called
# 557101
# API Called
# 557201
# API Called
# 557301
# API Called
# 557401
# API Called
# 557501
# API Called
# 557601
# API Called
# 557701
# API Called
# 557801
# API Called
# 557901
# API Called
# 558001
# API Called
# 558101
# API Called
# 558201
# API Called
# 558301
# API Called
# 558401
# API Called
# 558501
# API Called
# 558601
# API Called
# 558701
# API Called
# 558801
# API Called
# 558901
# API Called
# 559001
# API Called
# 559101
# API Called
# 559201
# API Called
# 559301
# API Called
# 559401
# API Called
# 559501
# API Called
# 559601
# API Called
# 559701
# API Called
# 559801
# API Called
# 559901
# API Called
# 560001
# API Called
# 560101
# API Called
# 560201
# API Called
# 560301
# API Called
# 560401
# API Called
# 560501
# API Called
# 560601
# API Called
# 560701
# API Called
# 560801
# API Called
# 560901
# API Called
# 561001
# API Called
# 561101
# API Called
# 561201
# API Called
# 561301
# API Called
# 561401
# API Called
# 561501
# API Called
# 561601
# API Called
# 561701
# API Called
# 561801
# API Called
# 561901
# API Called
# 562001
# API Called
# 562101
# API Called
# 562201
# API Called
# 562301
# API Called
# 562401
# API Called
# 562501
# API Called
# 562601
# API Called
# 562701
# API Called
# 562801
# API Called
# 562901
# API Called
# 563001
# API Called
# 563101
# API Called
# 563201
# API Called
# 563301
# API Called
# 563401
# API Called
# 563501
# API Called
# 563601
# API Called
# 563701
# API Called
# 563801
# API Called
# 563901
# API Called
# 564001
# API Called
# 564101
# API Called
# 564201
# API Called
# 564301
# API Called
# 564401
# API Called
# 564501
# API Called
# 564601
# API Called
# 564701
# API Called
# 564801
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=564801&startdate=2023-01-01&enddate=2023-12-31
# 564801
# API Called
# 564901
# API Called
# 565001
# API Called
# 565101
# API Called
# 565201
# API Called
# 565301
# API Called
# 565401
# API Called
# 565501
# API Called
# 565601
# API Called
# 565701
# API Called
# 565801
# API Called
# 565901
# API Called
# 566001
# API Called
# 566101
# API Called
# 566201
# API Called
# 566301
# API Called
# 566401
# API Called
# 566501
# API Called
# 566601
# API Called
# 566701
# API Called
# 566801
# API Called
# 566901
# API Called
# 567001
# API Called
# 567101
# API Called
# 567201
# API Called
# 567301
# API Called
# 567401
# API Called
# 567501
# API Called
# 567601
# API Called
# 567701
# API Called
# 567801
# API Called
# 567901
# API Called
# 568001
# API Called
# 568101
# API Called
# 568201
# API Called
# 568301
# API Called
# 568401
# API Called
# 568501
# API Called
# 568601
# API Called
# 568701
# API Called
# 568801
# API Called
# 568901
# API Called
# 569001
# API Called
# 569101
# API Called
# 569201
# API Called
# 569301
# API Called
# 569401
# API Called
# 569501
# API Called
# 569601
# API Called
# 569701
# API Called
# 569801
# API Called
# 569901
# API Called
# 570001
# API Called
# 570101
# API Called
# 570201
# API Called
# 570301
# API Called
# 570401
# API Called
# 570501
# API Called
# 570601
# API Called
# 570701
# API Called
# 570801
# API Called
# 570901
# API Called
# 571001
# API Called
# 571101
# API Called
# 571201
# API Called
# 571301
# API Called
# 571401
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=571401&startdate=2023-01-01&enddate=2023-12-31
# 571401
# API Called
# 571501
# API Called
# 571601
# API Called
# 571701
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=571701&startdate=2023-01-01&enddate=2023-12-31
# 571701
# API Called
# 571801
# API Called
# 571901
# API Called
# 572001
# API Called
# 572101
# API Called
# 572201
# API Called
# 572301
# API Called
# 572401
# API Called
# 572501
# API Called
# 572601
# API Called
# 572701
# API Called
# 572801
# API Called
# 572901
# API Called
# 573001
# API Called
# 573101
# API Called
# 573201
# API Called
# 573301
# API Called
# 573401
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=573401&startdate=2023-01-01&enddate=2023-12-31
# 573401
# API Called
# 573501
# API Called
# 573601
# API Called
# 573701
# API Called
# 573801
# API Called
# 573901
# API Called
# 574001
# API Called
# 574101
# API Called
# 574201
# API Called
# 574301
# API Called
# 574401
# API Called
# 574501
# API Called
# 574601
# API Called
# 574701
# API Called
# 574801
# API Called
# 574901
# API Called
# 575001
# API Called
# 575101
# API Called
# 575201
# API Called
# 575301
# API Called
# 575401
# API Called
# 575501
# API Called
# 575601
# API Called
# 575701
# API Called
# 575801
# API Called
# 575901
# API Called
# 576001
# API Called
# 576101
# API Called
# 576201
# API Called
# 576301
# API Called
# 576401
# API Called
# 576501
# API Called
# 576601
# API Called
# 576701
# API Called
# 576801
# API Called
# 576901
# API Called
# 577001
# API Called
# 577101
# API Called
# 577201
# API Called
# 577301
# API Called
# 577401
# API Called
# 577501
# API Called
# 577601
# API Called
# 577701
# API Called
# 577801
# API Called
# 577901
# API Called
# 578001
# API Called
# 578101
# API Called
# 578201
# API Called
# 578301
# API Called
# 578401
# API Called
# 578501
# API Called
# 578601
# API Called
# 578701
# API Called
# 578801
# API Called
# 578901
# API Called
# 579001
# API Called
# 579101
# API Called
# 579201
# API Called
# 579301
# API Called
# 579401
# API Called
# 579501
# API Called
# 579601
# API Called
# 579701
# API Called
# 579801
# API Called
# 579901
# API Called
# 580001
# API Called
# 580101
# API Called
# 580201
# API Called
# 580301
# API Called
# 580401
# API Called
# 580501
# API Called
# 580601
# API Called
# 580701
# API Called
# 580801
# API Called
# 580901
# API Called
# 581001
# API Called
# 581101
# API Called
# 581201
# API Called
# 581301
# API Called
# 581401
# API Called
# 581501
# API Called
# 581601
# API Called
# 581701
# API Called
# 581801
# API Called
# 581901
# API Called
# 582001
# API Called
# 582101
# API Called
# 582201
# API Called
# 582301
# API Called
# 582401
# API Called
# 582501
# API Called
# 582601
# API Called
# 582701
# API Called
# 582801
# API Called
# 582901
# API Called
# 583001
# API Called
# 583101
# API Called
# 583201
# API Called
# 583301
# API Called
# 583401
# API Called
# 583501
# API Called
# 583601
# API Called
# 583701
# API Called
# 583801
# API Called
# 583901
# API Called
# 584001
# API Called
# 584101
# API Called
# 584201
# API Called
# 584301
# API Called
# 584401
# API Called
# 584501
# API Called
# 584601
# API Called
# 584701
# API Called
# 584801
# API Called
# 584901
# API Called
# 585001
# API Called
# 585101
# API Called
# 585201
# API Called
# 585301
# API Called
# 585401
# API Called
# 585501
# API Called
# 585601
# API Called
# 585701
# API Called
# 585801
# API Called
# 585901
# API Called
# 586001
# API Called
# 586101
# API Called
# 586201
# API Called
# 586301
# API Called
# 586401
# API Called
# 586501
# API Called
# 586601
# API Called
# 586701
# API Called
# 586801
# API Called
# 586901
# API Called
# 587001
# API Called
# 587101
# API Called
# 587201
# API Called
# 587301
# API Called
# 587401
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=587401&startdate=2023-01-01&enddate=2023-12-31
# 587401
# API Called
# 587501
# API Called
# 587601
# API Called
# 587701
# API Called
# 587801
# API Called
# 587901
# API Called
# 588001
# API Called
# 588101
# API Called
# 588201
# API Called
# 588301
# API Called
# 588401
# API Called
# 588501
# API Called
# 588601
# API Called
# 588701
# API Called
# 588801
# API Called
# 588901
# API Called
# 589001
# API Called
# 589101
# API Called
# 589201
# API Called
# 589301
# API Called
# 589401
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=589401&startdate=2023-01-01&enddate=2023-12-31
# 589401
# API Called
# 589501
# API Called
# 589601
# API Called
# 589701
# API Called
# 589801
# API Called
# 589901
# API Called
# 590001
# API Called
# 590101
# API Called
# 590201
# API Called
# 590301
# API Called
# 590401
# API Called
# 590501
# API Called
# 590601
# API Called
# 590701
# API Called
# 590801
# API Called
# 590901
# API Called
# 591001
# API Called
# 591101
# API Called
# 591201
# API Called
# 591301
# API Called
# 591401
# API Called
# 591501
# API Called
# 591601
# API Called
# 591701
# API Called
# 591801
# API Called
# 591901
# API Called
# 592001
# API Called
# 592101
# API Called
# 592201
# API Called
# 592301
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=592301&startdate=2023-01-01&enddate=2023-12-31
# 592301
# API Called
# 592401
# API Called
# 592501
# API Called
# 592601
# API Called
# 592701
# API Called
# 592801
# API Called
# 592901
# API Called
# 593001
# API Called
# 593101
# API Called
# 593201
# API Called
# 593301
# API Called
# 593401
# API Called
# 593501
# API Called
# 593601
# API Called
# 593701
# API Called
# 593801
# API Called
# 593901
# API Called
# 594001
# API Called
# 594101
# API Called
# 594201
# API Called
# 594301
# API Called
# 594401
# API Called
# 594501
# API Called
# 594601
# API Called
# 594701
# API Called
# 594801
# API Called
# 594901
# API Called
# 595001
# API Called
# 595101
# API Called
# 595201
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=595201&startdate=2023-01-01&enddate=2023-12-31
# 595201
# API Called
# 595301
# API Called
# 595401
# API Called
# 595501
# API Called
# 595601
# API Called
# 595701
# API Called
# 595801
# API Called
# 595901
# API Called
# 596001
# API Called
# 596101
# API Called
# 596201
# API Called
# 596301
# API Called
# 596401
# API Called
# 596501
# API Called
# 596601
# API Called
# 596701
# API Called
# 596801
# API Called
# 596901
# API Called
# 597001
# API Called
# 597101
# API Called
# 597201
# API Called
# 597301
# API Called
# 597401
# API Called
# 597501
# API Called
# 597601
# API Called
# 597701
# API Called
# 597801
# API Called
# 597901
# API Called
# 598001
# API Called
# 598101
# API Called
# 598201
# API Called
# 598301
# API Called
# 598401
# API Called
# 598501
# API Called
# 598601
# API Called
# 598701
# API Called
# 598801
# API Called
# 598901
# API Called
# 599001
# API Called
# 599101
# API Called
# 599201
# API Called
# 599301
# API Called
# 599401
# API Called
# 599501
# API Called
# 599601
# API Called
# 599701
# API Called
# 599801
# API Called
# 599901
# API Called
# 600001
# API Called
# 600101
# API Called
# 600201
# API Called
# 600301
# API Called
# 600401
# API Called
# 600501
# API Called
# 600601
# API Called
# 600701
# API Called
# 600801
# API Called
# 600901
# API Called
# 601001
# API Called
# 601101
# API Called
# 601201
# API Called
# 601301
# API Called
# 601401
# API Called
# 601501
# API Called
# 601601
# API Called
# 601701
# API Called
# 601801
# API Called
# 601901
# API Called
# 602001
# API Called
# 602101
# API Called
# 602201
# API Called
# 602301
# API Called
# 602401
# API Called
# 602501
# API Called
# 602601
# API Called
# 602701
# API Called
# 602801
# API Called
# 602901
# API Called
# 603001
# API Called
# 603101
# API Called
# 603201
# API Called
# 603301
# API Called
# 603401
# API Called
# 603501
# API Called
# 603601
# API Called
# 603701
# API Called
# 603801
# API Called
# 603901
# API Called
# 604001
# API Called
# 604101
# API Called
# 604201
# API Called
# 604301
# API Called
# 604401
# API Called
# 604501
# API Called
# 604601
# API Called
# 604701
# API Called
# 604801
# API Called
# 604901
# API Called
# 605001
# API Called
# 605101
# API Called
# 605201
# API Called
# 605301
# API Called
# 605401
# API Called
# 605501
# API Called
# 605601
# API Called
# 605701
# API Called
# 605801
# API Called
# 605901
# API Called
# 606001
# API Called
# 606101
# API Called
# 606201
# API Called
# 606301
# API Called
# 606401
# API Called
# 606501
# API Called
# 606601
# API Called
# 606701
# API Called
# 606801
# API Called
# 606901
# API Called
# 607001
# API Called
# 607101
# API Called
# 607201
# API Called
# 607301
# API Called
# 607401
# API Called
# 607501
# API Called
# 607601
# API Called
# 607701
# API Called
# 607801
# API Called
# 607901
# API Called
# 608001
# API Called
# 608101
# API Called
# 608201
# API Called
# 608301
# API Called
# 608401
# API Called
# 608501
# API Called
# 608601
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=608601&startdate=2023-01-01&enddate=2023-12-31
# 608601
# API Called
# 608701
# API Called
# 608801
# API Called
# 608901
# API Called
# 609001
# API Called
# 609101
# API Called
# 609201
# API Called
# 609301
# API Called
# 609401
# API Called
# 609501
# API Called
# 609601
# API Called
# 609701
# API Called
# 609801
# API Called
# 609901
# API Called
# 610001
# API Called
# 610101
# API Called
# 610201
# API Called
# 610301
# API Called
# 610401
# API Called
# 610501
# API Called
# 610601
# API Called
# 610701
# API Called
# 610801
# API Called
# 610901
# API Called
# 611001
# API Called
# 611101
# API Called
# 611201
# API Called
# 611301
# API Called
# 611401
# API Called
# 611501
# API Called
# 611601
# API Called
# 611701
# API Called
# 611801
# API Called
# 611901
# API Called
# 612001
# API Called
# 612101
# API Called
# 612201
# API Called
# 612301
# API Called
# 612401
# API Called
# 612501
# API Called
# 612601
# API Called
# 612701
# API Called
# 612801
# API Called
# 612901
# API Called
# 613001
# API Called
# 613101
# API Called
# 613201
# API Called
# 613301
# API Called
# 613401
# API Called
# 613501
# API Called
# 613601
# API Called
# 613701
# API Called
# 613801
# API Called
# 613901
# API Called
# 614001
# API Called
# 614101
# API Called
# 614201
# API Called
# 614301
# API Called
# 614401
# API Called
# 614501
# API Called
# 614601
# API Called
# 614701
# API Called
# 614801
# API Called
# 614901
# API Called
# 615001
# API Called
# 615101
# API Called
# 615201
# API Called
# 615301
# API Called
# 615401
# API Called
# 615501
# API Called
# 615601
# API Called
# 615701
# API Called
# 615801
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=615801&startdate=2023-01-01&enddate=2023-12-31
# 615801
# API Called
# 615901
# API Called
# 616001
# API Called
# 616101
# API Called
# 616201
# API Called
# 616301
# API Called
# 616401
# API Called
# 616501
# API Called
# 616601
# API Called
# 616701
# API Called
# 616801
# API Called
# 616901
# API Called
# 617001
# API Called
# 617101
# API Called
# 617201
# API Called
# 617301
# API Called
# 617401
# API Called
# 617501
# API Called
# 617601
# API Called
# 617701
# API Called
# 617801
# API Called
# 617901
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=617901&startdate=2023-01-01&enddate=2023-12-31
# 617901
# API Called
# 618001
# API Called
# 618101
# API Called
# 618201
# API Called
# 618301
# API Called
# 618401
# API Called
# 618501
# API Called
# 618601
# API Called
# 618701
# API Called
# 618801
# API Called
# 618901
# API Called
# 619001
# API Called
# 619101
# API Called
# 619201
# API Called
# 619301
# API Called
# 619401
# API Called
# 619501
# API Called
# 619601
# API Called
# 619701
# API Called
# 619801
# API Called
# 619901
# API Called
# 620001
# API Called
# 620101
# API Called
# 620201
# API Called
# 620301
# API Called
# 620401
# API Called
# 620501
# API Called
# 620601
# API Called
# 620701
# API Called
# 620801
# API Called
# 620901
# API Called
# 621001
# API Called
# 621101
# API Called
# 621201
# API Called
# 621301
# API Called
# 621401
# API Called
# 621501
# API Called
# 621601
# API Called
# 621701
# API Called
# 621801
# API Called
# 621901
# API Called
# 622001
# API Called
# 622101
# API Called
# 622201
# API Called
# 622301
# API Called
# 622401
# API Called
# 622501
# API Called
# 622601
# API Called
# 622701
# API Called
# 622801
# API Called
# 622901
# API Called
# 623001
# API Called
# 623101
# API Called
# 623201
# API Called
# 623301
# API Called
# 623401
# API Called
# 623501
# API Called
# 623601
# API Called
# 623701
# API Called
# 623801
# API Called
# 623901
# API Called
# 624001
# API Called
# 624101
# API Called
# 624201
# API Called
# 624301
# API Called
# 624401
# API Called
# 624501
# API Called
# 624601
# API Called
# 624701
# API Called
# 624801
# API Called
# 624901
# API Called
# 625001
# API Called
# 625101
# API Called
# 625201
# API Called
# 625301
# API Called
# 625401
# API Called
# 625501
# API Called
# 625601
# API Called
# 625701
# API Called
# 625801
# API Called
# 625901
# API Called
# 626001
# API Called
# 626101
# API Called
# 626201
# API Called
# 626301
# API Called
# 626401
# API Called
# 626501
# API Called
# 626601
# API Called
# 626701
# API Called
# 626801
# API Called
# 626901
# API Called
# 627001
# API Called
# 627101
# API Called
# 627201
# API Called
# 627301
# API Called
# 627401
# API Called
# 627501
# API Called
# 627601
# API Called
# 627701
# API Called
# 627801
# API Called
# 627901
# API Called
# 628001
# API Called
# 628101
# API Called
# 628201
# API Called
# 628301
# API Called
# 628401
# API Called
# 628501
# API Called
# 628601
# API Called
# 628701
# API Called
# 628801
# API Called
# 628901
# API Called
# 629001
# API Called
# 629101
# API Called
# 629201
# API Called
# 629301
# API Called
# 629401
# API Called
# 629501
# API Called
# 629601
# API Called
# 629701
# API Called
# 629801
# API Called
# 629901
# API Called
# 630001
# API Called
# 630101
# API Called
# 630201
# API Called
# 630301
# API Called
# 630401
# API Called
# 630501
# API Called
# 630601
# API Called
# 630701
# API Called
# 630801
# API Called
# 630901
# API Called
# 631001
# API Called
# 631101
# API Called
# 631201
# API Called
# 631301
# API Called
# 631401
# API Called
# 631501
# API Called
# 631601
# API Called
# 631701
# API Called
# 631801
# API Called
# 631901
# API Called
# 632001
# API Called
# 632101
# API Called
# 632201
# API Called
# 632301
# API Called
# 632401
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=632401&startdate=2023-01-01&enddate=2023-12-31
# 632401
# API Called
# 632501
# API Called
# 632601
# API Called
# 632701
# API Called
# 632801
# API Called
# 632901
# API Called
# 633001
# API Called
# 633101
# API Called
# 633201
# API Called
# 633301
# API Called
# 633401
# API Called
# 633501
# API Called
# 633601
# API Called
# 633701
# API Called
# 633801
# API Called
# 633901
# API Called
# 634001
# API Called
# 634101
# API Called
# 634201
# API Called
# 634301
# API Called
# 634401
# API Called
# 634501
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=634501&startdate=2023-01-01&enddate=2023-12-31
# 634501
# API Called
# 634601
# API Called
# 634701
# API Called
# 634801
# API Called
# 634901
# API Called
# 635001
# API Called
# 635101
# API Called
# 635201
# API Called
# 635301
# API Called
# 635401
# API Called
# 635501
# API Called
# 635601
# API Called
# 635701
# API Called
# 635801
# API Called
# 635901
# API Called
# 636001
# API Called
# 636101
# API Called
# 636201
# API Called
# 636301
# API Called
# 636401
# API Called
# 636501
# API Called
# 636601
# API Called
# 636701
# API Called
# 636801
# API Called
# 636901
# API Called
# 637001
# API Called
# 637101
# API Called
# 637201
# API Called
# 637301
# API Called
# 637401
# API Called
# 637501
# API Called
# 637601
# API Called
# 637701
# API Called
# 637801
# API Called
# 637901
# API Called
# 638001
# API Called
# 638101
# API Called
# 638201
# API Called
# 638301
# API Called
# 638401
# API Called
# 638501
# API Called
# 638601
# API Called
# 638701
# API Called
# 638801
# API Called
# 638901
# API Called
# 639001
# API Called
# 639101
# API Called
# 639201
# API Called
# 639301
# API Called
# 639401
# API Called
# 639501
# API Called
# 639601
# API Called
# 639701
# API Called
# 639801
# API Called
# 639901
# API Called
# 640001
# API Called
# 640101
# API Called
# 640201
# API Called
# 640301
# API Called
# 640401
# API Called
# 640501
# API Called
# 640601
# API Called
# 640701
# API Called
# 640801
# API Called
# 640901
# API Called
# 641001
# API Called
# 641101
# API Called
# 641201
# API Called
# 641301
# API Called
# 641401
# API Called
# 641501
# API Called
# 641601
# API Called
# 641701
# API Called
# 641801
# API Called
# 641901
# API Called
# 642001
# API Called
# 642101
# API Called
# 642201
# API Called
# 642301
# API Called
# 642401
# API Called
# 642501
# API Called
# 642601
# API Called
# 642701
# API Called
# 642801
# API Called
# 642901
# API Called
# 643001
# API Called
# 643101
# API Called
# 643201
# API Called
# 643301
# API Called
# 643401
# API Called
# 643501
# API Called
# 643601
# API Called
# 643701
# API Called
# 643801
# API Called
# 643901
# API Called
# 644001
# API Called
# 644101
# API Called
# 644201
# API Called
# 644301
# API Called
# 644401
# API Called
# 644501
# API Called
# 644601
# API Called
# 644701
# API Called
# 644801
# API Called
# 644901
# API Called
# 645001
# API Called
# 645101
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=645101&startdate=2023-01-01&enddate=2023-12-31
# 645101
# API Called
# 645201
# API Called
# 645301
# API Called
# 645401
# API Called
# 645501
# API Called
# 645601
# API Called
# 645701
# API Called
# 645801
# API Called
# 645901
# API Called
# 646001
# API Called
# 646101
# API Called
# 646201
# API Called
# 646301
# API Called
# 646401
# API Called
# 646501
# API Called
# 646601
# API Called
# 646701
# API Called
# 646801
# API Called
# 646901
# API Called
# 647001
# API Called
# 647101
# API Called
# 647201
# API Called
# 647301
# API Called
# 647401
# API Called
# 647501
# API Called
# 647601
# API Called
# 647701
# API Called
# 647801
# API Called
# 647901
# API Called
# 648001
# API Called
# 648101
# API Called
# 648201
# API Called
# 648301
# API Called
# 648401
# API Called
# 648501
# API Called
# 648601
# API Called
# 648701
# API Called
# 648801
# API Called
# 648901
# API Called
# 649001
# API Called
# 649101
# API Called
# 649201
# API Called
# 649301
# API Called
# 649401
# API Called
# 649501
# API Called
# 649601
# API Called
# 649701
# API Called
# 649801
# API Called
# 649901
# API Called
# 650001
# API Called
# 650101
# API Called
# 650201
# API Called
# 650301
# API Called
# 650401
# API Called
# 650501
# API Called
# 650601
# API Called
# 650701
# API Called
# 650801
# API Called
# 650901
# API Called
# 651001
# API Called
# 651101
# API Called
# 651201
# API Called
# 651301
# API Called
# 651401
# API Called
# 651501
# API Called
# 651601
# API Called
# 651701
# API Called
# 651801
# API Called
# 651901
# API Called
# 652001
# API Called
# 652101
# API Called
# 652201
# API Called
# 652301
# API Called
# 652401
# API Called
# 652501
# API Called
# 652601
# API Called
# 652701
# API Called
# 652801
# API Called
# 652901
# API Called
# 653001
# API Called
# 653101
# API Called
# 653201
# API Called
# 653301
# API Called
# 653401
# API Called
# 653501
# API Called
# 653601
# API Called
# 653701
# API Called
# 653801
# API Called
# 653901
# API Called
# 654001
# API Called
# 654101
# API Called
# 654201
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=654201&startdate=2023-01-01&enddate=2023-12-31
# 654201
# API Called
# 654301
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=654301&startdate=2023-01-01&enddate=2023-12-31
# 654301
# API Called
# 654401
# API Called
# 654501
# API Called
# 654601
# API Called
# 654701
# API Called
# 654801
# API Called
# 654901
# API Called
# 655001
# API Called
# 655101
# API Called
# 655201
# API Called
# 655301
# API Called
# 655401
# API Called
# 655501
# API Called
# 655601
# API Called
# 655701
# API Called
# 655801
# API Called
# 655901
# API Called
# 656001
# API Called
# 656101
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=656101&startdate=2023-01-01&enddate=2023-12-31
# 656101
# API Called
# 656201
# API Called
# 656301
# API Called
# 656401
# API Called
# 656501
# API Called
# 656601
# API Called
# 656701
# API Called
# 656801
# API Called
# 656901
# API Called
# 657001
# API Called
# 657101
# API Called
# 657201
# API Called
# 657301
# API Called
# 657401
# API Called
# 657501
# API Called
# 657601
# API Called
# 657701
# API Called
# 657801
# API Called
# 657901
# API Called
# 658001
# API Called
# 658101
# API Called
# 658201
# API Called
# 658301
# API Called
# 658401
# API Called
# 658501
# API Called
# 658601
# API Called
# 658701
# API Called
# 658801
# API Called
# 658901
# API Called
# 659001
# API Called
# 659101
# API Called
# 659201
# API Called
# 659301
# API Called
# 659401
# API Called
# 659501
# API Called
# 659601
# API Called
# 659701
# API Called
# 659801
# API Called
# 659901
# API Called
# 660001
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=660001&startdate=2023-01-01&enddate=2023-12-31
# 660001
# API Called
# 660101
# API Called
# 660201
# API Called
# 660301
# API Called
# 660401
# API Called
# 660501
# API Called
# 660601
# API Called
# 660701
# API Called
# 660801
# API Called
# 660901
# API Called
# 661001
# API Called
# 661101
# API Called
# 661201
# API Called
# 661301
# API Called
# 661401
# API Called
# 661501
# API Called
# 661601
# API Called
# 661701
# API Called
# 661801
# API Called
# 661901
# API Called
# 662001
# API Called
# 662101
# API Called
# 662201
# API Called
# 662301
# API Called
# 662401
# API Called
# 662501
# API Called
# 662601
# API Called
# 662701
# API Called
# 662801
# API Called
# 662901
# API Called
# 663001
# API Called
# 663101
# API Called
# 663201
# API Called
# 663301
# API Called
# 663401
# API Called
# 663501
# API Called
# 663601
# API Called
# 663701
# API Called
# 663801
# API Called
# 663901
# API Called
# 664001
# API Called
# 664101
# API Called
# 664201
# API Called
# 664301
# API Called
# 664401
# API Called
# 664501
# API Called
# 664601
# API Called
# 664701
# API Called
# 664801
# API Called
# 664901
# API Called
# 665001
# API Called
# 665101
# API Called
# 665201
# API Called
# 665301
# API Called
# 665401
# API Called
# 665501
# API Called
# 665601
# API Called
# 665701
# API Called
# 665801
# API Called
# 665901
# API Called
# 666001
# API Called
# 666101
# API Called
# 666201
# API Called
# 666301
# API Called
# 666401
# API Called
# 666501
# API Called
# 666601
# API Called
# 666701
# API Called
# 666801
# API Called
# 666901
# API Called
# 667001
# API Called
# 667101
# API Called
# 667201
# API Called
# 667301
# API Called
# 667401
# API Called
# 667501
# API Called
# 667601
# API Called
# 667701
# API Called
# 667801
# API Called
# 667901
# API Called
# 668001
# API Called
# 668101
# API Called
# 668201
# API Called
# 668301
# API Called
# 668401
# API Called
# 668501
# API Called
# 668601
# API Called
# 668701
# API Called
# 668801
# API Called
# 668901
# API Called
# 669001
# API Called
# 669101
# API Called
# 669201
# API Called
# 669301
# API Called
# 669401
# API Called
# 669501
# API Called
# 669601
# API Called
# 669701
# API Called
# 669801
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=669801&startdate=2023-01-01&enddate=2023-12-31
# 669801
# API Called
# 669901
# API Called
# 670001
# API Called
# 670101
# API Called
# 670201
# API Called
# 670301
# API Called
# 670401
# API Called
# 670501
# API Called
# 670601
# API Called
# 670701
# API Called
# 670801
# API Called
# 670901
# API Called
# 671001
# API Called
# 671101
# API Called
# 671201
# API Called
# 671301
# API Called
# 671401
# API Called
# 671501
# API Called
# 671601
# API Called
# 671701
# API Called
# 671801
# API Called
# 671901
# API Called
# 672001
# API Called
# 672101
# API Called
# 672201
# API Called
# 672301
# API Called
# 672401
# API Called
# 672501
# API Called
# 672601
# API Called
# 672701
# API Called
# 672801
# API Called
# 672901
# API Called
# 673001
# API Called
# 673101
# API Called
# 673201
# API Called
# 673301
# API Called
# 673401
# API Called
# 673501
# API Called
# 673601
# API Called
# 673701
# API Called
# 673801
# API Called
# 673901
# API Called
# 674001
# API Called
# 674101
# API Called
# 674201
# API Called
# 674301
# API Called
# 674401
# API Called
# 674501
# API Called
# 674601
# API Called
# 674701
# API Called
# 674801
# API Called
# 674901
# API Called
# 675001
# API Called
# 675101
# API Called
# 675201
# API Called
# 675301
# API Called
# 675401
# API Called
# 675501
# API Called
# 675601
# API Called
# 675701
# API Called
# 675801
# API Called
# 675901
# API Called
# 676001
# API Called
# 676101
# API Called
# 676201
# API Called
# 676301
# API Called
# 676401
# API Called
# 676501
# API Called
# 676601
# API Called
# 676701
# API Called
# 676801
# API Called
# 676901
# API Called
# 677001
# API Called
# 677101
# API Called
# 677201
# API Called
# 677301
# API Called
# 677401
# API Called
# 677501
# API Called
# 677601
# API Called
# 677701
# API Called
# 677801
# API Called
# 677901
# API Called
# 678001
# API Called
# 678101
# API Called
# 678201
# API Called
# 678301
# API Called
# 678401
# API Called
# 678501
# API Called
# 678601
# API Called
# 678701
# API Called
# 678801
# API Called
# 678901
# API Called
# 679001
# API Called
# 679101
# API Called
# 679201
# API Called
# 679301
# API Called
# 679401
# API Called
# 679501
# API Called
# 679601
# API Called
# 679701
# API Called
# 679801
# API Called
# 679901
# API Called
# 680001
# API Called
# 680101
# API Called
# 680201
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=680201&startdate=2023-01-01&enddate=2023-12-31
# 680201
# API Called
# 680301
# API Called
# 680401
# API Called
# 680501
# API Called
# 680601
# API Called
# 680701
# API Called
# 680801
# API Called
# 680901
# API Called
# 681001
# API Called
# 681101
# API Called
# 681201
# API Called
# 681301
# API Called
# 681401
# API Called
# 681501
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=681501&startdate=2023-01-01&enddate=2023-12-31
# 681501
# API Called
# 681601
# API Called
# 681701
# API Called
# 681801
# API Called
# 681901
# API Called
# 682001
# API Called
# 682101
# API Called
# 682201
# API Called
# 682301
# API Called
# 682401
# API Called
# 682501
# API Called
# 682601
# API Called
# 682701
# API Called
# 682801
# API Called
# 682901
# API Called
# 683001
# API Called
# 683101
# API Called
# 683201
# API Called
# 683301
# API Called
# 683401
# API Called
# 683501
# API Called
# 683601
# API Called
# 683701
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=683701&startdate=2023-01-01&enddate=2023-12-31
# 683701
# API Called
# 683801
# API Called
# 683901
# API Called
# 684001
# API Called
# 684101
# API Called
# 684201
# API Called
# 684301
# API Called
# 684401
# API Called
# 684501
# API Called
# 684601
# API Called
# 684701
# API Called
# 684801
# API Called
# 684901
# API Called
# 685001
# API Called
# 685101
# API Called
# 685201
# API Called
# 685301
# API Called
# 685401
# API Called
# 685501
# API Called
# 685601
# API Called
# 685701
# API Called
# 685801
# API Called
# 685901
# API Called
# 686001
# API Called
# 686101
# API Called
# 686201
# API Called
# 686301
# API Called
# 686401
# API Called
# 686501
# API Called
# 686601
# API Called
# 686701
# API Called
# 686801
# API Called
# 686901
# API Called
# 687001
# API Called
# 687101
# API Called
# 687201
# API Called
# 687301
# API Called
# 687401
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=687401&startdate=2023-01-01&enddate=2023-12-31
# 687401
# API Called
# 687501
# API Called
# 687601
# API Called
# 687701
# API Called
# 687801
# API Called
# 687901
# API Called
# 688001
# API Called
# 688101
# API Called
# 688201
# API Called
# 688301
# API Called
# 688401
# API Called
# 688501
# API Called
# 688601
# API Called
# 688701
# API Called
# 688801
# API Called
# 688901
# API Called
# 689001
# API Called
# 689101
# API Called
# 689201
# API Called
# 689301
# API Called
# 689401
# API Called
# 689501
# API Called
# 689601
# API Called
# 689701
# API Called
# 689801
# API Called
# 689901
# API Called
# 690001
# API Called
# 690101
# API Called
# 690201
# API Called
# 690301
# API Called
# 690401
# API Called
# 690501
# API Called
# 690601
# API Called
# 690701
# API Called
# 690801
# API Called
# 690901
# API Called
# 691001
# API Called
# 691101
# API Called
# 691201
# API Called
# 691301
# API Called
# 691401
# API Called
# 691501
# API Called
# 691601
# API Called
# 691701
# API Called
# 691801
# API Called
# 691901
# API Called
# 692001
# API Called
# 692101
# API Called
# 692201
# API Called
# 692301
# API Called
# 692401
# API Called
# 692501
# API Called
# 692601
# API Called
# 692701
# API Called
# 692801
# API Called
# 692901
# API Called
# 693001
# API Called
# 693101
# API Called
# 693201
# API Called
# 693301
# API Called
# 693401
# API Called
# 693501
# API Called
# 693601
# API Called
# 693701
# API Called
# 693801
# API Called
# 693901
# API Called
# 694001
# API Called
# 694101
# API Called
# 694201
# API Called
# 694301
# API Called
# 694401
# API Called
# 694501
# API Called
# 694601
# API Called
# 694701
# API Called
# 694801
# API Called
# 694901
# API Called
# 695001
# API Called
# 695101
# API Called
# 695201
# API Called
# 695301
# API Called
# 695401
# API Called
# 695501
# API Called
# 695601
# API Called
# 695701
# API Called
# 695801
# API Called
# 695901
# API Called
# 696001
# API Called
# 696101
# API Called
# 696201
# API Called
# 696301
# API Called
# 696401
# API Called
# 696501
# API Called
# 696601
# API Called
# 696701
# API Called
# 696801
# API Called
# 696901
# API Called
# 697001
# API Called
# 697101
# API Called
# 697201
# API Called
# 697301
# API Called
# 697401
# API Called
# 697501
# API Called
# 697601
# API Called
# 697701
# API Called
# 697801
# API Called
# 697901
# API Called
# 698001
# API Called
# 698101
# API Called
# 698201
# API Called
# 698301
# API Called
# 698401
# API Called
# 698501
# API Called
# 698601
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=698601&startdate=2023-01-01&enddate=2023-12-31
# 698601
# API Called
# 698701
# API Called
# 698801
# API Called
# 698901
# API Called
# 699001
# API Called
# 699101
# API Called
# 699201
# API Called
# 699301
# API Called
# 699401
# API Called
# 699501
# API Called
# 699601
# API Called
# 699701
# API Called
# 699801
# API Called
# 699901
# API Called
# 700001
# API Called
# 700101
# API Called
# 700201
# API Called
# 700301
# API Called
# 700401
# API Called
# 700501
# API Called
# 700601
# API Called
# 700701
# API Called
# 700801
# API Called
# 700901
# API Called
# 701001
# API Called
# 701101
# API Called
# 701201
# API Called
# 701301
# API Called
# 701401
# API Called
# 701501
# API Called
# 701601
# API Called
# 701701
# API Called
# 701801
# API Called
# 701901
# API Called
# 702001
# API Called
# 702101
# API Called
# 702201
# API Called
# 702301
# API Called
# 702401
# API Called
# 702501
# API Called
# 702601
# API Called
# 702701
# API Called
# 702801
# API Called
# 702901
# API Called
# 703001
# API Called
# 703101
# API Called
# 703201
# API Called
# 703301
# API Called
# 703401
# API Called
# 703501
# API Called
# 703601
# API Called
# 703701
# API Called
# 703801
# API Called
# 703901
# API Called
# 704001
# API Called
# 704101
# API Called
# 704201
# API Called
# 704301
# API Called
# 704401
# API Called
# 704501
# API Called
# 704601
# API Called
# 704701
# API Called
# 704801
# API Called
# 704901
# API Called
# 705001
# API Called
# 705101
# API Called
# 705201
# API Called
# 705301
# API Called
# 705401
# API Called
# 705501
# API Called
# 705601
# API Called
# 705701
# API Called
# 705801
# API Called
# 705901
# API Called
# 706001
# API Called
# 706101
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=706101&startdate=2023-01-01&enddate=2023-12-31
# 706101
# API Called
# 706201
# API Called
# 706301
# API Called
# 706401
# API Called
# 706501
# API Called
# 706601
# API Called
# 706701
# API Called
# 706801
# API Called
# 706901
# API Called
# 707001
# API Called
# 707101
# API Called
# 707201
# API Called
# 707301
# API Called
# 707401
# API Called
# 707501
# API Called
# 707601
# API Called
# 707701
# API Called
# 707801
# API Called
# 707901
# API Called
# 708001
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=708001&startdate=2023-01-01&enddate=2023-12-31
# 708001
# API Called
# 708101
# API Called
# 708201
# API Called
# 708301
# API Called
# 708401
# API Called
# 708501
# API Called
# 708601
# API Called
# 708701
# API Called
# 708801
# API Called
# 708901
# API Called
# 709001
# API Called
# 709101
# API Called
# 709201
# API Called
# 709301
# API Called
# 709401
# API Called
# 709501
# API Called
# 709601
# API Called
# 709701
# API Called
# 709801
# API Called
# 709901
# API Called
# 710001
# API Called
# 710101
# API Called
# 710201
# API Called
# 710301
# API Called
# 710401
# API Called
# 710501
# API Called
# 710601
# API Called
# 710701
# API Called
# 710801
# API Called
# 710901
# API Called
# 711001
# API Called
# 711101
# API Called
# 711201
# API Called
# 711301
# API Called
# 711401
# API Called
# 711501
# API Called
# 711601
# API Called
# 711701
# API Called
# 711801
# API Called
# 711901
# API Called
# 712001
# API Called
# 712101
# API Called
# 712201
# API Called
# 712301
# API Called
# 712401
# API Called
# 712501
# API Called
# 712601
# API Called
# 712701
# API Called
# 712801
# API Called
# 712901
# API Called
# 713001
# API Called
# 713101
# API Called
# 713201
# API Called
# 713301
# API Called
# 713401
# API Called
# 713501
# API Called
# 713601
# API Called
# 713701
# API Called
# 713801
# API Called
# 713901
# API Called
# 714001
# API Called
# ...
# 804601
# API Called
# 804701
# API Called
# 804801
# API Called
# 804901
# API Called
# 805001
# API Called
# 805101
# API Called
# 805201
# API Called
# 805301
# API Called
# 805401
# API Called
# 805501
# API Called
# 805601
# API Called
# 805701
# API Called
# 805801
# API Called
# 805901
# API Called
# 806001
# API Called
# 806101
# API Called
# 806201
# API Called
# 806301
# API Called
# 806401
# API Called
# 806501
# API Called
# 806601
# API Called
# 806701
# API Called
# 806801
# API Called
# 806901
# API Called
# 807001
# API Called
# 807101
# API Called
# 807201
# API Called
# 807301
# API Called
# 807401
# API Called
# 807501
# API Called
# 807601
# API Called
# 807701
# API Called
# 807801
# API Called
# 807901
# API Called
# 808001
# API Called
# 808101
# API Called
# 808201
# API Called
# 808301
# API Called
# 808401
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=808401&startdate=2023-01-01&enddate=2023-12-31
# 808401
# API Called
# 808501
# API Called
# 808601
# API Called
# 808701
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=808701&startdate=2023-01-01&enddate=2023-12-31
# 808701
# API Called
# 808801
# API Called
# 808901
# API Called
# 809001
# API Called
# 809101
# API Called
# 809201
# API Called
# 809301
# API Called
# 809401
# API Called
# 809501
# API Called
# 809601
# API Called
# 809701
# API Called
# 809801
# API Called
# 809901
# API Called
# 810001
# API Called
# 810101
# API Called
# 810201
# API Called
# 810301
# API Called
# 810401
# API Called
# 810501
# API Called
# 810601
# API Called
# 810701
# API Called
# 810801
# API Called
# 810901
# API Called
# 811001
# API Called
# 811101
# API Called
# 811201
# API Called
# 811301
# API Called
# 811401
# API Called
# 811501
# API Called
# 811601
# API Called
# 811701
# API Called
# 811801
# API Called
# 811901
# API Called
# 812001
# API Called
# 812101
# API Called
# 812201
# API Called
# 812301
# API Called
# 812401
# API Called
# 812501
# API Called
# 812601
# API Called
# 812701
# API Called
# 812801
# API Called
# 812901
# API Called
# 813001
# API Called
# 813101
# API Called
# 813201
# API Called
# 813301
# API Called
# 813401
# API Called
# 813501
# API Called
# 813601
# API Called
# 813701
# API Called
# 813801
# API Called
# 813901
# API Called
# 814001
# API Called
# 814101
# API Called
# 814201
# API Called
# 814301
# API Called
# 814401
# API Called
# 814501
# API Called
# 814601
# API Called
# 814701
# API Called
# 814801
# API Called
# 814901
# API Called
# 815001
# API Called
# 815101
# API Called
# 815201
# API Called
# 815301
# API Called
# 815401
# API Called
# 815501
# API Called
# 815601
# API Called
# 815701
# API Called
# 815801
# API Called
# 815901
# API Called
# 816001
# API Called
# 816101
# API Called
# 816201
# API Called
# 816301
# API Called
# 816401
# API Called
# 816501
# API Called
# 816601
# API Called
# 816701
# API Called
# 816801
# API Called
# 816901
# API Called
# 817001
# API Called
# 817101
# API Called
# 817201
# API Called
# 817301
# API Called
# 817401
# API Called
# 817501
# API Called
# 817601
# API Called
# 817701
# API Called
# 817801
# API Called
# 817901
# API Called
# 818001
# API Called
# 818101
# API Called
# 818201
# API Called
# 818301
# API Called
# 818401
# API Called
# 818501
# API Called
# 818601
# API Called
# 818701
# API Called
# 818801
# API Called
# 818901
# API Called
# 819001
# API Called
# 819101
# API Called
# 819201
# API Called
# 819301
# API Called
# 819401
# API Called
# 819501
# API Called
# 819601
# API Called
# 819701
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=819701&startdate=2023-01-01&enddate=2023-12-31
# 819701
# API Called
# 819801
# API Called
# 819901
# API Called
# 820001
# API Called
# 820101
# API Called
# 820201
# API Called
# 820301
# API Called
# 820401
# API Called
# 820501
# API Called
# 820601
# API Called
# 820701
# API Called
# 820801
# API Called
# 820901
# API Called
# 821001
# API Called
# 821101
# API Called
# 821201
# API Called
# 821301
# API Called
# 821401
# API Called
# 821501
# API Called
# 821601
# API Called
# 821701
# API Called
# 821801
# API Called
# 821901
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=821901&startdate=2023-01-01&enddate=2023-12-31
# 821901
# API Called
# 822001
# API Called
# 822101
# API Called
# 822201
# API Called
# 822301
# API Called
# 822401
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=822401&startdate=2023-01-01&enddate=2023-12-31
# 822401
# API Called
# 822501
# API Called
# 822601
# API Called
# 822701
# API Called
# 822801
# API Called
# 822901
# API Called
# 823001
# API Called
# 823101
# API Called
# 823201
# API Called
# 823301
# API Called
# 823401
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=823401&startdate=2023-01-01&enddate=2023-12-31
# 823401
# API Called
# 823501
# API Called
# 823601
# API Called
# 823701
# API Called
# 823801
# API Called
# 823901
# API Called
# 824001
# API Called
# 824101
# API Called
# 824201
# API Called
# 824301
# API Called
# 824401
# API Called
# 824501
# API Called
# 824601
# API Called
# 824701
# API Called
# 824801
# API Called
# 824901
# API Called
# 825001
# API Called
# 825101
# API Called
# 825201
# API Called
# 825301
# API Called
# 825401
# API Called
# 825501
# API Called
# 825601
# API Called
# 825701
# API Called
# 825801
# API Called
# 825901
# API Called
# 826001
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=826001&startdate=2023-01-01&enddate=2023-12-31
# 826001
# API Called
# 826101
# API Called
# 826201
# API Called
# 826301
# API Called
# 826401
# API Called
# 826501
# API Called
# 826601
# API Called
# 826701
# API Called
# 826801
# API Called
# 826901
# API Called
# 827001
# API Called
# 827101
# API Called
# 827201
# API Called
# 827301
# API Called
# 827401
# API Called
# 827501
# API Called
# 827601
# API Called
# 827701
# API Called
# 827801
# API Called
# 827901
# API Called
# 828001
# API Called
# 828101
# API Called
# 828201
# API Called
# 828301
# API Called
# 828401
# API Called
# 828501
# API Called
# 828601
# API Called
# 828701
# API Called
# 828801
# API Called
# 828901
# API Called
# 829001
# API Called
# 829101
# API Called
# 829201
# API Called
# 829301
# API Called
# 829401
# API Called
# 829501
# API Called
# 829601
# API Called
# 829701
# API Called
# 829801
# API Called
# 829901
# API Called
# 830001
# API Called
# 830101
# API Called
# 830201
# API Called
# 830301
# API Called
# 830401
# API Called
# 830501
# API Called
# 830601
# API Called
# 830701
# API Called
# 830801
# API Called
# 830901
# API Called
# 831001
# API Called
# 831101
# API Called
# 831201
# API Called
# 831301
# API Called
# 831401
# API Called
# 831501
# API Called
# 831601
# API Called
# 831701
# API Called
# 831801
# API Called
# 831901
# API Called
# 832001
# API Called
# 832101
# API Called
# 832201
# API Called
# 832301
# API Called
# 832401
# API Called
# 832501
# API Called
# 832601
# API Called
# 832701
# API Called
# 832801
# API Called
# 832901
# API Called
# 833001
# API Called
# 833101
# API Called
# 833201
# API Called
# 833301
# API Called
# 833401
# API Called
# 833501
# API Called
# 833601
# API Called
# 833701
# API Called
# 833801
# API Called
# 833901
# API Called
# 834001
# API Called
# 834101
# API Called
# 834201
# API Called
# 834301
# API Called
# 834401
# API Called
# 834501
# API Called
# 834601
# API Called
# 834701
# API Called
# 834801
# API Called
# 834901
# API Called
# 835001
# API Called
# 835101
# API Called
# 835201
# API Called
# 835301
# API Called
# 835401
# API Called
# 835501
# API Called
# 835601
# API Called
# 835701
# API Called
# 835801
# API Called
# 835901
# API Called
# 836001
# API Called
# 836101
# API Called
# 836201
# API Called
# 836301
# API Called
# 836401
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=836401&startdate=2023-01-01&enddate=2023-12-31
# 836401
# API Called
# 836501
# API Called
# 836601
# API Called
# 836701
# API Called
# 836801
# API Called
# 836901
# API Called
# 837001
# API Called
# 837101
# API Called
# 837201
# API Called
# 837301
# API Called
# 837401
# API Called
# 837501
# API Called
# 837601
# API Called
# 837701
# API Called
# 837801
# API Called
# 837901
# API Called
# 838001
# API Called
# 838101
# API Called
# 838201
# API Called
# 838301
# API Called
# 838401
# API Called
# 838501
# API Called
# 838601
# API Called
# 838701
# API Called
# 838801
# API Called
# 838901
# API Called
# 839001
# API Called
# 839101
# API Called
# 839201
# API Called
# 839301
# API Called
# 839401
# API Called
# 839501
# API Called
# 839601
# API Called
# 839701
# API Called
# 839801
# API Called
# 839901
# API Called
# 840001
# API Called
# 840101
# API Called
# 840201
# API Called
# 840301
# API Called
# 840401
# API Called
# 840501
# API Called
# 840601
# API Called
# 840701
# API Called
# 840801
# API Called
# 840901
# API Called
# 841001
# API Called
# 841101
# API Called
# 841201
# API Called
# 841301
# API Called
# 841401
# API Called
# 841501
# API Called
# 841601
# API Called
# 841701
# API Called
# 841801
# API Called
# 841901
# API Called
# 842001
# API Called
# 842101
# API Called
# 842201
# API Called
# 842301
# API Called
# 842401
# API Called
# 842501
# API Called
# 842601
# API Called
# 842701
# API Called
# 842801
# API Called
# 842901
# API Called
# 843001
# API Called
# 843101
# API Called
# 843201
# API Called
# 843301
# API Called
# 843401
# API Called
# 843501
# API Called
# 843601
# API Called
# 843701
# API Called
# 843801
# API Called
# 843901
# API Called
# 844001
# API Called
# 844101
# API Called
# 844201
# API Called
# 844301
# API Called
# 844401
# API Called
# 844501
# API Called
# 844601
# API Called
# 844701
# API Called
# 844801
# API Called
# 844901
# API Called
# 845001
# API Called
# 845101
# API Called
# 845201
# API Called
# 845301
# API Called
# 845401
# API Called
# 845501
# API Called
# 845601
# API Called
# 845701
# API Called
# 845801
# API Called
# 845901
# API Called
# 846001
# API Called
# 846101
# API Called
# 846201
# API Called
# 846301
# API Called
# 846401
# API Called
# 846501
# API Called
# 846601
# API Called
# 846701
# API Called
# 846801
# API Called
# 846901
# API Called
# 847001
# API Called
# 847101
# API Called
# 847201
# API Called
# 847301
# API Called
# 847401
# API Called
# 847501
# API Called
# 847601
# API Called
# 847701
# API Called
# 847801
# API Called
# 847901
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=847901&startdate=2023-01-01&enddate=2023-12-31
# 847901
# API Called
# 848001
# API Called
# 848101
# API Called
# 848201
# API Called
# 848301
# API Called
# 848401
# API Called
# 848501
# API Called
# 848601
# API Called
# 848701
# API Called
# 848801
# API Called
# 848901
# API Called
# 849001
# API Called
# 849101
# API Called
# 849201
# API Called
# 849301
# API Called
# 849401
# API Called
# 849501
# API Called
# 849601
# API Called
# 849701
# API Called
# 849801
# API Called
# 849901
# API Called
# 850001
# API Called
# 850101
# API Called
# 850201
# API Called
# 850301
# API Called
# 850401
# API Called
# 850501
# API Called
# 850601
# API Called
# 850701
# API Called
# 850801
# API Called
# 850901
# API Called
# 851001
# API Called
# 851101
# API Called
# 851201
# API Called
# 851301
# API Called
# 851401
# API Called
# 851501
# API Called
# 851601
# API Called
# 851701
# API Called
# 851801
# API Called
# 851901
# API Called
# 852001
# API Called
# 852101
# API Called
# 852201
# API Called
# 852301
# API Called
# 852401
# API Called
# 852501
# API Called
# 852601
# API Called
# 852701
# API Called
# 852801
# API Called
# 852901
# API Called
# 853001
# API Called
# 853101
# API Called
# 853201
# API Called
# 853301
# API Called
# 853401
# API Called
# 853501
# API Called
# 853601
# API Called
# 853701
# API Called
# 853801
# API Called
# 853901
# API Called
# 854001
# API Called
# 854101
# API Called
# 854201
# API Called
# 854301
# API Called
# 854401
# API Called
# 854501
# API Called
# 854601
# API Called
# 854701
# API Called
# 854801
# API Called
# 854901
# API Called
# 855001
# API Called
# 855101
# API Called
# 855201
# API Called
# 855301
# API Called
# 855401
# API Called
# 855501
# API Called
# 855601
# API Called
# 855701
# API Called
# 855801
# API Called
# 855901
# API Called
# 856001
# API Called
# 856101
# API Called
# 856201
# API Called
# 856301
# API Called
# 856401
# API Called
# 856501
# API Called
# 856601
# API Called
# 856701
# API Called
# 856801
# API Called
# 856901
# API Called
# 857001
# API Called
# 857101
# API Called
# 857201
# API Called
# 857301
# API Called
# 857401
# API Called
# 857501
# API Called
# 857601
# API Called
# 857701
# API Called
# 857801
# API Called
# 857901
# API Called
# 858001
# API Called
# 858101
# API Called
# 858201
# API Called
# 858301
# API Called
# 858401
# API Called
# 858501
# API Called
# 858601
# API Called
# 858701
# API Called
# 858801
# API Called
# 858901
# API Called
# 859001
# API Called
# 859101
# API Called
# 859201
# API Called
# 859301
# API Called
# 859401
# API Called
# 859501
# API Called
# 859601
# API Called
# 859701
# API Called
# 859801
# API Called
# 859901
# API Called
# 860001
# API Called
# 860101
# API Called
# 860201
# API Called
# 860301
# API Called
# 860401
# API Called
# 860501
# API Called
# 860601
# API Called
# 860701
# API Called
# 860801
# API Called
# 860901
# API Called
# 861001
# API Called
# 861101
# API Called
# 861201
# API Called
# 861301
# API Called
# 861401
# API Called
# 861501
# API Called
# 861601
# API Called
# 861701
# API Called
# 861801
# API Called
# 861901
# API Called
# 862001
# API Called
# 862101
# API Called
# 862201
# API Called
# 862301
# API Called
# 862401
# API Called
# 862501
# API Called
# 862601
# API Called
# 862701
# API Called
# 862801
# API Called
# 862901
# API Called
# 863001
# API Called
# 863101
# API Called
# 863201
# API Called
# 863301
# API Called
# 863401
# API Called
# 863501
# API Called
# 863601
# API Called
# 863701
# API Called
# 863801
# API Called
# 863901
# API Called
# 864001
# API Called
# 864101
# API Called
# 864201
# API Called
# 864301
# API Called
# 864401
# API Called
# 864501
# API Called
# 864601
# API Called
# 864701
# API Called
# 864801
# API Called
# 864901
# API Called
# 865001
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=865001&startdate=2023-01-01&enddate=2023-12-31
# 865001
# API Called
# 865101
# API Called
# 865201
# API Called
# 865301
# API Called
# 865401
# API Called
# 865501
# API Called
# 865601
# API Called
# 865701
# API Called
# 865801
# API Called
# 865901
# API Called
# 866001
# API Called
# 866101
# API Called
# 866201
# API Called
# 866301
# API Called
# 866401
# API Called
# 866501
# API Called
# 866601
# API Called
# 866701
# API Called
# 866801
# API Called
# 866901
# API Called
# 867001
# API Called
# 867101
# API Called
# 867201
# API Called
# 867301
# API Called
# 867401
# API Called
# 867501
# API Called
# 867601
# API Called
# 867701
# API Called
# 867801
# API Called
# 867901
# API Called
# 868001
# API Called
# 868101
# API Called
# 868201
# API Called
# 868301
# API Called
# 868401
# API Called
# 868501
# API Called
# 868601
# API Called
# 868701
# API Called
# 868801
# API Called
# 868901
# API Called
# 869001
# API Called
# 869101
# API Called
# 869201
# API Called
# 869301
# API Called
# 869401
# API Called
# 869501
# API Called
# 869601
# API Called
# 869701
# API Called
# 869801
# API Called
# 869901
# API Called
# 870001
# API Called
# 870101
# API Called
# 870201
# API Called
# 870301
# API Called
# 870401
# API Called
# 870501
# API Called
# 870601
# API Called
# 870701
# API Called
# 870801
# API Called
# 870901
# API Called
# 871001
# API Called
# 871101
# API Called
# 871201
# API Called
# 871301
# API Called
# 871401
# API Called
# 871501
# API Called
# 871601
# API Called
# 871701
# API Called
# 871801
# API Called
# 871901
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=871901&startdate=2023-01-01&enddate=2023-12-31
# 871901
# API Called
# 872001
# API Called
# 872101
# API Called
# 872201
# API Called
# 872301
# API Called
# 872401
# API Called
# 872501
# API Called
# 872601
# API Called
# 872701
# API Called
# 872801
# API Called
# 872901
# API Called
# 873001
# API Called
# 873101
# API Called
# 873201
# API Called
# 873301
# API Called
# 873401
# API Called
# 873501
# API Called
# 873601
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=873601&startdate=2023-01-01&enddate=2023-12-31
# 873601
# API Called
# 873701
# API Called
# 873801
# API Called
# 873901
# API Called
# 874001
# API Called
# 874101
# API Called
# 874201
# API Called
# 874301
# API Called
# 874401
# API Called
# 874501
# API Called
# 874601
# API Called
# 874701
# API Called
# 874801
# API Called
# 874901
# API Called
# 875001
# API Called
# 875101
# API Called
# 875201
# API Called
# 875301
# API Called
# 875401
# API Called
# 875501
# API Called
# 875601
# API Called
# 875701
# API Called
# 875801
# API Called
# 875901
# API Called
# 876001
# API call failed: 503 Server Error: Service Unavailable for url: https://www.ncdc.noaa.gov/cdo-web/api/v2//data/?datasetid=GHCND&locationid=FIPS%3A27&limit=100&offset=876001&startdate=2023-01-01&enddate=2023-12-31
# 876001
# API Called
# 876101
# API Called
# 876201
# API Called
# 876301
# API Called
# 876401
# API Called
# 876501
# API Called
# 876601
# API Called
# 876701
# API Called
# 876801
# API Called
# 876901
# API Called
