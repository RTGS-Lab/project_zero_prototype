# %%
import requests
import os
from time import sleep

## DOWNLOAD_FILE: performs request call and downloads file to given directory with retry logic.
def download_file(url, target_folder):
    # Extract filename from URL
    filename = url.split('/')[-1]

    # Make sure the target folder exists
    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    # Full path for saving the file
    full_path = os.path.join(target_folder, filename)

    # Retry logic
    max_attempts = 3
    attempts = 0

    while attempts < max_attempts:
        try:
            # Send a GET request to the URL
            response = requests.get(url, stream=True)
            
            # Raise an exception if the request was unsuccessful
            response.raise_for_status()

            # Open the target file in binary write mode
            with open(full_path, 'wb') as file:
                # Write the content of the response in chunks to the file
                for chunk in response.iter_content(chunk_size=8192):
                    file.write(chunk)

            print(f"File downloaded: {full_path}")
            return  # Exit function after successful download
        except requests.exceptions.RequestException as e:
            attempts += 1
            print(f"Attempt {attempts} failed: {e}")
            sleep(1)  # Wait for 1 second before retrying

    print(f"Failed to download the file after {max_attempts} attempts.")

# %%
##file_downloads: This is an interface for the NOAA data. needs web directory and then iterates for 12 months.
def file_downloads(year):
    web_dir = 'https://www.ncei.noaa.gov/data/nclimgrid-daily/access/grids/'
    year = str(year)
    output_dir = 'downloaded_files/' + year

    start = 'ncdd-'
    end = '-grd-scaled.nc'
    for i in range(12):
        adder = ''
        if i+1 < 10:
            adder = '0'
        filepath = '/' + start + year + adder + str(i+1) + end
        print(filepath)
        filepath = web_dir + filepath
        try:
            download_file(filepath, output_dir)
        
        except Exception as e:
            print('error')
            print(e)

# %%
##Main function. Change how many years you want to download.
#WARNING: downloading all the data from 1951 on will take a lot of storage!
# Roughtly 50gb (~60Mb per file, 12 months per year, 72 years)
def main():
    start = 2018
    end = 2023
    
    for i in range(end-start+1):
        thisyear = start + i
        file_downloads(thisyear)

# %%
main()
# Out:
# /2018/ncdd-201801-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201801-grd-scaled.nc
# /2018/ncdd-201802-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201802-grd-scaled.nc
# /2018/ncdd-201803-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201803-grd-scaled.nc
# /2018/ncdd-201804-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201804-grd-scaled.nc
# /2018/ncdd-201805-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201805-grd-scaled.nc
# /2018/ncdd-201806-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201806-grd-scaled.nc
# /2018/ncdd-201807-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201807-grd-scaled.nc
# /2018/ncdd-201808-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201808-grd-scaled.nc
# /2018/ncdd-201809-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201809-grd-scaled.nc
# /2018/ncdd-201810-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201810-grd-scaled.nc
# /2018/ncdd-201811-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201811-grd-scaled.nc
# /2018/ncdd-201812-grd-scaled.nc
# File downloaded: downloaded_files/2018\ncdd-201812-grd-scaled.nc
# /2019/ncdd-201901-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201901-grd-scaled.nc
# /2019/ncdd-201902-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201902-grd-scaled.nc
# /2019/ncdd-201903-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201903-grd-scaled.nc
# /2019/ncdd-201904-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201904-grd-scaled.nc
# /2019/ncdd-201905-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201905-grd-scaled.nc
# /2019/ncdd-201906-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201906-grd-scaled.nc
# /2019/ncdd-201907-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201907-grd-scaled.nc
# /2019/ncdd-201908-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201908-grd-scaled.nc
# /2019/ncdd-201909-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201909-grd-scaled.nc
# /2019/ncdd-201910-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201910-grd-scaled.nc
# /2019/ncdd-201911-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201911-grd-scaled.nc
# /2019/ncdd-201912-grd-scaled.nc
# File downloaded: downloaded_files/2019\ncdd-201912-grd-scaled.nc
# /2020/ncdd-202001-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202001-grd-scaled.nc
# /2020/ncdd-202002-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202002-grd-scaled.nc
# /2020/ncdd-202003-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202003-grd-scaled.nc
# /2020/ncdd-202004-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202004-grd-scaled.nc
# /2020/ncdd-202005-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202005-grd-scaled.nc
# /2020/ncdd-202006-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202006-grd-scaled.nc
# /2020/ncdd-202007-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202007-grd-scaled.nc
# /2020/ncdd-202008-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202008-grd-scaled.nc
# /2020/ncdd-202009-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202009-grd-scaled.nc
# /2020/ncdd-202010-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202010-grd-scaled.nc
# /2020/ncdd-202011-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202011-grd-scaled.nc
# /2020/ncdd-202012-grd-scaled.nc
# File downloaded: downloaded_files/2020\ncdd-202012-grd-scaled.nc
# /2021/ncdd-202101-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202101-grd-scaled.nc
# /2021/ncdd-202102-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202102-grd-scaled.nc
# /2021/ncdd-202103-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202103-grd-scaled.nc
# /2021/ncdd-202104-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202104-grd-scaled.nc
# /2021/ncdd-202105-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202105-grd-scaled.nc
# /2021/ncdd-202106-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202106-grd-scaled.nc
# /2021/ncdd-202107-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202107-grd-scaled.nc
# /2021/ncdd-202108-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202108-grd-scaled.nc
# /2021/ncdd-202109-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202109-grd-scaled.nc
# /2021/ncdd-202110-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202110-grd-scaled.nc
# /2021/ncdd-202111-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202111-grd-scaled.nc
# /2021/ncdd-202112-grd-scaled.nc
# File downloaded: downloaded_files/2021\ncdd-202112-grd-scaled.nc
# /2022/ncdd-202201-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202201-grd-scaled.nc
# /2022/ncdd-202202-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202202-grd-scaled.nc
# /2022/ncdd-202203-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202203-grd-scaled.nc
# /2022/ncdd-202204-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202204-grd-scaled.nc
# /2022/ncdd-202205-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202205-grd-scaled.nc
# /2022/ncdd-202206-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202206-grd-scaled.nc
# /2022/ncdd-202207-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202207-grd-scaled.nc
# /2022/ncdd-202208-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202208-grd-scaled.nc
# /2022/ncdd-202209-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202209-grd-scaled.nc
# /2022/ncdd-202210-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202210-grd-scaled.nc
# /2022/ncdd-202211-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202211-grd-scaled.nc
# /2022/ncdd-202212-grd-scaled.nc
# File downloaded: downloaded_files/2022\ncdd-202212-grd-scaled.nc
# /2023/ncdd-202301-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202301-grd-scaled.nc
# /2023/ncdd-202302-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202302-grd-scaled.nc
# /2023/ncdd-202303-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202303-grd-scaled.nc
# /2023/ncdd-202304-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202304-grd-scaled.nc
# /2023/ncdd-202305-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202305-grd-scaled.nc
# /2023/ncdd-202306-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202306-grd-scaled.nc
# /2023/ncdd-202307-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202307-grd-scaled.nc
# /2023/ncdd-202308-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202308-grd-scaled.nc
# /2023/ncdd-202309-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202309-grd-scaled.nc
# /2023/ncdd-202310-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202310-grd-scaled.nc
# /2023/ncdd-202311-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202311-grd-scaled.nc
# /2023/ncdd-202312-grd-scaled.nc
# File downloaded: downloaded_files/2023\ncdd-202312-grd-scaled.nc
