# %%
#imports
import requests

# %%
#Set up requests (get token)

# Open the text file and read the API key
with open('../API_Keys/NOAA_Token.txt', 'r') as file:
    api_key = file.read().strip()  # .strip() removes any leading/trailing whitespace

url = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/'

headers = {
    'token': api_key
}

#Define an API call function
def api_call(url, endpoint, headers, parameters):
    url += endpoint
    response = requests.get(url, headers=headers, params=parameters)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
        print("API Called")
    else:
        print("Error:", response.status_code)
        data = response.status_code
    return data

def append_to_csv(file_path, data):
    """Function to append data to a CSV file."""
    with open(file_path, mode='a', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=data[0].keys())
        
        if file.tell() == 0:  # Check if file is empty to write headers
            writer.writeheader()
        
        writer.writerows(data)

# %%
#List stations in Minnesota
endpoint = '/stations/'

# Specify the dataset, station ID, and date range
parameters = {
    'locationid': 'FIPS:72',
    'limit': 1000, # max is 1000 for a single request
    'offset': 1
}

data = api_call(url, endpoint, headers, parameters)
# Out:
# API Called

# %%
data
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 413, 'limit': 1000}},
#  'results': [{'elevation': 598.9,
#    'mindate': '1947-06-01',
#    'maxdate': '2015-08-01',
#    'latitude': 18.1469,
#    'name': 'ACEITUNA WATER TREATMENT PLANT, US',
#    'datacoverage': 0.9475,
#    'id': 'COOP:660040',
#    'elevationUnit': 'METERS',
#    'longitude': -66.4919},
#   {'elevation': 454.8,
#    'mindate': '1931-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.17236,
#    'name': 'ADJUNTAS 2 NW, US',
#    'datacoverage': 0.9303,
#    'id': 'COOP:660053',
#    'elevationUnit': 'METERS',
#    'longitude': -66.73831},
#   {'elevation': 557.8,
#    'mindate': '1970-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.1747,
#    'name': 'ADJUNTAS SUBSTATION, US',
#    'datacoverage': 0.9964,
#    'id': 'COOP:660061',
#    'elevationUnit': 'METERS',
#    'longitude': -66.7977},
#   {'elevation': 14.9,
#    'mindate': '1900-01-01',
#    'maxdate': '1966-12-01',
#    'latitude': 17.96667,
#    'name': 'AGUIRRE, US',
#    'datacoverage': 0.9888,
#    'id': 'COOP:660147',
#    'elevationUnit': 'METERS',
#    'longitude': -66.21667},
#   {'elevation': 7.6,
#    'mindate': '1955-04-01',
#    'maxdate': '2015-11-01',
#    'latitude': 17.9555,
#    'name': 'AGUIRRE, US',
#    'datacoverage': 0.9327,
#    'id': 'COOP:660152',
#    'elevationUnit': 'METERS',
#    'longitude': -66.2222},
#   {'elevation': 710.2,
#    'mindate': '1931-05-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.128,
#    'name': 'AIBONITO 1 S, US',
#    'datacoverage': 0.7458,
#    'id': 'COOP:660158',
#    'elevationUnit': 'METERS',
#    'longitude': -66.2641},
#   {'elevation': 0,
#    'mindate': '1953-01-01',
#    'maxdate': '1954-03-01',
#    'latitude': 18.28333,
#    'name': 'ANGELES, US',
#    'datacoverage': 0.8027,
#    'id': 'COOP:660301',
#    'elevationUnit': 'METERS',
#    'longitude': -66.78333},
#   {'elevation': 3,
#    'mindate': '1900-01-01',
#    'maxdate': '1999-01-01',
#    'latitude': 18.45333,
#    'name': 'ARECIBO 3 ESE, US',
#    'datacoverage': 0.9588,
#    'id': 'COOP:660410',
#    'elevationUnit': 'METERS',
#    'longitude': -66.67472},
#   {'elevation': 323.1,
#    'mindate': '1980-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.3494,
#    'name': 'ARECIBO OBSERVATORY, US',
#    'datacoverage': 0.9699,
#    'id': 'COOP:660426',
#    'elevationUnit': 'METERS',
#    'longitude': -66.7525},
#   {'elevation': 3,
#    'mindate': '1931-01-01',
#    'maxdate': '1990-05-01',
#    'latitude': 18.46667,
#    'name': 'BARCELONETA 2, US',
#    'datacoverage': 0.878,
#    'id': 'COOP:660662',
#    'elevationUnit': 'METERS',
#    'longitude': -66.5},
#   {'elevation': 73.2,
#    'mindate': '1990-09-01',
#    'maxdate': '2009-12-01',
#    'latitude': 18.42861,
#    'name': 'BARCELONETA 3 SW, US',
#    'datacoverage': 0.8232,
#    'id': 'COOP:660668',
#    'elevationUnit': 'METERS',
#    'longitude': -66.56306},
#   {'elevation': 627.9,
#    'mindate': '1936-09-01',
#    'maxdate': '1991-12-01',
#    'latitude': 18.16667,
#    'name': 'BARRANQUITAS, US',
#    'datacoverage': 0.7952,
#    'id': 'COOP:660736',
#    'elevationUnit': 'METERS',
#    'longitude': -66.31667},
#   {'elevation': 75,
#    'mindate': '1952-08-01',
#    'maxdate': '1973-05-01',
#    'latitude': 18.4,
#    'name': 'CANDELARIA TOA BAJA, US',
#    'datacoverage': 0.996,
#    'id': 'COOP:660842',
#    'elevationUnit': 'METERS',
#    'longitude': -66.21667},
#   {'elevation': 262.1,
#    'mindate': '1970-06-01',
#    'maxdate': '1979-08-01',
#    'latitude': 18.38333,
#    'name': 'BAYANEY, US',
#    'datacoverage': 0.9819,
#    'id': 'COOP:660849',
#    'elevationUnit': 'METERS',
#    'longitude': -66.78333},
#   {'elevation': 13.7,
#    'mindate': '1973-07-01',
#    'maxdate': '2002-08-01',
#    'latitude': 18.11639,
#    'name': 'BENAVENTE HORMIGUERO, US',
#    'datacoverage': 0.5272,
#    'id': 'COOP:660900',
#    'elevationUnit': 'METERS',
#    'longitude': -67.11333},
#   {'elevation': 4.6,
#    'mindate': '1996-07-01',
#    'maxdate': '2012-12-01',
#    'latitude': 17.9906,
#    'name': 'BOCA, US',
#    'datacoverage': 0.9998,
#    'id': 'COOP:660948',
#    'elevationUnit': 'METERS',
#    'longitude': -66.816},
#   {'elevation': 72.2,
#    'mindate': '1974-01-01',
#    'maxdate': '2013-12-01',
#    'latitude': 18.494861,
#    'name': 'BORINQUEN AIRPORT, US',
#    'datacoverage': 0.8771,
#    'id': 'COOP:660974',
#    'elevationUnit': 'METERS',
#    'longitude': -67.129444},
#   {'elevation': 563.9,
#    'mindate': '1973-06-01',
#    'maxdate': '2014-01-01',
#    'latitude': 18.2422,
#    'name': 'BOTIJAS 1 OROCOVIS, US',
#    'datacoverage': 0.037,
#    'id': 'COOP:660984',
#    'elevationUnit': 'METERS',
#    'longitude': -66.358},
#   {'elevation': 685.8,
#    'mindate': '1973-06-01',
#    'maxdate': '2014-01-01',
#    'latitude': 18.1925,
#    'name': 'BOTIJAS 2 OROCOVIS, US',
#    'datacoverage': 0.0317,
#    'id': 'COOP:660988',
#    'elevationUnit': 'METERS',
#    'longitude': -66.3502},
#   {'elevation': 75.9,
#    'mindate': '1931-01-01',
#    'maxdate': '1969-08-01',
#    'latitude': 18.08333,
#    'name': 'CABO ROJO, US',
#    'datacoverage': 0.9871,
#    'id': 'COOP:661123',
#    'elevationUnit': 'METERS',
#    'longitude': -67.15},
#   {'elevation': 554.7,
#    'mindate': '1981-05-01',
#    'maxdate': '2010-12-01',
#    'latitude': 18.22583,
#    'name': 'CACAOS OROCOVIS, US',
#    'datacoverage': 0.9943,
#    'id': 'COOP:661142',
#    'elevationUnit': 'METERS',
#    'longitude': -66.50389},
#   {'elevation': 75.9,
#    'mindate': '1931-01-01',
#    'maxdate': '1960-05-01',
#    'latitude': 18.23333,
#    'name': 'CAGUAS, US',
#    'datacoverage': 0.8442,
#    'id': 'COOP:661300',
#    'elevationUnit': 'METERS',
#    'longitude': -66.03333},
#   {'elevation': 53.9,
#    'mindate': '1960-08-01',
#    'maxdate': '1967-05-01',
#    'latitude': 18.25,
#    'name': 'CAGUAS 2 ENE, US',
#    'datacoverage': 0.9637,
#    'id': 'COOP:661301',
#    'elevationUnit': 'METERS',
#    'longitude': -66.01667},
#   {'elevation': 79.2,
#    'mindate': '1970-01-01',
#    'maxdate': '1995-03-01',
#    'latitude': 18.23333,
#    'name': 'CAGUAS 1 W, US',
#    'datacoverage': 0.954,
#    'id': 'COOP:661309',
#    'elevationUnit': 'METERS',
#    'longitude': -66.05},
#   {'elevation': 85,
#    'mindate': '1931-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.4724,
#    'name': 'CALERO CAMP, US',
#    'datacoverage': 0.9833,
#    'id': 'COOP:661345',
#    'elevationUnit': 'METERS',
#    'longitude': -67.1155},
#   {'elevation': 29.9,
#    'mindate': '1945-05-01',
#    'maxdate': '1966-02-01',
#    'latitude': 18.45,
#    'name': 'CAMBALACHE EXPERIMENTAL FORES, US',
#    'datacoverage': 0.876,
#    'id': 'COOP:661423',
#    'elevationUnit': 'METERS',
#    'longitude': -66.6},
#   {'elevation': 75,
#    'mindate': '1973-09-01',
#    'maxdate': '1995-08-01',
#    'latitude': 18.4,
#    'name': 'CANDELARIA TOA BAJA, US',
#    'datacoverage': 0.7728,
#    'id': 'COOP:661536',
#    'elevationUnit': 'METERS',
#    'longitude': -66.21667},
#   {'elevation': 9.1,
#    'mindate': '1900-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.3791,
#    'name': 'CANOVANAS, US',
#    'datacoverage': 0.9979,
#    'id': 'COOP:661590',
#    'elevationUnit': 'METERS',
#    'longitude': -65.8938},
#   {'elevation': 260.3,
#    'mindate': '1944-05-01',
#    'maxdate': '1987-11-01',
#    'latitude': 18.28333,
#    'name': 'CAONILLAS UTUADO, US',
#    'datacoverage': 0.9809,
#    'id': 'COOP:661623',
#    'elevationUnit': 'METERS',
#    'longitude': -66.65},
#   {'elevation': 182,
#    'mindate': '1944-07-01',
#    'maxdate': '1969-12-01',
#    'latitude': 18.11667,
#    'name': 'CAONILLAS VILLALBA, US',
#    'datacoverage': 0.9541,
#    'id': 'COOP:661634',
#    'elevationUnit': 'METERS',
#    'longitude': -66.48333},
#   {'elevation': 551.1,
#    'mindate': '1931-01-01',
#    'maxdate': '1980-08-01',
#    'latitude': 18.08333,
#    'name': 'CARITE DAM, US',
#    'datacoverage': 0.9966,
#    'id': 'COOP:661701',
#    'elevationUnit': 'METERS',
#    'longitude': -66.1},
#   {'elevation': 295,
#    'mindate': '1945-01-01',
#    'maxdate': '1980-07-01',
#    'latitude': 18.05,
#    'name': 'CARITE PLANT 1, US',
#    'datacoverage': 0.9672,
#    'id': 'COOP:661712',
#    'elevationUnit': 'METERS',
#    'longitude': -66.11667},
#   {'elevation': 6.1,
#    'mindate': '1942-01-01',
#    'maxdate': '1976-05-01',
#    'latitude': 18.41667,
#    'name': 'CATANO, US',
#    'datacoverage': 0.9928,
#    'id': 'COOP:661845',
#    'elevationUnit': 'METERS',
#    'longitude': -66.11667},
#   {'elevation': 395,
#    'mindate': '1931-01-01',
#    'maxdate': '2014-01-01',
#    'latitude': 18.1188,
#    'name': 'CAYEY 1 E, US',
#    'datacoverage': 0.8951,
#    'id': 'COOP:661901',
#    'elevationUnit': 'METERS',
#    'longitude': -66.1658},
#   {'elevation': 4.6,
#    'mindate': '1931-01-01',
#    'maxdate': '1996-06-01',
#    'latitude': 17.9906,
#    'name': 'BOCA, US',
#    'datacoverage': 0.9911,
#    'id': 'COOP:662316',
#    'elevationUnit': 'METERS',
#    'longitude': -66.816},
#   {'elevation': 291.1,
#    'mindate': '1969-10-01',
#    'maxdate': '1997-09-01',
#    'latitude': 18.27639,
#    'name': 'CERRO GORDO CIALES, US',
#    'datacoverage': 0.9881,
#    'id': 'COOP:662330',
#    'elevationUnit': 'METERS',
#    'longitude': -66.51944},
#   {'elevation': 1219.8,
#    'mindate': '1969-03-01',
#    'maxdate': '2013-08-01',
#    'latitude': 18.1547,
#    'name': 'CERRO MARAVILLA, US',
#    'datacoverage': 0.9334,
#    'id': 'COOP:662336',
#    'elevationUnit': 'METERS',
#    'longitude': -66.5619},
#   {'elevation': 426.7,
#    'mindate': '1931-01-01',
#    'maxdate': '1994-06-01',
#    'latitude': 18.18333,
#    'name': 'CIDRA 1 E, US',
#    'datacoverage': 0.9253,
#    'id': 'COOP:662634',
#    'elevationUnit': 'METERS',
#    'longitude': -66.15},
#   {'elevation': 111.3,
#    'mindate': '1932-01-01',
#    'maxdate': '2003-12-01',
#    'latitude': 18.06639,
#    'name': 'COAMO 2 SW, US',
#    'datacoverage': 0.9514,
#    'id': 'COOP:662723',
#    'elevationUnit': 'METERS',
#    'longitude': -66.37806},
#   {'elevation': 12.2,
#    'mindate': '1931-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.3808,
#    'name': 'COLOSO, US',
#    'datacoverage': 0.9941,
#    'id': 'COOP:662801',
#    'elevationUnit': 'METERS',
#    'longitude': -67.1569},
#   {'elevation': 111.9,
#    'mindate': '1931-01-01',
#    'maxdate': '1959-01-01',
#    'latitude': 18.26667,
#    'name': 'COMERIO FALLS PLANT, US',
#    'datacoverage': 0.9999,
#    'id': 'COOP:662823',
#    'elevationUnit': 'METERS',
#    'longitude': -66.18333},
#   {'elevation': 111.9,
#    'mindate': '1959-02-01',
#    'maxdate': '1974-05-01',
#    'latitude': 18.26667,
#    'name': 'COMERIO FALLS PLANT, US',
#    'datacoverage': 1,
#    'id': 'COOP:662825',
#    'elevationUnit': 'METERS',
#    'longitude': -66.18333},
#   {'elevation': 198.1,
#    'mindate': '1900-01-01',
#    'maxdate': '2013-08-01',
#    'latitude': 18.3266,
#    'name': 'COROZAL SUBSTATION, US',
#    'datacoverage': 0.9137,
#    'id': 'COOP:662934',
#    'elevationUnit': 'METERS',
#    'longitude': -66.3591},
#   {'elevation': 198.1,
#    'mindate': '1970-05-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.08425,
#    'name': 'CORRAL VIEJO, US',
#    'datacoverage': 0.9872,
#    'id': 'COOP:663023',
#    'elevationUnit': 'METERS',
#    'longitude': -66.65464},
#   {'elevation': 497.7,
#    'mindate': '1973-05-01',
#    'maxdate': '2014-01-01',
#    'latitude': 18.26867,
#    'name': 'CUBUY, US',
#    'datacoverage': 0.0478,
#    'id': 'COOP:663113',
#    'elevationUnit': 'METERS',
#    'longitude': -65.86748},
#   {'elevation': 14.9,
#    'mindate': '1938-01-01',
#    'maxdate': '1975-07-01',
#    'latitude': 18.30301,
#    'name': 'CULEBRA ISLAND, US',
#    'datacoverage': 0.989,
#    'id': 'COOP:663145',
#    'elevationUnit': 'METERS',
#    'longitude': -65.30098},
#   {'elevation': 1.5,
#    'mindate': '1907-11-01',
#    'maxdate': '2006-05-01',
#    'latitude': 18.47222,
#    'name': 'DORADO 2 WNW, US',
#    'datacoverage': 0.962,
#    'id': 'COOP:663409',
#    'elevationUnit': 'METERS',
#    'longitude': -66.30556},
#   {'elevation': 61,
#    'mindate': '1936-12-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.3361,
#    'name': 'DOS BOCAS, US',
#    'datacoverage': 0.9884,
#    'id': 'COOP:663431',
#    'elevationUnit': 'METERS',
#    'longitude': -66.6666},
#   {'elevation': 137.2,
#    'mindate': '1973-05-01',
#    'maxdate': '2001-07-01',
#    'latitude': 18.255,
#    'name': 'DUQUE 2 NE, US',
#    'datacoverage': 0.0498,
#    'id': 'COOP:663480',
#    'elevationUnit': 'METERS',
#    'longitude': -65.71194},
#   {'elevation': 17.7,
#    'mindate': '1931-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 17.9955,
#    'name': 'ENSENADA 1 W, US',
#    'datacoverage': 0.9696,
#    'id': 'COOP:663532',
#    'elevationUnit': 'METERS',
#    'longitude': -66.95719},
#   {'elevation': 9.1,
#    'mindate': '1900-01-01',
#    'maxdate': '2014-01-01',
#    'latitude': 18.3096,
#    'name': 'FAJARDO, US',
#    'datacoverage': 0.9922,
#    'id': 'COOP:663657',
#    'elevationUnit': 'METERS',
#    'longitude': -65.6625},
#   {'elevation': 9.1,
#    'mindate': '1965-09-01',
#    'maxdate': '1970-04-01',
#    'latitude': 18.45,
#    'name': 'GARROCHALES, US',
#    'datacoverage': 0.9473,
#    'id': 'COOP:663850',
#    'elevationUnit': 'METERS',
#    'longitude': -66.58333},
#   {'elevation': 719,
#    'mindate': '1931-01-01',
#    'maxdate': '1981-01-01',
#    'latitude': 18.15,
#    'name': 'GARZAS, US',
#    'datacoverage': 0.9683,
#    'id': 'COOP:663871',
#    'elevationUnit': 'METERS',
#    'longitude': -66.73333},
#   {'elevation': 202.1,
#    'mindate': '1931-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.3963,
#    'name': 'GUAJATACA DAM, US',
#    'datacoverage': 0.9775,
#    'id': 'COOP:663904',
#    'elevationUnit': 'METERS',
#    'longitude': -66.9244},
#   {'elevation': 780.3,
#    'mindate': '1969-10-01',
#    'maxdate': '1994-06-01',
#    'latitude': 18.11667,
#    'name': 'GUAVATE CAMP, US',
#    'datacoverage': 0.8688,
#    'id': 'COOP:664115',
#    'elevationUnit': 'METERS',
#    'longitude': -66.06667},
#   {'elevation': 112.8,
#    'mindate': '1931-01-01',
#    'maxdate': '2008-03-01',
#    'latitude': 18.0741,
#    'name': 'GUAYABAL, US',
#    'datacoverage': 0.9774,
#    'id': 'COOP:664126',
#    'elevationUnit': 'METERS',
#    'longitude': -66.4966},
#   {'elevation': 41.5,
#    'mindate': '1931-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 17.9798,
#    'name': 'GUAYAMA 1 SW, US',
#    'datacoverage': 0.9892,
#    'id': 'COOP:664193',
#    'elevationUnit': 'METERS',
#    'longitude': -66.12625},
#   {'elevation': 9.1,
#    'mindate': '1955-01-01',
#    'maxdate': '1961-08-01',
#    'latitude': 18,
#    'name': 'GUAYANILLA, US',
#    'datacoverage': 1,
#    'id': 'COOP:664211',
#    'elevationUnit': 'METERS',
#    'longitude': -66.86667},
#   {'elevation': 914.1,
#    'mindate': '1931-01-01',
#    'maxdate': '1969-03-01',
#    'latitude': 18.16667,
#    'name': 'GUINEO RESERVOIR, US',
#    'datacoverage': 1,
#    'id': 'COOP:664260',
#    'elevationUnit': 'METERS',
#    'longitude': -66.53333},
#   {'elevation': 75.9,
#    'mindate': '1942-01-01',
#    'maxdate': '1967-05-01',
#    'latitude': 18.25,
#    'name': 'GURABO, US',
#    'datacoverage': 0.9903,
#    'id': 'COOP:664271',
#    'elevationUnit': 'METERS',
#    'longitude': -65.96667},
#   {'elevation': 288,
#    'mindate': '1973-05-01',
#    'maxdate': '2005-04-01',
#    'latitude': 18.29361,
#    'name': 'GURABO 3 NW, US',
#    'datacoverage': 0.0364,
#    'id': 'COOP:664272',
#    'elevationUnit': 'METERS',
#    'longitude': -65.99889},
#   {'elevation': 48.8,
#    'mindate': '1956-03-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.2583,
#    'name': 'GURABO SUBSTATION, US',
#    'datacoverage': 0.9986,
#    'id': 'COOP:664276',
#    'elevationUnit': 'METERS',
#    'longitude': -65.9922},
#   {'elevation': 146.3,
#    'mindate': '1969-09-01',
#    'maxdate': '2011-12-01',
#    'latitude': 18.1243,
#    'name': 'HACIENDA CONSTANZA, US',
#    'datacoverage': 0.9567,
#    'id': 'COOP:664330',
#    'elevationUnit': 'METERS',
#    'longitude': -67.053},
#   {'elevation': 196.6,
#    'mindate': '2011-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.2159,
#    'name': 'HACIENDA CONSTANZA 2 W, US',
#    'datacoverage': 0.8139,
#    'id': 'COOP:664331',
#    'elevationUnit': 'METERS',
#    'longitude': -67.0883},
#   {'elevation': 64.9,
#    'mindate': '1974-01-01',
#    'maxdate': '1994-08-01',
#    'latitude': 18.45,
#    'name': 'HATO ARRIBA ARECIBO, US',
#    'datacoverage': 0.9678,
#    'id': 'COOP:664340',
#    'elevationUnit': 'METERS',
#    'longitude': -66.76667},
#   {'elevation': 39.9,
#    'mindate': '1900-01-01',
#    'maxdate': '1996-01-01',
#    'latitude': 18.13333,
#    'name': 'HUMACAO 2 SSE, US',
#    'datacoverage': 0.9723,
#    'id': 'COOP:664613',
#    'elevationUnit': 'METERS',
#    'longitude': -65.81667},
#   {'elevation': 2.7,
#    'mindate': '2013-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.1505,
#    'name': 'HUMACAO NATURAL RESERVE, US',
#    'datacoverage': 1,
#    'id': 'COOP:664614',
#    'elevationUnit': 'METERS',
#    'longitude': -65.7719},
#   {'elevation': 792.5,
#    'mindate': '1962-10-01',
#    'maxdate': '1990-06-01',
#    'latitude': 18.16667,
#    'name': 'INDIERA ALTA, US',
#    'datacoverage': 0.973,
#    'id': 'COOP:664677',
#    'elevationUnit': 'METERS',
#    'longitude': -66.88333},
#   {'elevation': 853.1,
#    'mindate': '1952-11-01',
#    'maxdate': '1962-09-01',
#    'latitude': 18.18333,
#    'name': 'INDIERA BAJA, US',
#    'datacoverage': 0.9919,
#    'id': 'COOP:664685',
#    'elevationUnit': 'METERS',
#    'longitude': -66.9},
#   {'elevation': 128,
#    'mindate': '1931-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.4652,
#    'name': 'ISABELA SUBSTATION, US',
#    'datacoverage': 0.9598,
#    'id': 'COOP:664702',
#    'elevationUnit': 'METERS',
#    'longitude': -67.0525},
#   {'elevation': 719.3,
#    'mindate': '1931-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.0716,
#    'name': 'JAJOME ALTO, US',
#    'datacoverage': 0.9951,
#    'id': 'COOP:664867',
#    'elevationUnit': 'METERS',
#    'longitude': -66.1427},
#   {'elevation': 469.4,
#    'mindate': '1931-01-01',
#    'maxdate': '2002-08-01',
#    'latitude': 18.215,
#    'name': 'JAYUYA, US',
#    'datacoverage': 0.5291,
#    'id': 'COOP:664910',
#    'elevationUnit': 'METERS',
#    'longitude': -66.59306},
#   {'elevation': 530,
#    'mindate': '1960-04-01',
#    'maxdate': '1981-05-01',
#    'latitude': 18.2,
#    'name': 'JAYUYA 1 SE, US',
#    'datacoverage': 0.9213,
#    'id': 'COOP:664911',
#    'elevationUnit': 'METERS',
#    'longitude': -66.58333},
#   {'elevation': 9.1,
#    'mindate': '1931-01-01',
#    'maxdate': '1968-12-01',
#    'latitude': 17.96667,
#    'name': 'JOSEFA, US',
#    'datacoverage': 0.9868,
#    'id': 'COOP:664976',
#    'elevationUnit': 'METERS',
#    'longitude': -66.15},
#   {'elevation': 79.9,
#    'mindate': '1907-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.0513,
#    'name': 'JUANA DIAZ CAMP, US',
#    'datacoverage': 0.8891,
#    'id': 'COOP:665020',
#    'elevationUnit': 'METERS',
#    'longitude': -66.4986},
#   {'elevation': 64.9,
#    'mindate': '1909-03-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.2264,
#    'name': 'JUNCOS 1 SE, US',
#    'datacoverage': 0.9235,
#    'id': 'COOP:665064',
#    'elevationUnit': 'METERS',
#    'longitude': -65.9114},
#   {'elevation': 45.1,
#    'mindate': '1931-01-01',
#    'maxdate': '1969-03-01',
#    'latitude': 18.23333,
#    'name': 'LA FE, US',
#    'datacoverage': 0.9456,
#    'id': 'COOP:665075',
#    'elevationUnit': 'METERS',
#    'longitude': -65.76667},
#   {'elevation': 27.4,
#    'mindate': '1947-04-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.033,
#    'name': 'LAJAS SUBSTATION, US',
#    'datacoverage': 0.9842,
#    'id': 'COOP:665097',
#    'elevationUnit': 'METERS',
#    'longitude': -67.0722},
#   {'elevation': 625.1,
#    'mindate': '1935-01-01',
#    'maxdate': '1944-05-01',
#    'latitude': 18.3,
#    'name': 'LA MINA EL YUNQUE, US',
#    'datacoverage': 0.9913,
#    'id': 'COOP:665120',
#    'elevationUnit': 'METERS',
#    'longitude': -65.78333},
#   {'elevation': 88.4,
#    'mindate': '1971-05-01',
#    'maxdate': '1994-06-01',
#    'latitude': 18.31667,
#    'name': 'LA MUDA CAGUAS, US',
#    'datacoverage': 0.928,
#    'id': 'COOP:665123',
#    'elevationUnit': 'METERS',
#    'longitude': -66.1},
#   {'elevation': 451.1,
#    'mindate': '1931-01-01',
#    'maxdate': '1992-02-01',
#    'latitude': 18.28333,
#    'name': 'LARES, US',
#    'datacoverage': 0.9551,
#    'id': 'COOP:665175',
#    'elevationUnit': 'METERS',
#    'longitude': -66.88333},
#   {'elevation': 82.3,
#    'mindate': '1973-06-01',
#    'maxdate': '2014-01-01',
#    'latitude': 18.1963,
#    'name': 'LAS PIEDRAS 1 N, US',
#    'datacoverage': 0.0427,
#    'id': 'COOP:665258',
#    'elevationUnit': 'METERS',
#    'longitude': -65.865},
#   {'elevation': 9.1,
#    'mindate': '1947-11-01',
#    'maxdate': '1973-08-01',
#    'latitude': 18.43333,
#    'name': 'LOS CANOS, US',
#    'datacoverage': 0.9967,
#    'id': 'COOP:665474',
#    'elevationUnit': 'METERS',
#    'longitude': -66.71667},
#   {'elevation': 3.7,
#    'mindate': '1959-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 17.9722,
#    'name': 'MAGUEYES ISLAND, US',
#    'datacoverage': 0.962,
#    'id': 'COOP:665693',
#    'elevationUnit': 'METERS',
#    'longitude': -67.0461},
#   {'elevation': 76.2,
#    'mindate': '1931-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.43078,
#    'name': 'MANATI 2 E, US',
#    'datacoverage': 0.9127,
#    'id': 'COOP:665807',
#    'elevationUnit': 'METERS',
#    'longitude': -66.46608},
#   {'elevation': 456.9,
#    'mindate': '1931-01-01',
#    'maxdate': '1969-08-01',
#    'latitude': 18.18333,
#    'name': 'MARICAO, US',
#    'datacoverage': 0.9828,
#    'id': 'COOP:665906',
#    'elevationUnit': 'METERS',
#    'longitude': -66.98333},
#   {'elevation': 863.2,
#    'mindate': '1969-05-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.1511,
#    'name': 'MARICAO 2 SSW, US',
#    'datacoverage': 0.9141,
#    'id': 'COOP:665908',
#    'elevationUnit': 'METERS',
#    'longitude': -66.9888},
#   {'elevation': 457.2,
#    'mindate': '1950-04-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.1725,
#    'name': 'MARICAO FISH HATCHERY, US',
#    'datacoverage': 0.9213,
#    'id': 'COOP:665911',
#    'elevationUnit': 'METERS',
#    'longitude': -66.9872},
#   {'elevation': 746.2,
#    'mindate': '1932-03-01',
#    'maxdate': '1981-04-01',
#    'latitude': 18.21667,
#    'name': 'MATRULLAS DAM, US',
#    'datacoverage': 0.9966,
#    'id': 'COOP:666017',
#    'elevationUnit': 'METERS',
#    'longitude': -66.48333},
#   {'elevation': 14.9,
#    'mindate': '1931-01-01',
#    'maxdate': '2003-04-01',
#    'latitude': 18.00944,
#    'name': 'MAUNABO, US',
#    'datacoverage': 0.9379,
#    'id': 'COOP:666050',
#    'elevationUnit': 'METERS',
#    'longitude': -65.89889},
#   {'elevation': 22.6,
#    'mindate': '1931-01-01',
#    'maxdate': '2009-04-01',
#    'latitude': 18.1875,
#    'name': 'MAYAGUEZ CITY, US',
#    'datacoverage': 0.9543,
#    'id': 'COOP:666073',
#    'elevationUnit': 'METERS',
#    'longitude': -67.1377},
#   {'elevation': 11.6,
#    'mindate': '1957-01-01',
#    'maxdate': '2015-08-01',
#    'latitude': 18.2538,
#    'name': 'MAYAGUEZ AIRPORT, US',
#    'datacoverage': 0.9262,
#    'id': 'COOP:666083',
#    'elevationUnit': 'METERS',
#    'longitude': -67.1486},
#   {'elevation': 42.1,
#    'mindate': '1938-08-01',
#    'maxdate': '1969-01-01',
#    'latitude': 17.98333,
#    'name': 'MELANIA DAM, US',
#    'datacoverage': 0.9971,
#    'id': 'COOP:666128',
#    'elevationUnit': 'METERS',
#    'longitude': -66.15},
#   {'elevation': 70.1,
#    'mindate': '1931-01-01',
#    'maxdate': '1952-12-01',
#    'latitude': 18.08333,
#    'name': 'MONA ISLAND LIGHT STATION, US',
#    'datacoverage': 0.9431,
#    'id': 'COOP:666250',
#    'elevationUnit': 'METERS',
#    'longitude': -67.85},
#   {'elevation': 50.9,
#    'mindate': '1953-01-01',
#    'maxdate': '1974-08-01',
#    'latitude': 18.08333,
#    'name': 'MONA ISLAND, US',
#    'datacoverage': 0.9309,
#    'id': 'COOP:666255',
#    'elevationUnit': 'METERS',
#    'longitude': -67.85},
#   {'elevation': 2.1,
#    'mindate': '1980-01-01',
#    'maxdate': '2010-05-01',
#    'latitude': 18.1,
#    'name': 'MONA ISLAND 2, US',
#    'datacoverage': 0.9179,
#    'id': 'COOP:666258',
#    'elevationUnit': 'METERS',
#    'longitude': -67.93333},
#   {'elevation': 195.1,
#    'mindate': '1969-10-01',
#    'maxdate': '2001-09-01',
#    'latitude': 18.37944,
#    'name': 'MONTE BELLO MANATI, US',
#    'datacoverage': 0.9922,
#    'id': 'COOP:666270',
#    'elevationUnit': 'METERS',
#    'longitude': -66.51528},
#   {'elevation': 71.3,
#    'mindate': '2011-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.2973,
#    'name': 'CULEBRA HILL, US',
#    'datacoverage': 0.7291,
#    'id': 'COOP:666343',
#    'elevationUnit': 'METERS',
#    'longitude': -65.2901},
#   {'elevation': 125,
#    'mindate': '1932-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.4736,
#    'name': 'MORA CAMP, US',
#    'datacoverage': 0.9901,
#    'id': 'COOP:666361',
#    'elevationUnit': 'METERS',
#    'longitude': -67.0288},
#   {'elevation': 182.9,
#    'mindate': '1933-10-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.3344,
#    'name': 'MOROVIS 1 N, US',
#    'datacoverage': 0.8124,
#    'id': 'COOP:666390',
#    'elevationUnit': 'METERS',
#    'longitude': -66.4078},
#   {'elevation': 21.3,
#    'mindate': '1972-04-01',
#    'maxdate': '1983-05-01',
#    'latitude': 18.21667,
#    'name': 'NAGUABO 3 E, US',
#    'datacoverage': 1,
#    'id': 'COOP:666427',
#    'elevationUnit': 'METERS',
#    'longitude': -65.68333},
#   {'elevation': 29.9,
#    'mindate': '1942-01-01',
#    'maxdate': '1967-05-01',
#    'latitude': 18.23333,
#    'name': 'NAGUABO 6 W, US',
#    'datacoverage': 0.9936,
#    'id': 'COOP:666432',
#    'elevationUnit': 'METERS',
#    'longitude': -65.73333},
#   {'elevation': 518.2,
#    'mindate': '2007-08-01',
#    'maxdate': '2009-03-01',
#    'latitude': 18.20972,
#    'name': 'NARANJALES, US',
#    'datacoverage': 0.6497,
#    'id': 'COOP:666440',
#    'elevationUnit': 'METERS',
#    'longitude': -66.99556},
#   {'elevation': 538.3,
#    'mindate': '1973-06-01',
#    'maxdate': '2014-01-01',
#    'latitude': 18.2886,
#    'name': 'NEGRO COROZAL, US',
#    'datacoverage': 0.9583,
#    'id': 'COOP:666514',
#    'elevationUnit': 'METERS',
#    'longitude': -66.3433},
#   {'elevation': 466,
#    'mindate': '2011-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.3169,
#    'name': 'PALMA SOLA, US',
#    'datacoverage': 0.9835,
#    'id': 'COOP:666725',
#    'elevationUnit': 'METERS',
#    'longitude': -65.8663},
#   {'elevation': 173.7,
#    'mindate': '2009-06-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.38527,
#    'name': 'PALMAREJO VEGA BAJA, US',
#    'datacoverage': 1,
#    'id': 'COOP:666730',
#    'elevationUnit': 'METERS',
#    'longitude': -66.4301},
#   {'elevation': 472.1,
#    'mindate': '1963-03-01',
#    'maxdate': '1975-04-01',
#    'latitude': 18.28333,
#    'name': 'PALMARITO, US',
#    'datacoverage': 0.9452,
#    'id': 'COOP:666740',
#    'elevationUnit': 'METERS',
#    'longitude': -66.35},
#   {'elevation': 109.7,
#    'mindate': '1931-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.265,
#    'name': 'PARAISO, US',
#    'datacoverage': 0.9686,
#    'id': 'COOP:666805',
#    'elevationUnit': 'METERS',
#    'longitude': -65.7208},
#   {'elevation': 13.7,
#    'mindate': '1982-04-01',
#    'maxdate': '2003-06-01',
#    'latitude': 18.0025,
#    'name': 'PATILLAS, US',
#    'datacoverage': 0.855,
#    'id': 'COOP:666900',
#    'elevationUnit': 'METERS',
#    'longitude': -66.01278},
#   {'elevation': 73.2,
#    'mindate': '1911-05-01',
#    'maxdate': '1969-01-01',
#    'latitude': 18.03333,
#    'name': 'PATILLAS DAM, US',
#    'datacoverage': 0.9984,
#    'id': 'COOP:666904',
#    'elevationUnit': 'METERS',
#    'longitude': -66.03333},
#   {'elevation': 100.6,
#    'mindate': '1973-05-01',
#    'maxdate': '2014-01-01',
#    'latitude': 18.22,
#    'name': 'PENA POBRE NAGUABO, US',
#    'datacoverage': 0.0407,
#    'id': 'COOP:666942',
#    'elevationUnit': 'METERS',
#    'longitude': -65.8258},
#   {'elevation': 349.9,
#    'mindate': '1940-10-01',
#    'maxdate': '1970-12-01',
#    'latitude': 18.08333,
#    'name': 'PENUELAS SALTO GARZA, US',
#    'datacoverage': 0.876,
#    'id': 'COOP:666982',
#    'elevationUnit': 'METERS',
#    'longitude': -66.73333},
#   {'elevation': 143.3,
#    'mindate': '1971-01-01',
#    'maxdate': '2014-12-01',
#    'latitude': 18.0585,
#    'name': 'PENUELAS 1 E, US',
#    'datacoverage': 0.8636,
#    'id': 'COOP:666983',
#    'elevationUnit': 'METERS',
#    'longitude': -66.7184},
#   {'elevation': 1051,
#    'mindate': '1969-09-01',
#    'maxdate': '2006-05-31',
#    'latitude': 18.27083,
#    'name': 'PICO DEL ESTE, US',
#    'datacoverage': 0.9885,
#    'id': 'COOP:666992',
#    'elevationUnit': 'METERS',
#    'longitude': -65.75917},
#   {'elevation': 21.3,
#    'mindate': '1900-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.0258,
#    'name': 'PONCE 4 E, US',
#    'datacoverage': 0.9317,
#    'id': 'COOP:667292',
#    'elevationUnit': 'METERS',
#    'longitude': -66.5252},
#   {'elevation': 3,
#    'mindate': '1970-05-01',
#    'maxdate': '1998-08-01',
#    'latitude': 17.985,
#    'name': 'PONCE CITY, US',
#    'datacoverage': 0.9117,
#    'id': 'COOP:667295',
#    'elevationUnit': 'METERS',
#    'longitude': -66.62944},
#   {'elevation': 21,
#    'mindate': '1957-01-01',
#    'maxdate': '1968-12-01',
#    'latitude': 18.01667,
#    'name': 'PONCE MERCEDITA, US',
#    'datacoverage': 1,
#    'id': 'COOP:667297',
#    'elevationUnit': 'METERS',
#    'longitude': -66.56667},
#   {'elevation': 14.9,
#    'mindate': '1931-01-01',
#    'maxdate': '1969-02-01',
#    'latitude': 18.01667,
#    'name': 'POTALA, US',
#    'datacoverage': 0.9957,
#    'id': 'COOP:667348',
#    'elevationUnit': 'METERS',
#    'longitude': -66.51667},
#   {'elevation': 10.1,
#    'mindate': '1936-01-01',
#    'maxdate': '2001-08-01',
#    'latitude': 18.07889,
#    'name': 'PUERTO REAL, US',
#    'datacoverage': 0.9594,
#    'id': 'COOP:667492',
#    'elevationUnit': 'METERS',
#    'longitude': -67.17694},
#   {'elevation': 113.4,
#    'mindate': '1931-01-01',
#    'maxdate': '2000-09-01',
#    'latitude': 18.47194,
#    'name': 'QUEBRADILLAS, US',
#    'datacoverage': 0.9857,
#    'id': 'COOP:667843',
#    'elevationUnit': 'METERS',
#    'longitude': -66.93583},
#   {'elevation': 72.2,
#    'mindate': '1940-01-01',
#    'maxdate': '1973-07-01',
#    'latitude': 18.494861,
#    'name': 'BORINQUEN AIRPORT, US',
#    'datacoverage': 0.9901,
#    'id': 'COOP:667898',
#    'elevationUnit': 'METERS',
#    'longitude': -67.129444},
#   {'elevation': 91.1,
#    'mindate': '1958-01-01',
#    'maxdate': '1968-05-01',
#    'latitude': 18.36667,
#    'name': 'RINCON 2 NNW, US',
#    'datacoverage': 0.9762,
#    'id': 'COOP:668122',
#    'elevationUnit': 'METERS',
#    'longitude': -67.25},
#   {'elevation': 3,
#    'mindate': '1968-06-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.3375,
#    'name': 'RINCON, US',
#    'datacoverage': 0.7474,
#    'id': 'COOP:668126',
#    'elevationUnit': 'METERS',
#    'longitude': -67.2497},
#   {'elevation': 34.1,
#    'mindate': '1932-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.24273,
#    'name': 'RIO BLANCO LOWER, US',
#    'datacoverage': 0.9434,
#    'id': 'COOP:668144',
#    'elevationUnit': 'METERS',
#    'longitude': -65.78497},
#   {'elevation': 438.9,
#    'mindate': '1931-01-01',
#    'maxdate': '1974-03-01',
#    'latitude': 18.28333,
#    'name': 'RIO BLANCO UPPER, US',
#    'datacoverage': 0.9654,
#    'id': 'COOP:668155',
#    'elevationUnit': 'METERS',
#    'longitude': -65.78333},
#   {'elevation': 57,
#    'mindate': '1944-08-01',
#    'maxdate': '1969-12-01',
#    'latitude': 18.03333,
#    'name': 'RIO CANAS, US',
#    'datacoverage': 0.9999,
#    'id': 'COOP:668178',
#    'elevationUnit': 'METERS',
#    'longitude': -66.46667},
#   {'elevation': 182.9,
#    'mindate': '1956-03-01',
#    'maxdate': '1987-12-01',
#    'latitude': 18.33333,
#    'name': 'RIO GRANDE EL VERDE, US',
#    'datacoverage': 0.8638,
#    'id': 'COOP:668245',
#    'elevationUnit': 'METERS',
#    'longitude': -65.81667},
#   {'elevation': 42.1,
#    'mindate': '1944-08-01',
#    'maxdate': '1969-01-01',
#    'latitude': 18.01667,
#    'name': 'RIO JUEYES, US',
#    'datacoverage': 0.9964,
#    'id': 'COOP:668278',
#    'elevationUnit': 'METERS',
#    'longitude': -66.35},
#   {'elevation': 29.9,
#    'mindate': '1911-01-01',
#    'maxdate': '1961-12-01',
#    'latitude': 18.4,
#    'name': 'RIO PIEDRAS, US',
#    'datacoverage': 0.9967,
#    'id': 'COOP:668301',
#    'elevationUnit': 'METERS',
#    'longitude': -66.06667},
#   {'elevation': 28,
#    'mindate': '1959-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.3905,
#    'name': 'RIO PIEDRAS EXPERIMENTAL STATION, US',
#    'datacoverage': 0.9254,
#    'id': 'COOP:668306',
#    'elevationUnit': 'METERS',
#    'longitude': -66.0541},
#   {'elevation': 10.1,
#    'mindate': '1942-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.2552,
#    'name': 'ROOSEVELT ROADS, US',
#    'datacoverage': 0.637,
#    'id': 'COOP:668412',
#    'elevationUnit': 'METERS',
#    'longitude': -65.6411},
#   {'elevation': 200.9,
#    'mindate': '1931-01-01',
#    'maxdate': '1976-08-01',
#    'latitude': 18.08333,
#    'name': 'SABANA GRANDE 2 ENE, US',
#    'datacoverage': 0.7482,
#    'id': 'COOP:668535',
#    'elevationUnit': 'METERS',
#    'longitude': -66.93333},
#   {'elevation': 259.1,
#    'mindate': '1977-02-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.0888,
#    'name': 'SABANA GRANDE 2 ENE, US',
#    'datacoverage': 0.9315,
#    'id': 'COOP:668536',
#    'elevationUnit': 'METERS',
#    'longitude': -66.93},
#   {'elevation': 21,
#    'mindate': '1931-01-01',
#    'maxdate': '1969-01-01',
#    'latitude': 17.98333,
#    'name': 'SABATER, US',
#    'datacoverage': 0.9912,
#    'id': 'COOP:668623',
#    'elevationUnit': 'METERS',
#    'longitude': -66.23333},
#   {'elevation': 29.9,
#    'mindate': '1943-01-01',
#    'maxdate': '1966-12-01',
#    'latitude': 18.38333,
#    'name': 'ST JUST, US',
#    'datacoverage': 0.9861,
#    'id': 'COOP:668634',
#    'elevationUnit': 'METERS',
#    'longitude': -66},
#   {'elevation': 868.7,
#    'mindate': '1981-05-01',
#    'maxdate': '1991-12-01',
#    'latitude': 18.13333,
#    'name': 'SALTILLO 2 ADJUNTAS, US',
#    'datacoverage': 0.9997,
#    'id': 'COOP:668684',
#    'elevationUnit': 'METERS',
#    'longitude': -66.73333},
#   {'elevation': 21.3,
#    'mindate': '1931-01-01',
#    'maxdate': '1972-03-01',
#    'latitude': 18.21667,
#    'name': 'NAGUABO 3 E, US',
#    'datacoverage': 0.9556,
#    'id': 'COOP:668745',
#    'elevationUnit': 'METERS',
#    'longitude': -65.68333},
#   {'elevation': 27.1,
#    'mindate': '1931-01-01',
#    'maxdate': '1973-08-01',
#    'latitude': 18.08333,
#    'name': 'SAN GERMAN 4 W, US',
#    'datacoverage': 0.9354,
#    'id': 'COOP:668757',
#    'elevationUnit': 'METERS',
#    'longitude': -67.1},
#   {'elevation': 6.1,
#    'mindate': '1900-01-01',
#    'maxdate': '1977-05-01',
#    'latitude': 18.46667,
#    'name': 'SAN JUAN CITY, US',
#    'datacoverage': 0.9753,
#    'id': 'COOP:668808',
#    'elevationUnit': 'METERS',
#    'longitude': -66.1},
#   {'elevation': 3,
#    'mindate': '1955-06-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.43261,
#    'name': 'SAN JUAN L M MARIN INTERNATIONAL AIRPORT, US',
#    'datacoverage': 1,
#    'id': 'COOP:668812',
#    'elevationUnit': 'METERS',
#    'longitude': -66.01065},
#   {'elevation': 3,
#    'mindate': '2006-11-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.4312,
#    'name': 'WEATHER FORECAST OFFICE SAN JUAN, US',
#    'datacoverage': 0.991,
#    'id': 'COOP:668814',
#    'elevationUnit': 'METERS',
#    'longitude': -65.9917},
#   {'elevation': 113.4,
#    'mindate': '1966-04-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.18416,
#    'name': 'SAN LORENZO 1 SW, US',
#    'datacoverage': 0.9698,
#    'id': 'COOP:668815',
#    'elevationUnit': 'METERS',
#    'longitude': -65.96862},
#   {'elevation': 140.2,
#    'mindate': '1973-05-01',
#    'maxdate': '2014-01-01',
#    'latitude': 18.185,
#    'name': 'SAN LORENZO 2 ESE, US',
#    'datacoverage': 0.0427,
#    'id': 'COOP:668816',
#    'elevationUnit': 'METERS',
#    'longitude': -65.9294},
#   {'elevation': 387.1,
#    'mindate': '1931-01-01',
#    'maxdate': '1959-06-01',
#    'latitude': 18.1,
#    'name': 'SAN LORENZO ESPINO, US',
#    'datacoverage': 0.9241,
#    'id': 'COOP:668817',
#    'elevationUnit': 'METERS',
#    'longitude': -66},
#   {'elevation': 73.2,
#    'mindate': '1931-01-01',
#    'maxdate': '1988-09-01',
#    'latitude': 18.2,
#    'name': 'SAN LORENZO FARM 2 N, US',
#    'datacoverage': 0.7605,
#    'id': 'COOP:668822',
#    'elevationUnit': 'METERS',
#    'longitude': -65.96667},
#   {'elevation': 59.1,
#    'mindate': '1931-01-01',
#    'maxdate': '2014-01-01',
#    'latitude': 18.3483,
#    'name': 'SAN SEBASTIAN 2 WNW, US',
#    'datacoverage': 0.9314,
#    'id': 'COOP:668881',
#    'elevationUnit': 'METERS',
#    'longitude': -67.0077},
#   {'elevation': 9.1,
#    'mindate': '1931-01-01',
#    'maxdate': '2010-07-01',
#    'latitude': 17.96917,
#    'name': 'SANTA ISABEL, US',
#    'datacoverage': 0.9623,
#    'id': 'COOP:668940',
#    'elevationUnit': 'METERS',
#    'longitude': -66.37722},
#   {'elevation': 22.9,
#    'mindate': '1931-01-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.0097,
#    'name': 'SANTA RITA, US',
#    'datacoverage': 0.9745,
#    'id': 'COOP:668955',
#    'elevationUnit': 'METERS',
#    'longitude': -66.8847},
#   {'elevation': 137.2,
#    'mindate': '2004-11-01',
#    'maxdate': '2006-09-01',
#    'latitude': 18.35778,
#    'name': 'SIESTA ALEGRE, US',
#    'datacoverage': 0.7838,
#    'id': 'COOP:669116',
#    'elevationUnit': 'METERS',
#    'longitude': -65.82833},
#   {'elevation': 8.5,
#    'mindate': '2004-12-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.4356,
#    'name': 'TOA BAJA LEVITTOWN, US',
#    'datacoverage': 0.932,
#    'id': 'COOP:669415',
#    'elevationUnit': 'METERS',
#    'longitude': -66.1678},
#   {'elevation': 7.9,
#    'mindate': '1931-01-01',
#    'maxdate': '1994-08-01',
#    'latitude': 18.43333,
#    'name': 'TOA BAJA 1 SSW, US',
#    'datacoverage': 0.9751,
#    'id': 'COOP:669421',
#    'elevationUnit': 'METERS',
#    'longitude': -66.26667},
#   {'elevation': 868.1,
#    'mindate': '1982-08-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.1731,
#    'name': 'TORO NEGRO FOREST, US',
#    'datacoverage': 0.9125,
#    'id': 'COOP:669432',
#    'elevationUnit': 'METERS',
#    'longitude': -66.4928},
#   {'elevation': 685.8,
#    'mindate': '1931-01-01',
#    'maxdate': '1981-07-01',
#    'latitude': 18.16667,
#    'name': 'TORO NEGRO PLANT 2, US',
#    'datacoverage': 1,
#    'id': 'COOP:669466',
#    'elevationUnit': 'METERS',
#    'longitude': -66.51667},
#   {'elevation': 35.1,
#    'mindate': '1957-03-01',
#    'maxdate': '2015-11-01',
#    'latitude': 18.3283,
#    'name': 'TRUJILLO ALTO 2 SSW, US',
#    'datacoverage': 0.8369,
#    'id': 'COOP:669521',
#    'elevationUnit': 'METERS',
#    'longitude': -66.0163},
#   {'elevation': 158.5,
#    'mindate': '1900-01-01',
#    'maxdate': '1998-07-01',
#    'latitude': 18.26167,
#    'name': 'UTUADO, US',
#    'datacoverage': 0.7431,
#    'id': 'COOP:669608',
#    'elevationUnit': 'METERS',
#    'longitude': -66.68639},
#   {'elevation': 15.2,
#    'mindate': '1931-01-01',
#    'maxdate': '1976-09-01',
#    'latitude': 18.11667,
#    'name': 'VIEQUES ISLAND, US',
#    'datacoverage': 0.867,
#    'id': 'COOP:669763',
#    'elevationUnit': 'METERS',
#    'longitude': -65.41667},
#   {'elevation': 6.7,
#    'mindate': '1983-03-01',
#    'maxdate': '1994-01-01',
#    'latitude': 18.13333,
#    'name': 'VIEQUES ISLAND NUMBER 2, US',
#    'datacoverage': 0.9307,
#    'id': 'COOP:669766',
#    'elevationUnit': 'METERS',
#    'longitude': -65.43333},
#   {'elevation': 120.4,
#    'mindate': '1938-01-01',
#    'maxdate': '2015-05-01',
#    'latitude': 18.1094,
#    'name': 'VILLALBA 1 SE, US',
#    'datacoverage': 0.9419,
#    'id': 'COOP:669774',
#    'elevationUnit': 'METERS',
#    'longitude': -66.5055},
#   {'elevation': 10.7,
#    'mindate': '1931-01-01',
#    'maxdate': '2010-02-01',
#    'latitude': 18.03853,
#    'name': 'YABUCOA 3 SE, US',
#    'datacoverage': 0.9819,
#    'id': 'COOP:669829',
#    'elevationUnit': 'METERS',
#    'longitude': -65.83943},
#   {'elevation': 53.9,
#    'mindate': '1981-11-01',
#    'maxdate': '2010-11-01',
#    'latitude': 18.04361,
#    'name': 'YAUCO 1 NW, US',
#    'datacoverage': 0.9972,
#    'id': 'COOP:669860',
#    'elevationUnit': 'METERS',
#    'longitude': -66.86056},
#   {'elevation': 9.1,
#    'mindate': '1931-01-01',
#    'maxdate': '1969-06-01',
#    'latitude': 18.01667,
#    'name': 'YAUCO 1 S, US',
#    'datacoverage': 0.9849,
#    'id': 'COOP:669862',
#    'elevationUnit': 'METERS',
#    'longitude': -66.85},
#   {'elevation': 39,
#    'mindate': '1944-08-01',
#    'maxdate': '1969-03-01',
#    'latitude': 17.98333,
#    'name': 'YAUREL 3 NNE, US',
#    'datacoverage': 0.9967,
#    'id': 'COOP:669884',
#    'elevationUnit': 'METERS',
#    'longitude': -66.06667},
#   {'elevation': 268.2,
#    'mindate': '2020-01-01',
#    'maxdate': '2020-05-10',
#    'latitude': 18.2607597,
#    'name': 'AGUAS BUENAS 2.4 W, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQ1PRAB0001',
#    'elevationUnit': 'METERS',
#    'longitude': -66.1415523},
#   {'elevation': 29.6,
#    'mindate': '2014-09-01',
#    'maxdate': '2024-04-09',
#    'latitude': 18.441404,
#    'name': 'ARECIBO 5.2 ESE, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQ1PRAC0001',
#    'elevationUnit': 'METERS',
#    'longitude': -66.658861},
#   {'elevation': 152.1,
#    'mindate': '2015-03-01',
#    'maxdate': '2017-07-03',
#    'latitude': 18.4070695460463,
#    'name': 'CUCHI 0.3 ENE, US',
#    'datacoverage': 0.998,
#    'id': 'GHCND:RQ1PRAC0002',
#    'elevationUnit': 'METERS',
#    'longitude': -66.7602735757828},
#   {'mindate': '2019-12-26',
#    'maxdate': '2024-03-26',
#    'latitude': 18.368547,
#    'name': 'SABANA HOYOS, US',
#    'datacoverage': 0.3979,
#    'id': 'GHCND:RQ1PRAC0003',
#    'longitude': -66.532581},
#   {'elevation': 71.3,
#    'mindate': '2014-06-01',
#    'maxdate': '2016-09-07',
#    'latitude': 18.4774111078362,
#    'name': 'AGUADILLA 2.7 NNE, US',
#    'datacoverage': 0.8098,
#    'id': 'GHCND:RQ1PRAL0002',
#    'elevationUnit': 'METERS',
#    'longitude': -67.1437382698059},
#   {'elevation': 39.9,
#    'mindate': '1998-10-17',
#    'maxdate': '2024-04-08',
#    'latitude': 18.50834,
#    'name': 'AGUADILLA 5.5 NNE, US',
#    'datacoverage': 0.9991,
#    'id': 'GHCND:RQ1PRAL0003',
#    'elevationUnit': 'METERS',
#    'longitude': -67.11241},
#   {'elevation': 125.3,
#    'mindate': '2020-03-29',
#    'maxdate': '2020-09-28',
#    'latitude': 18.446805,
#    'name': 'AGUADILLA 0.6 NE, US',
#    'datacoverage': 0.6956,
#    'id': 'GHCND:RQ1PRAL0005',
#    'elevationUnit': 'METERS',
#    'longitude': -67.148808},
#   {'elevation': 11.6,
#    'mindate': '2014-06-01',
#    'maxdate': '2015-11-20',
#    'latitude': 18.28153,
#    'name': 'ANASCO 0.5 SSW, US',
#    'datacoverage': 0.9998,
#    'id': 'GHCND:RQ1PRAN0002',
#    'elevationUnit': 'METERS',
#    'longitude': -67.14307},
#   {'elevation': 117.7,
#    'mindate': '2021-02-20',
#    'maxdate': '2024-04-08',
#    'latitude': 18.314833,
#    'name': 'FINCA LA LOMA, US',
#    'datacoverage': 0.6844,
#    'id': 'GHCND:RQ1PRBY0001',
#    'elevationUnit': 'METERS',
#    'longitude': -66.155872},
#   {'elevation': 76.2,
#    'mindate': '2020-08-09',
#    'maxdate': '2024-04-08',
#    'latitude': 18.328599,
#    'name': 'BAYAMON 3.9 SSE, US',
#    'datacoverage': 0.2853,
#    'id': 'GHCND:RQ1PRBY0002',
#    'elevationUnit': 'METERS',
#    'longitude': -66.144077},
#   {'elevation': 90.5,
#    'mindate': '2014-06-01',
#    'maxdate': '2018-12-20',
#    'latitude': 18.2272777,
#    'name': 'CAGUAS 1.1 WSW, US',
#    'datacoverage': 0.9375,
#    'id': 'GHCND:RQ1PRCG0001',
#    'elevationUnit': 'METERS',
#    'longitude': -66.0543106},
#   {'elevation': 96.9,
#    'mindate': '2014-01-01',
#    'maxdate': '2017-09-18',
#    'latitude': 18.222332,
#    'name': 'CAGUAS 1.4 SW, US',
#    'datacoverage': 0.9992,
#    'id': 'GHCND:RQ1PRCG0002',
#    'elevationUnit': 'METERS',
#    'longitude': -66.056716},
#   {'elevation': 119.8,
#    'mindate': '2018-12-21',
#    'maxdate': '2023-06-29',
#    'latitude': 18.26473,
#    'name': 'CAGUAS 2.2 NNW, US',
#    'datacoverage': 0.3493,
#    'id': 'GHCND:RQ1PRCG0003',
#    'elevationUnit': 'METERS',
#    'longitude': -66.050128},
#   {'elevation': 48.8,
#    'mindate': '2014-05-01',
#    'maxdate': '2016-03-18',
#    'latitude': 18.3871233882721,
#    'name': 'CAROLINA 1.5 SSW, US',
#    'datacoverage': 0.9118,
#    'id': 'GHCND:RQ1PRCL0001',
#    'elevationUnit': 'METERS',
#    'longitude': -65.9975928068161},
#   {'elevation': 2.7,
#    'mindate': '2023-05-19',
#    'maxdate': '2024-04-09',
#    'latitude': 18.431143,
#    'name': 'CAROLINA 1.7 NNW, US',
#    'datacoverage': 0.998,
#    'id': 'GHCND:RQ1PRCL0006',
#    'elevationUnit': 'METERS',
#    'longitude': -65.991773},
#   {'elevation': 27.4,
#    'mindate': '2014-06-01',
#    'maxdate': '2024-01-23',
#    'latitude': 18.08128,
#    'name': 'CABO ROJO 0.8 SE, US',
#    'datacoverage': 0.9994,
#    'id': 'GHCND:RQ1PRCR0001',
#    'elevationUnit': 'METERS',
#    'longitude': -67.13942},
#   {'elevation': 13.1,
#    'mindate': '2023-03-23',
#    'maxdate': '2024-04-09',
#    'latitude': 18.095,
#    'name': 'CABO ROJO 1.1 ENE, US',
#    'datacoverage': 0.6771,
#    'id': 'GHCND:RQ1PRCR0004',
#    'elevationUnit': 'METERS',
#    'longitude': -67.134},
#   {'elevation': 71.9,
#    'mindate': '2014-09-01',
#    'maxdate': '2020-09-07',
#    'latitude': 18.33797,
#    'name': 'CIALES 0.1 N, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQ1PRCS0001',
#    'elevationUnit': 'METERS',
#    'longitude': -66.470593},
#   {'elevation': 381.3,
#    'mindate': '2015-03-01',
#    'maxdate': '2016-07-18',
#    'latitude': 18.1332649431587,
#    'name': 'CAYEY 1.6 NE, US',
#    'datacoverage': 0.9967,
#    'id': 'GHCND:RQ1PRCY0001',
#    'elevationUnit': 'METERS',
#    'longitude': -66.1451996515279},
#   {'elevation': 42.1,
#    'mindate': '2016-02-11',
#    'maxdate': '2017-09-29',
#    'latitude': 18.339358,
#    'name': 'FAJARDO 0.4 NE, US',
#    'datacoverage': 0.938,
#    'id': 'GHCND:RQ1PRFJ0002',
#    'elevationUnit': 'METERS',
#    'longitude': -65.654947},
#   {'elevation': 24.7,
#    'mindate': '2020-01-01',
#    'maxdate': '2020-07-12',
#    'latitude': 18.309147,
#    'name': 'FAJARDO 1.9 SSW, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQ1PRFJ0004',
#    'elevationUnit': 'METERS',
#    'longitude': -65.67018},
#   {'elevation': 23.8,
#    'mindate': '2022-04-01',
#    'maxdate': '2024-04-09',
#    'latitude': 18.318836,
#    'name': 'FAJARDO 1.1 S, US',
#    'datacoverage': 0.9716,
#    'id': 'GHCND:RQ1PRFJ0005',
#    'elevationUnit': 'METERS',
#    'longitude': -65.6606},
#   {'elevation': 24.7,
#    'mindate': '2022-09-27',
#    'maxdate': '2024-04-09',
#    'latitude': 18.309012,
#    'name': 'FAJARDO 1.9 SSW, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQ1PRFJ0006',
#    'elevationUnit': 'METERS',
#    'longitude': -65.670212},
#   {'elevation': 243.8,
#    'mindate': '2014-06-01',
#    'maxdate': '2017-09-03',
#    'latitude': 18.292129,
#    'name': 'LA MARQUESA 6.5 S, US',
#    'datacoverage': 0.9819,
#    'id': 'GHCND:RQ1PRGB0002',
#    'elevationUnit': 'METERS',
#    'longitude': -66.116326},
#   {'elevation': 78.6,
#    'mindate': '2014-08-01',
#    'maxdate': '2015-08-06',
#    'latitude': 18.304175,
#    'name': 'GUARAGUAO 5.8 S, US',
#    'datacoverage': 0.6918,
#    'id': 'GHCND:RQ1PRGB0003',
#    'elevationUnit': 'METERS',
#    'longitude': -66.131306},
#   {'mindate': '2020-04-20',
#    'maxdate': '2020-12-17',
#    'latitude': 18.317317,
#    'name': 'BAYAMON 4.4 S, US',
#    'datacoverage': 0.6736,
#    'id': 'GHCND:RQ1PRGB0005',
#    'longitude': -66.15821},
#   {'elevation': 52.4,
#    'mindate': '2023-03-16',
#    'maxdate': '2024-04-09',
#    'latitude': 17.974,
#    'name': 'GUANICA 0.9 WNW, US',
#    'datacoverage': 0.376,
#    'id': 'GHCND:RQ1PRGC0002',
#    'elevationUnit': 'METERS',
#    'longitude': -66.944},
#   {'elevation': 47.2,
#    'mindate': '2018-04-17',
#    'maxdate': '2024-04-09',
#    'latitude': 17.979951,
#    'name': 'GUAYAMA 1.1 W, US',
#    'datacoverage': 0.901,
#    'id': 'GHCND:RQ1PRGM0002',
#    'elevationUnit': 'METERS',
#    'longitude': -66.12771},
#   {'elevation': 27.7,
#    'mindate': '2023-05-01',
#    'maxdate': '2023-12-14',
#    'latitude': 17.9764366,
#    'name': 'GUAYAMA 0.8 E, US',
#    'datacoverage': 0.8534,
#    'id': 'GHCND:RQ1PRGM0003',
#    'elevationUnit': 'METERS',
#    'longitude': -66.0995473},
#   {'elevation': 19.5,
#    'mindate': '2014-06-01',
#    'maxdate': '2015-10-04',
#    'latitude': 18.145606,
#    'name': 'HUMACAO 0.9 SE, US',
#    'datacoverage': 0.9989,
#    'id': 'GHCND:RQ1PRHM0001',
#    'elevationUnit': 'METERS',
#    'longitude': -65.809274},
#   {'mindate': '2020-01-30',
#    'maxdate': '2024-04-09',
#    'latitude': 18.1514701843262,
#    'name': 'FINCA APONTE, US',
#    'datacoverage': 0.2565,
#    'id': 'GHCND:RQ1PRHM0002',
#    'longitude': -65.823371887207},
#   {'elevation': 33.8,
#    'mindate': '2014-06-01',
#    'maxdate': '2020-09-24',
#    'latitude': 18.480992,
#    'name': 'HATILLO 1.1 ESE, US',
#    'datacoverage': 0.9819,
#    'id': 'GHCND:RQ1PRHT0001',
#    'elevationUnit': 'METERS',
#    'longitude': -66.808037},
#   {'elevation': 14.9,
#    'mindate': '2014-09-01',
#    'maxdate': '2022-03-24',
#    'latitude': 18.486701,
#    'name': 'HATILLO 0.2 ESE, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQ1PRHT0003',
#    'elevationUnit': 'METERS',
#    'longitude': -66.821059},
#   {'elevation': 129.8,
#    'mindate': '2014-06-01',
#    'maxdate': '2015-01-14',
#    'latitude': 18.465419,
#    'name': 'ISABELA 2.9 SSW, US',
#    'datacoverage': 0.9939,
#    'id': 'GHCND:RQ1PRIS0001',
#    'elevationUnit': 'METERS',
#    'longitude': -67.033602},
#   {'elevation': 69.5,
#    'mindate': '2017-07-15',
#    'maxdate': '2022-11-15',
#    'latitude': 18.496202,
#    'name': 'ISABELA 0.6 S, US',
# ...
#    'name': 'PARAISO, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00666805',
#    'elevationUnit': 'METERS',
#    'longitude': -65.7208},
#   {'elevation': 13.7,
#    'mindate': '1982-04-01',
#    'maxdate': '2010-12-31',
#    'latitude': 18.0025,
#    'name': 'PATILLAS, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00666900',
#    'elevationUnit': 'METERS',
#    'longitude': -66.01278},
#   {'elevation': 73.2,
#    'mindate': '1931-01-01',
#    'maxdate': '1969-01-31',
#    'latitude': 18.03333,
#    'name': 'PATILLAS DAM, US',
#    'datacoverage': 0.9912,
#    'id': 'GHCND:RQC00666904',
#    'elevationUnit': 'METERS',
#    'longitude': -66.03333},
#   {'elevation': 349.9,
#    'mindate': '1955-01-01',
#    'maxdate': '1971-02-28',
#    'latitude': 18.08333,
#    'name': 'PENUELAS SALTO GARZA, US',
#    'datacoverage': 0.8095,
#    'id': 'GHCND:RQC00666982',
#    'elevationUnit': 'METERS',
#    'longitude': -66.73333},
#   {'elevation': 143.3,
#    'mindate': '1971-01-01',
#    'maxdate': '2015-07-31',
#    'latitude': 18.0585,
#    'name': 'PENUELAS 1 E, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00666983',
#    'elevationUnit': 'METERS',
#    'longitude': -66.7184},
#   {'elevation': 1051,
#    'mindate': '1969-10-01',
#    'maxdate': '2010-12-31',
#    'latitude': 18.27083,
#    'name': 'PICO DEL ESTE, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00666992',
#    'elevationUnit': 'METERS',
#    'longitude': -65.75917},
#   {'elevation': 21.3,
#    'mindate': '1898-10-03',
#    'maxdate': '2024-04-09',
#    'latitude': 18.0258,
#    'name': 'PONCE 4 E, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00667292',
#    'elevationUnit': 'METERS',
#    'longitude': -66.5252},
#   {'elevation': 3,
#    'mindate': '1970-01-01',
#    'maxdate': '2010-12-31',
#    'latitude': 17.985,
#    'name': 'PONCE CITY, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00667295',
#    'elevationUnit': 'METERS',
#    'longitude': -66.62944},
#   {'elevation': 21,
#    'mindate': '1957-01-01',
#    'maxdate': '1968-11-30',
#    'latitude': 18.01667,
#    'name': 'PONCE MERCEDITA, US',
#    'datacoverage': 0.9722,
#    'id': 'GHCND:RQC00667297',
#    'elevationUnit': 'METERS',
#    'longitude': -66.56667},
#   {'elevation': 14.9,
#    'mindate': '1955-01-01',
#    'maxdate': '1969-02-28',
#    'latitude': 18.01667,
#    'name': 'POTALA, US',
#    'datacoverage': 0.9826,
#    'id': 'GHCND:RQC00667348',
#    'elevationUnit': 'METERS',
#    'longitude': -66.51667},
#   {'elevation': 10.1,
#    'mindate': '1955-01-01',
#    'maxdate': '2001-08-31',
#    'latitude': 18.07889,
#    'name': 'PUERTO REAL, US',
#    'datacoverage': 0.9268,
#    'id': 'GHCND:RQC00667492',
#    'elevationUnit': 'METERS',
#    'longitude': -67.17694},
#   {'elevation': 113.4,
#    'mindate': '1955-01-01',
#    'maxdate': '2000-09-30',
#    'latitude': 18.47194,
#    'name': 'QUEBRADILLAS, US',
#    'datacoverage': 0.9745,
#    'id': 'GHCND:RQC00667843',
#    'elevationUnit': 'METERS',
#    'longitude': -66.93583},
#   {'elevation': 91.1,
#    'mindate': '1957-11-01',
#    'maxdate': '1968-05-31',
#    'latitude': 18.36667,
#    'name': 'RINCON 2 NNW, US',
#    'datacoverage': 0.9056,
#    'id': 'GHCND:RQC00668122',
#    'elevationUnit': 'METERS',
#    'longitude': -67.25},
#   {'elevation': 3,
#    'mindate': '1968-01-01',
#    'maxdate': '2024-03-26',
#    'latitude': 18.3375,
#    'name': 'RINCON, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00668126',
#    'elevationUnit': 'METERS',
#    'longitude': -67.2497},
#   {'elevation': 34.1,
#    'mindate': '1955-01-01',
#    'maxdate': '2024-04-09',
#    'latitude': 18.24273,
#    'name': 'RIO BLANCO LOWER, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00668144',
#    'elevationUnit': 'METERS',
#    'longitude': -65.78497},
#   {'elevation': 438.9,
#    'mindate': '1955-01-01',
#    'maxdate': '1974-03-31',
#    'latitude': 18.28333,
#    'name': 'RIO BLANCO UPPER, US',
#    'datacoverage': 0.7707,
#    'id': 'GHCND:RQC00668155',
#    'elevationUnit': 'METERS',
#    'longitude': -65.78333},
#   {'elevation': 57,
#    'mindate': '1955-01-01',
#    'maxdate': '1969-12-31',
#    'latitude': 18.03333,
#    'name': 'RIO CANAS, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00668178',
#    'elevationUnit': 'METERS',
#    'longitude': -66.46667},
#   {'elevation': 182.9,
#    'mindate': '1956-02-01',
#    'maxdate': '1987-12-31',
#    'latitude': 18.33333,
#    'name': 'RIO GRANDE EL VERDE, US',
#    'datacoverage': 0.8277,
#    'id': 'GHCND:RQC00668245',
#    'elevationUnit': 'METERS',
#    'longitude': -65.81667},
#   {'elevation': 42.1,
#    'mindate': '1955-01-01',
#    'maxdate': '1969-01-31',
#    'latitude': 18.01667,
#    'name': 'RIO JUEYES, US',
#    'datacoverage': 0.9998,
#    'id': 'GHCND:RQC00668278',
#    'elevationUnit': 'METERS',
#    'longitude': -66.35},
#   {'elevation': 29.9,
#    'mindate': '1931-01-01',
#    'maxdate': '1961-12-31',
#    'latitude': 18.4,
#    'name': 'RIO PIEDRAS, US',
#    'datacoverage': 0.9543,
#    'id': 'GHCND:RQC00668301',
#    'elevationUnit': 'METERS',
#    'longitude': -66.06667},
#   {'elevation': 28,
#    'mindate': '1959-01-01',
#    'maxdate': '2020-02-26',
#    'latitude': 18.3905,
#    'name': 'RIO PIEDRAS EXPERIMENTAL STATION, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00668306',
#    'elevationUnit': 'METERS',
#    'longitude': -66.0541},
#   {'elevation': 200.9,
#    'mindate': '1955-11-01',
#    'maxdate': '1977-04-30',
#    'latitude': 18.08333,
#    'name': 'SABANA GRANDE 2 ENE, US',
#    'datacoverage': 0.8326,
#    'id': 'GHCND:RQC00668535',
#    'elevationUnit': 'METERS',
#    'longitude': -66.93333},
#   {'elevation': 259.1,
#    'mindate': '1907-09-01',
#    'maxdate': '2024-03-31',
#    'latitude': 18.0888,
#    'name': 'SABANA GRANDE 2 ENE, US',
#    'datacoverage': 0.452,
#    'id': 'GHCND:RQC00668536',
#    'elevationUnit': 'METERS',
#    'longitude': -66.93},
#   {'elevation': 21,
#    'mindate': '1955-01-01',
#    'maxdate': '1969-01-31',
#    'latitude': 17.98333,
#    'name': 'SABATER, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00668623',
#    'elevationUnit': 'METERS',
#    'longitude': -66.23333},
#   {'elevation': 29.9,
#    'mindate': '1955-01-01',
#    'maxdate': '1966-12-31',
#    'latitude': 18.38333,
#    'name': 'ST JUST, US',
#    'datacoverage': 0.9653,
#    'id': 'GHCND:RQC00668634',
#    'elevationUnit': 'METERS',
#    'longitude': -66},
#   {'elevation': 868.7,
#    'mindate': '1981-05-01',
#    'maxdate': '1991-12-31',
#    'latitude': 18.13333,
#    'name': 'SALTILLO 2 ADJUNTAS, US',
#    'datacoverage': 0.9997,
#    'id': 'GHCND:RQC00668684',
#    'elevationUnit': 'METERS',
#    'longitude': -66.73333},
#   {'elevation': 21.3,
#    'mindate': '1956-01-01',
#    'maxdate': '1972-03-31',
#    'latitude': 18.21667,
#    'name': 'NAGUABO 3 E, US',
#    'datacoverage': 0.9489,
#    'id': 'GHCND:RQC00668745',
#    'elevationUnit': 'METERS',
#    'longitude': -65.68333},
#   {'elevation': 27.1,
#    'mindate': '1904-11-01',
#    'maxdate': '1973-07-31',
#    'latitude': 18.08333,
#    'name': 'SAN GERMAN 4 W, US',
#    'datacoverage': 0.8158,
#    'id': 'GHCND:RQC00668757',
#    'elevationUnit': 'METERS',
#    'longitude': -67.1},
#   {'elevation': 3,
#    'mindate': '2006-11-01',
#    'maxdate': '2024-04-08',
#    'latitude': 18.4312,
#    'name': 'WEATHER FORECAST OFFICE SAN JUAN, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00668814',
#    'elevationUnit': 'METERS',
#    'longitude': -65.9917},
#   {'elevation': 113.4,
#    'mindate': '1966-01-01',
#    'maxdate': '2024-04-05',
#    'latitude': 18.18416,
#    'name': 'SAN LORENZO 1 SW, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00668815',
#    'elevationUnit': 'METERS',
#    'longitude': -65.96862},
#   {'elevation': 387.1,
#    'mindate': '1945-01-01',
#    'maxdate': '1959-06-30',
#    'latitude': 18.1,
#    'name': 'SAN LORENZO ESPINO, US',
#    'datacoverage': 0.8279,
#    'id': 'GHCND:RQC00668817',
#    'elevationUnit': 'METERS',
#    'longitude': -66},
#   {'elevation': 73.2,
#    'mindate': '1955-01-01',
#    'maxdate': '1988-09-30',
#    'latitude': 18.2,
#    'name': 'SAN LORENZO FARM 2 N, US',
#    'datacoverage': 0.8565,
#    'id': 'GHCND:RQC00668822',
#    'elevationUnit': 'METERS',
#    'longitude': -65.96667},
#   {'elevation': 59.1,
#    'mindate': '1955-04-01',
#    'maxdate': '2010-12-31',
#    'latitude': 18.3483,
#    'name': 'SAN SEBASTIAN 2 WNW, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00668881',
#    'elevationUnit': 'METERS',
#    'longitude': -67.0077},
#   {'elevation': 9.1,
#    'mindate': '1955-01-01',
#    'maxdate': '2012-07-31',
#    'latitude': 17.96917,
#    'name': 'SANTA ISABEL, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00668940',
#    'elevationUnit': 'METERS',
#    'longitude': -66.37722},
#   {'elevation': 22.9,
#    'mindate': '1955-01-01',
#    'maxdate': '2017-05-31',
#    'latitude': 18.0097,
#    'name': 'SANTA RITA, US',
#    'datacoverage': 0.9279,
#    'id': 'GHCND:RQC00668955',
#    'elevationUnit': 'METERS',
#    'longitude': -66.8847},
#   {'elevation': 137.2,
#    'mindate': '2004-11-01',
#    'maxdate': '2006-09-30',
#    'latitude': 18.35778,
#    'name': 'SIESTA ALEGRE, US',
#    'datacoverage': 0.7838,
#    'id': 'GHCND:RQC00669116',
#    'elevationUnit': 'METERS',
#    'longitude': -65.82833},
#   {'elevation': 8.5,
#    'mindate': '2004-12-01',
#    'maxdate': '2024-04-08',
#    'latitude': 18.4356,
#    'name': 'TOA BAJA LEVITTOWN, US',
#    'datacoverage': 0.9494,
#    'id': 'GHCND:RQC00669415',
#    'elevationUnit': 'METERS',
#    'longitude': -66.1678},
#   {'elevation': 7.9,
#    'mindate': '1955-01-01',
#    'maxdate': '2010-12-31',
#    'latitude': 18.43333,
#    'name': 'TOA BAJA 1 SSW, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00669421',
#    'elevationUnit': 'METERS',
#    'longitude': -66.26667},
#   {'elevation': 868.1,
#    'mindate': '1982-08-01',
#    'maxdate': '2024-02-28',
#    'latitude': 18.1731,
#    'name': 'TORO NEGRO FOREST, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00669432',
#    'elevationUnit': 'METERS',
#    'longitude': -66.4928},
#   {'elevation': 685.8,
#    'mindate': '1955-01-01',
#    'maxdate': '1981-07-31',
#    'latitude': 18.16667,
#    'name': 'TORO NEGRO PLANT 2, US',
#    'datacoverage': 0.9993,
#    'id': 'GHCND:RQC00669466',
#    'elevationUnit': 'METERS',
#    'longitude': -66.51667},
#   {'elevation': 35.1,
#    'mindate': '1957-02-01',
#    'maxdate': '2024-04-09',
#    'latitude': 18.3283,
#    'name': 'TRUJILLO ALTO 2 SSW, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00669521',
#    'elevationUnit': 'METERS',
#    'longitude': -66.0163},
#   {'elevation': 158.5,
#    'mindate': '1931-01-01',
#    'maxdate': '2010-12-31',
#    'latitude': 18.26167,
#    'name': 'UTUADO, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00669608',
#    'elevationUnit': 'METERS',
#    'longitude': -66.68639},
#   {'elevation': 15.2,
#    'mindate': '1955-01-01',
#    'maxdate': '1976-09-30',
#    'latitude': 18.11667,
#    'name': 'VIEQUES ISLAND, US',
#    'datacoverage': 0.9541,
#    'id': 'GHCND:RQC00669763',
#    'elevationUnit': 'METERS',
#    'longitude': -65.41667},
#   {'elevation': 6.7,
#    'mindate': '1983-03-01',
#    'maxdate': '1994-01-31',
#    'latitude': 18.13333,
#    'name': 'VIEQUES ISLAND NUMBER 2, US',
#    'datacoverage': 0.9383,
#    'id': 'GHCND:RQC00669766',
#    'elevationUnit': 'METERS',
#    'longitude': -65.43333},
#   {'elevation': 120.4,
#    'mindate': '1955-01-01',
#    'maxdate': '2015-05-31',
#    'latitude': 18.1094,
#    'name': 'VILLALBA 1 SE, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00669774',
#    'elevationUnit': 'METERS',
#    'longitude': -66.5055},
#   {'elevation': 10.7,
#    'mindate': '1955-01-01',
#    'maxdate': '1995-03-31',
#    'latitude': 18.03853,
#    'name': 'YABUCOA 3 SE, US',
#    'datacoverage': 0.8572,
#    'id': 'GHCND:RQC00669829',
#    'elevationUnit': 'METERS',
#    'longitude': -65.83943},
#   {'elevation': 53.9,
#    'mindate': '1981-12-01',
#    'maxdate': '2010-12-31',
#    'latitude': 18.04361,
#    'name': 'YAUCO 1 NW, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQC00669860',
#    'elevationUnit': 'METERS',
#    'longitude': -66.86056},
#   {'elevation': 9.1,
#    'mindate': '1955-01-01',
#    'maxdate': '1969-06-30',
#    'latitude': 18.01667,
#    'name': 'YAUCO 1 S, US',
#    'datacoverage': 0.7243,
#    'id': 'GHCND:RQC00669862',
#    'elevationUnit': 'METERS',
#    'longitude': -66.85},
#   {'elevation': 39,
#    'mindate': '1955-01-01',
#    'maxdate': '1969-03-31',
#    'latitude': 17.98333,
#    'name': 'YAUREL 3 NNE, US',
#    'datacoverage': 0.7194,
#    'id': 'GHCND:RQC00669884',
#    'elevationUnit': 'METERS',
#    'longitude': -66.06667},
#   {'elevation': 72.2,
#    'mindate': '1942-01-01',
#    'maxdate': '2014-09-23',
#    'latitude': 18.494861,
#    'name': 'BORINQUEN AIRPORT, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQW00011603',
#    'elevationUnit': 'METERS',
#    'longitude': -67.129444},
#   {'elevation': 13.1,
#    'mindate': '1945-01-01',
#    'maxdate': '1962-04-30',
#    'latitude': 18.46667,
#    'name': 'SAN JUAN NS, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQW00011618',
#    'elevationUnit': 'METERS',
#    'longitude': -66.11667},
#   {'elevation': 10.1,
#    'mindate': '1942-10-01',
#    'maxdate': '2024-04-08',
#    'latitude': 18.2552,
#    'name': 'ROOSEVELT ROADS, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQW00011630',
#    'elevationUnit': 'METERS',
#    'longitude': -65.6411},
#   {'elevation': 6.1,
#    'mindate': '1916-05-01',
#    'maxdate': '1977-05-31',
#    'latitude': 18.46667,
#    'name': 'SAN JUAN CITY, US',
#    'datacoverage': 0.5675,
#    'id': 'GHCND:RQW00011631',
#    'elevationUnit': 'METERS',
#    'longitude': -66.1},
#   {'elevation': 9.1,
#    'mindate': '1951-01-01',
#    'maxdate': '1954-03-31',
#    'latitude': 17.96667,
#    'name': 'PONCE SANTA ISABEL, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQW00011637',
#    'elevationUnit': 'METERS',
#    'longitude': -66.4},
#   {'elevation': 3,
#    'mindate': '1941-06-17',
#    'maxdate': '2024-04-08',
#    'latitude': 18.43261,
#    'name': 'SAN JUAN L M MARIN INTERNATIONAL AIRPORT, US',
#    'datacoverage': 1,
#    'id': 'GHCND:RQW00011641',
#    'elevationUnit': 'METERS',
#    'longitude': -66.01065},
#   {'elevation': 85.3,
#    'mindate': '2017-11-01',
#    'maxdate': '2018-06-25',
#    'latitude': 18.485,
#    'name': 'RAFAEL HERNANDEZ AIRPORT, US',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD:TJBQ',
#    'elevationUnit': 'METERS',
#    'longitude': -67.143},
#   {'elevation': 15.2,
#    'mindate': '2017-11-01',
#    'maxdate': '2018-06-26',
#    'latitude': 18.256,
#    'name': 'JOSE APONTE DE LA TORRE AIRPORT, US',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD:TJRV',
#    'elevationUnit': 'METERS',
#    'longitude': -65.637},
#   {'elevation': 901.7,
#    'mindate': '1997-06-27',
#    'maxdate': '2024-04-10',
#    'latitude': 18.115667,
#    'name': 'SAN JUAN, US',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD:TJUA',
#    'elevationUnit': 'METERS',
#    'longitude': -66.078167},
#   {'elevation': 47.9,
#    'mindate': '2009-02-26',
#    'maxdate': '2024-04-10',
#    'latitude': 18.473889,
#    'name': 'SAN JUAN',
#    'datacoverage': 0.95,
#    'id': 'NEXRAD:TSJU',
#    'elevationUnit': 'METERS',
#    'longitude': -66.178889},
#   {'elevation': 9.1,
#    'mindate': '2005-01-01',
#    'maxdate': '2024-04-10',
#    'latitude': 18,
#    'name': 'MERCEDITA AIRPORT, US',
#    'datacoverage': 0.54,
#    'id': 'WBAN:00398',
#    'elevationUnit': 'METERS',
#    'longitude': -66.55},
#   {'elevation': 3,
#    'mindate': '2011-02-23',
#    'maxdate': '2024-04-09',
#    'latitude': 18.45677,
#    'name': 'FERNANDO LUIS RIBAS DOMINICCI AIRPORT, US',
#    'datacoverage': 0.51,
#    'id': 'WBAN:00494',
#    'elevationUnit': 'METERS',
#    'longitude': -66.09847},
#   {'elevation': 72.2,
#    'mindate': '2006-01-01',
#    'maxdate': '2024-04-10',
#    'latitude': 18.494861,
#    'name': 'BORINQUEN AIRPORT, US',
#    'datacoverage': 0.73,
#    'id': 'WBAN:11603',
#    'elevationUnit': 'METERS',
#    'longitude': -67.129444},
#   {'elevation': 10.1,
#    'mindate': '1947-07-01',
#    'maxdate': '2024-04-10',
#    'latitude': 18.2552,
#    'name': 'ROOSEVELT ROADS, US',
#    'datacoverage': 0.94,
#    'id': 'WBAN:11630',
#    'elevationUnit': 'METERS',
#    'longitude': -65.6411},
#   {'elevation': 3,
#    'mindate': '1955-05-24',
#    'maxdate': '2024-04-10',
#    'latitude': 18.43261,
#    'name': 'SAN JUAN L M MARIN INTERNATIONAL AIRPORT, US',
#    'datacoverage': 0.96,
#    'id': 'WBAN:11641',
#    'elevationUnit': 'METERS',
#    'longitude': -66.01065},
#   {'elevation': 11.6,
#    'mindate': '2005-01-01',
#    'maxdate': '2017-08-10',
#    'latitude': 18.2538,
#    'name': 'MAYAGUEZ AIRPORT, US',
#    'datacoverage': 0.22,
#    'id': 'WBAN:11653',
#    'elevationUnit': 'METERS',
#    'longitude': -67.1486}]}

# %%
all_results = []  # List to store all results

while True:
    data = api_call(url, endpoint, headers, parameters)
    if data is not None and 'results' in data:
        all_results.extend(data['results'])  # Append results from current call
        
        # Check if more results are available
        if parameters['offset'] + parameters['limit'] - 1 < data['metadata']['resultset']['count']:
            parameters['offset'] += parameters['limit']
        else:
            break
    else:
        # Handle error or no data case
        print("No data returned or an error occurred")
        break

# At this point, `all_results` contains all the stations fetched from the API
# Out:
# Error: 503
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8652\446333328.py in <cell line: 4>()
#       3 while True:
#       4     data = api_call(url, endpoint, headers, parameters)
# ----> 5     if data is not None and 'results' in data:
#       6         all_results.extend(data['results'])  # Append results from current call
#       7
#
# TypeError: argument of type 'int' is not iterable

# %%
all_results
# Out:
# [{'elevation': 276.5,
#   'mindate': '1916-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.2991,
#   'name': 'ADA, MN US',
#   'datacoverage': 0.9497,
#   'id': 'COOP:210018',
#   'elevationUnit': 'METERS',
#   'longitude': -96.5161},
#  {'elevation': 348.1,
#   'mindate': '1961-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 48.3005,
#   'name': 'AGASSIZ REFUGE, MN US',
#   'datacoverage': 0.9295,
#   'id': 'COOP:210050',
#   'elevationUnit': 'METERS',
#   'longitude': -95.9816},
#  {'elevation': 370.3,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.5257,
#   'name': 'AITKIN 2 E, MN US',
#   'datacoverage': 0.8973,
#   'id': 'COOP:210059',
#   'elevationUnit': 'METERS',
#   'longitude': -93.6674},
#  {'elevation': 374.9,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.6064,
#   'name': 'ALBERT LEA 3 SE, MN US',
#   'datacoverage': 0.9922,
#   'id': 'COOP:210075',
#   'elevationUnit': 'METERS',
#   'longitude': -93.3019},
#  {'elevation': 374.9,
#   'mindate': '1948-08-01',
#   'maxdate': '2003-09-01',
#   'latitude': 43.66667,
#   'name': 'ALBERT LEA 3 E, MN US',
#   'datacoverage': 0.7145,
#   'id': 'COOP:210080',
#   'elevationUnit': 'METERS',
#   'longitude': -93.3},
#  {'elevation': 402.9,
#   'mindate': '1948-08-01',
#   'maxdate': '1952-12-01',
#   'latitude': 46.96667,
#   'name': 'ALBORN, MN US',
#   'datacoverage': 0.5469,
#   'id': 'COOP:210096',
#   'elevationUnit': 'METERS',
#   'longitude': -92.58333},
#  {'elevation': 431.3,
#   'mindate': '1931-01-01',
#   'maxdate': '1947-12-01',
#   'latitude': 45.87833,
#   'name': 'ALEXANDRIA, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:210110',
#   'elevationUnit': 'METERS',
#   'longitude': -95.38287},
#  {'elevation': 432.8,
#   'mindate': '1940-05-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.86801,
#   'name': 'ALEXANDRIA CHANDLER FIELD, MN US',
#   'datacoverage': 0.9493,
#   'id': 'COOP:210112',
#   'elevationUnit': 'METERS',
#   'longitude': -95.39399},
#  {'elevation': 426.7,
#   'mindate': '1971-09-01',
#   'maxdate': '2014-01-01',
#   'latitude': 45.8966,
#   'name': 'ALEXANDRIA WATER TREATMENT PLANT, MN US',
#   'datacoverage': 0.0259,
#   'id': 'COOP:210116',
#   'elevationUnit': 'METERS',
#   'longitude': -95.3657},
#  {'elevation': 454.2,
#   'mindate': '1948-08-01',
#   'maxdate': '1952-10-01',
#   'latitude': 47.53333,
#   'name': 'ALLEN JUNCTION, MN US',
#   'datacoverage': 0.49,
#   'id': 'COOP:210128',
#   'elevationUnit': 'METERS',
#   'longitude': -92.11667},
#  {'elevation': 263.7,
#   'mindate': '2003-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.0634,
#   'name': 'ALTURA 5 W, MN US',
#   'datacoverage': 0.9932,
#   'id': 'COOP:210146',
#   'elevationUnit': 'METERS',
#   'longitude': -92.0398},
#  {'elevation': 313.9,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.8835,
#   'name': 'AMBOY, MN US',
#   'datacoverage': 0.3824,
#   'id': 'COOP:210157',
#   'elevationUnit': 'METERS',
#   'longitude': -94.1665},
#  {'elevation': 274,
#   'mindate': '2007-06-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.2534,
#   'name': 'ANDOVER 1 N, MN US',
#   'datacoverage': 0.9901,
#   'id': 'COOP:210190',
#   'elevationUnit': 'METERS',
#   'longitude': -93.2927},
#  {'elevation': 264.9,
#   'mindate': '1931-01-01',
#   'maxdate': '1975-12-01',
#   'latitude': 48.1,
#   'name': 'ANGUS 1 N, MN US',
#   'datacoverage': 0.9611,
#   'id': 'COOP:210195',
#   'elevationUnit': 'METERS',
#   'longitude': -96.7},
#  {'elevation': 258.2,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 48.3311,
#   'name': 'ARGYLE, MN US',
#   'datacoverage': 0.9686,
#   'id': 'COOP:210252',
#   'elevationUnit': 'METERS',
#   'longitude': -96.8252},
#  {'elevation': 334.7,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.38564,
#   'name': 'ARTICHOKE LAKE 1 E, MN US',
#   'datacoverage': 0.9922,
#   'id': 'COOP:210287',
#   'elevationUnit': 'METERS',
#   'longitude': -96.12578},
#  {'elevation': 365.5,
#   'mindate': '1937-04-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.6542,
#   'name': 'AUSTIN WASTE WATER TREATMENT FACILITY, MN US',
#   'datacoverage': 0.9757,
#   'id': 'COOP:210355',
#   'elevationUnit': 'METERS',
#   'longitude': -92.9739},
#  {'elevation': 451.4,
#   'mindate': '1999-06-01',
#   'maxdate': '2014-12-01',
#   'latitude': 47.7121,
#   'name': 'BABBITT, MN US',
#   'datacoverage': 0.9784,
#   'id': 'COOP:210387',
#   'elevationUnit': 'METERS',
#   'longitude': -91.9533},
#  {'elevation': 492.3,
#   'mindate': '1931-01-01',
#   'maxdate': '1986-07-01',
#   'latitude': 47.68333,
#   'name': 'BABBITT 2 SE, MN US',
#   'datacoverage': 0.9671,
#   'id': 'COOP:210390',
#   'elevationUnit': 'METERS',
#   'longitude': -91.91667},
#  {'elevation': 333.5,
#   'mindate': '1931-01-01',
#   'maxdate': '2009-12-01',
#   'latitude': 48.7095,
#   'name': 'BAUDETTE, MN US',
#   'datacoverage': 0.9451,
#   'id': 'COOP:210515',
#   'elevationUnit': 'METERS',
#   'longitude': -94.5853},
#  {'elevation': 359.7,
#   'mindate': '1963-09-01',
#   'maxdate': '1990-02-01',
#   'latitude': 48.41667,
#   'name': 'BAUDETTE 21 SSE, MN US',
#   'datacoverage': 0.89,
#   'id': 'COOP:210520',
#   'elevationUnit': 'METERS',
#   'longitude': -94.56667},
#  {'elevation': 331.9,
#   'mindate': '1931-01-01',
#   'maxdate': '1973-06-01',
#   'latitude': 45.55,
#   'name': 'BEARDSLEY, MN US',
#   'datacoverage': 0.9805,
#   'id': 'COOP:210541',
#   'elevationUnit': 'METERS',
#   'longitude': -96.71667},
#  {'elevation': 220.1,
#   'mindate': '1948-08-01',
#   'maxdate': '1989-09-01',
#   'latitude': 44.15,
#   'name': 'BEAVER, MN US',
#   'datacoverage': 0.9373,
#   'id': 'COOP:210559',
#   'elevationUnit': 'METERS',
#   'longitude': -92.01667},
#  {'elevation': 192,
#   'mindate': '2005-03-01',
#   'maxdate': '2014-12-01',
#   'latitude': 47.20028,
#   'name': 'BEAVER BAY 5 SW, MN US',
#   'datacoverage': 0.9742,
#   'id': 'COOP:210564',
#   'elevationUnit': 'METERS',
#   'longitude': -91.36722},
#  {'elevation': 414.5,
#   'mindate': '1896-02-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.5353,
#   'name': 'BEMIDJI, MN US',
#   'datacoverage': 0.788,
#   'id': 'COOP:210643',
#   'elevationUnit': 'METERS',
#   'longitude': -94.8268},
#  {'elevation': 313.9,
#   'mindate': '1952-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.3167,
#   'name': 'BENSON, MN US',
#   'datacoverage': 0.9895,
#   'id': 'COOP:210667',
#   'elevationUnit': 'METERS',
#   'longitude': -95.6166},
#  {'elevation': 371.9,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 48.1969,
#   'name': 'BIG FALLS, MN US',
#   'datacoverage': 0.9568,
#   'id': 'COOP:210746',
#   'elevationUnit': 'METERS',
#   'longitude': -93.7994},
#  {'elevation': 430.1,
#   'mindate': '1948-08-01',
#   'maxdate': '1981-07-01',
#   'latitude': 47.7,
#   'name': 'BIGFORK 5 ESE, MN US',
#   'datacoverage': 0.564,
#   'id': 'COOP:210754',
#   'elevationUnit': 'METERS',
#   'longitude': -93.55},
#  {'elevation': 331.9,
#   'mindate': '1931-01-01',
#   'maxdate': '1976-06-01',
#   'latitude': 44.76667,
#   'name': 'BIRD ISLAND, MN US',
#   'datacoverage': 0.9854,
#   'id': 'COOP:210783',
#   'elevationUnit': 'METERS',
#   'longitude': -94.9},
#  {'elevation': 427,
#   'mindate': '1948-08-01',
#   'maxdate': '1953-07-01',
#   'latitude': 47.71667,
#   'name': 'BLACKDDCK RANGER STATION, MN US',
#   'datacoverage': 0.9835,
#   'id': 'COOP:210803',
#   'elevationUnit': 'METERS',
#   'longitude': -94.56667},
#  {'elevation': 408.4,
#   'mindate': '1989-11-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.6713,
#   'name': 'BLACKDUCK, MN US',
#   'datacoverage': 0.8116,
#   'id': 'COOP:210809',
#   'elevationUnit': 'METERS',
#   'longitude': -94.5175},
#  {'elevation': 328.9,
#   'mindate': '1948-08-01',
#   'maxdate': '1985-12-01',
#   'latitude': 45.86667,
#   'name': 'BLANCHARD POWER STATION, MN US',
#   'datacoverage': 0.9732,
#   'id': 'COOP:210826',
#   'elevationUnit': 'METERS',
#   'longitude': -94.35},
#  {'elevation': 324.6,
#   'mindate': '1948-08-01',
#   'maxdate': '2009-08-01',
#   'latitude': 43.6453,
#   'name': 'BLUE EARTH, MN US',
#   'datacoverage': 0.9687,
#   'id': 'COOP:210852',
#   'elevationUnit': 'METERS',
#   'longitude': -94.0937},
#  {'elevation': 335.3,
#   'mindate': '2009-10-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.6237,
#   'name': 'BLUE EARTH 1 S, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:210855',
#   'elevationUnit': 'METERS',
#   'longitude': -94.0947},
#  {'elevation': 371.9,
#   'mindate': '1931-01-01',
#   'maxdate': '1955-04-01',
#   'latitude': 46.36667,
#   'name': 'BRAINERD, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:210934',
#   'elevationUnit': 'METERS',
#   'longitude': -94.18333},
#  {'elevation': 359.7,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.3433,
#   'name': 'BRAINERD, MN US',
#   'datacoverage': 0.9864,
#   'id': 'COOP:210939',
#   'elevationUnit': 'METERS',
#   'longitude': -94.2086},
#  {'elevation': 292.6,
#   'mindate': '2000-01-01',
#   'maxdate': '2011-09-01',
#   'latitude': 46.268,
#   'name': 'BRECKENRIDGE, MN US',
#   'datacoverage': 0.8712,
#   'id': 'COOP:210973',
#   'elevationUnit': 'METERS',
#   'longitude': -96.5913},
#  {'elevation': 296,
#   'mindate': '2011-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.3047,
#   'name': 'BRECKENRIDGE 3 E, MN US',
#   'datacoverage': 0.9835,
#   'id': 'COOP:210974',
#   'elevationUnit': 'METERS',
#   'longitude': -96.5216},
#  {'elevation': 356.6,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.544,
#   'name': 'BRICELYN, MN US',
#   'datacoverage': 0.8849,
#   'id': 'COOP:210981',
#   'elevationUnit': 'METERS',
#   'longitude': -93.8423},
#  {'elevation': 452.9,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.2472,
#   'name': 'BRIMSON 2 S, MN US',
#   'datacoverage': 0.9493,
#   'id': 'COOP:210989',
#   'elevationUnit': 'METERS',
#   'longitude': -91.8624},
#  {'elevation': 298.1,
#   'mindate': '1973-12-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.59595,
#   'name': 'BROWNS VALLEY, MN US',
#   'datacoverage': 0.998,
#   'id': 'COOP:211063',
#   'elevationUnit': 'METERS',
#   'longitude': -96.82841},
#  {'elevation': 317,
#   'mindate': '2003-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.7335,
#   'name': 'BROWNTON WWTP, MN US',
#   'datacoverage': 0.9933,
#   'id': 'COOP:211065',
#   'elevationUnit': 'METERS',
#   'longitude': -94.3418},
#  {'elevation': 381.9,
#   'mindate': '1990-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.3004,
#   'name': 'BRUNO 7 ENE, MN US',
#   'datacoverage': 0.9968,
#   'id': 'COOP:211074',
#   'elevationUnit': 'METERS',
#   'longitude': -92.5337},
#  {'elevation': 302.4,
#   'mindate': '1948-08-01',
#   'maxdate': '2013-06-01',
#   'latitude': 45.1969,
#   'name': 'BUFFALO, MN US',
#   'datacoverage': 0.8538,
#   'id': 'COOP:211107',
#   'elevationUnit': 'METERS',
#   'longitude': -93.8399},
#  {'elevation': 317.3,
#   'mindate': '1993-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.0909,
#   'name': 'BYRON 4NORTH, MN US',
#   'datacoverage': 0.9926,
#   'id': 'COOP:211174',
#   'elevationUnit': 'METERS',
#   'longitude': -92.64},
#  {'elevation': 355.4,
#   'mindate': '1947-05-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.6309,
#   'name': 'CALEDONIA, MN US',
#   'datacoverage': 0.9732,
#   'id': 'COOP:211198',
#   'elevationUnit': 'METERS',
#   'longitude': -91.5027},
#  {'elevation': 294.1,
#   'mindate': '1932-03-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.55646,
#   'name': 'CAMBRIDGE, MN US',
#   'datacoverage': 0.9323,
#   'id': 'COOP:211227',
#   'elevationUnit': 'METERS',
#   'longitude': -93.23484},
#  {'elevation': 296.3,
#   'mindate': '1931-01-01',
#   'maxdate': '2006-01-01',
#   'latitude': 46.09583,
#   'name': 'CAMPBELL, MN US',
#   'datacoverage': 0.8968,
#   'id': 'COOP:211245',
#   'elevationUnit': 'METERS',
#   'longitude': -96.40917},
#  {'elevation': 392.9,
#   'mindate': '2001-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 48.61,
#   'name': 'CAMP NORRIS DNR, MN US',
#   'datacoverage': 0.9824,
#   'id': 'COOP:211250',
#   'elevationUnit': 'METERS',
#   'longitude': -95.1816},
#  {'elevation': 368.8,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.7184,
#   'name': 'CANBY, MN US',
#   'datacoverage': 0.9578,
#   'id': 'COOP:211263',
#   'elevationUnit': 'METERS',
#   'longitude': -96.2696},
#  {'elevation': 288,
#   'mindate': '2010-05-01',
#   'maxdate': '2013-12-01',
#   'latitude': 44.48278,
#   'name': 'CANNON FALLS 2 SW, MN US',
#   'datacoverage': 0.9987,
#   'id': 'COOP:211278',
#   'elevationUnit': 'METERS',
#   'longitude': -92.91333},
#  {'elevation': 310.9,
#   'mindate': '1948-08-01',
#   'maxdate': '2002-02-01',
#   'latitude': 48.95111,
#   'name': 'CARIBOU 2 S, MN US',
#   'datacoverage': 0.9659,
#   'id': 'COOP:211303',
#   'elevationUnit': 'METERS',
#   'longitude': -96.46389},
#  {'elevation': 426.7,
#   'mindate': '2008-05-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.9652,
#   'name': 'CARLOS 2 WSW, MN US',
#   'datacoverage': 0.9999,
#   'id': 'COOP:211310',
#   'elevationUnit': 'METERS',
#   'longitude': -95.3386},
#  {'elevation': 395,
#   'mindate': '1907-02-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.3847,
#   'name': 'CASS LAKE, MN US',
#   'datacoverage': 0.9855,
#   'id': 'COOP:211374',
#   'elevationUnit': 'METERS',
#   'longitude': -94.6147},
#  {'elevation': 276.5,
#   'mindate': '1962-11-01',
#   'maxdate': '2005-11-01',
#   'latitude': 45.32222,
#   'name': 'CEDAR, MN US',
#   'datacoverage': 0.971,
#   'id': 'COOP:211390',
#   'elevationUnit': 'METERS',
#   'longitude': -93.28444},
#  {'elevation': 391.7,
#   'mindate': '2014-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.8663,
#   'name': 'CELINA 2 E, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:211422',
#   'elevationUnit': 'METERS',
#   'longitude': -93.0266},
#  {'mindate': '1949-03-01',
#   'maxdate': '1951-08-01',
#   'latitude': 48.7,
#   'name': 'CENTRAL, MN US',
#   'datacoverage': 0.3853,
#   'id': 'COOP:211426',
#   'longitude': -94.35},
#  {'elevation': 288.3,
#   'mindate': '1996-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.8496,
#   'name': 'CHANHASSEN WSFO, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:211448',
#   'elevationUnit': 'METERS',
#   'longitude': -93.5644},
#  {'elevation': 219.5,
#   'mindate': '1931-01-01',
#   'maxdate': '2004-07-01',
#   'latitude': 44.8,
#   'name': 'CHASKA, MN US',
#   'datacoverage': 0.9287,
#   'id': 'COOP:211465',
#   'elevationUnit': 'METERS',
#   'longitude': -93.5833},
#  {'elevation': 281.3,
#   'mindate': '2005-02-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.813,
#   'name': 'CHASKA 2 NW, MN US',
#   'datacoverage': 0.9928,
#   'id': 'COOP:211468',
#   'elevationUnit': 'METERS',
#   'longitude': -93.6312},
#  {'elevation': 326.7,
#   'mindate': '1951-08-01',
#   'maxdate': '1998-05-30',
#   'latitude': 48.68333,
#   'name': 'CLEMENTSON, MN US',
#   'datacoverage': 0.998,
#   'id': 'COOP:211589',
#   'elevationUnit': 'METERS',
#   'longitude': -94.43333},
#  {'elevation': 385.6,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.70539,
#   'name': 'CLOQUET, MN US',
#   'datacoverage': 0.9951,
#   'id': 'COOP:211630',
#   'elevationUnit': 'METERS',
#   'longitude': -92.52391},
#  {'elevation': 325.8,
#   'mindate': '1948-08-01',
#   'maxdate': '2002-08-01',
#   'latitude': 45.05,
#   'name': 'COKATO, MN US',
#   'datacoverage': 0.9569,
#   'id': 'COOP:211669',
#   'elevationUnit': 'METERS',
#   'longitude': -94.25},
#  {'elevation': 402.9,
#   'mindate': '1934-07-01',
#   'maxdate': '1954-07-01',
#   'latitude': 47.26667,
#   'name': 'COLERAINE, MN US',
#   'datacoverage': 0.9086,
#   'id': 'COOP:211675',
#   'elevationUnit': 'METERS',
#   'longitude': -93.46667},
#  {'elevation': 368.8,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.5794,
#   'name': 'COLLEGEVILLE ST. JOHN S, MN US',
#   'datacoverage': 0.95,
#   'id': 'COOP:211691',
#   'elevationUnit': 'METERS',
#   'longitude': -94.392},
#  {'elevation': 331.9,
#   'mindate': '1948-08-01',
#   'maxdate': '1972-08-01',
#   'latitude': 44.11667,
#   'name': 'COMFREY 4 E, MN US',
#   'datacoverage': 0.9723,
#   'id': 'COOP:211718',
#   'elevationUnit': 'METERS',
#   'longitude': -94.81667},
#  {'elevation': 413,
#   'mindate': '1999-07-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.8948,
#   'name': 'COOK 8 NE, MN US',
#   'datacoverage': 0.9846,
#   'id': 'COOP:211771',
#   'elevationUnit': 'METERS',
#   'longitude': -92.5337},
#  {'elevation': 413,
#   'mindate': '1997-11-01',
#   'maxdate': '1999-06-01',
#   'latitude': 47.8948,
#   'name': 'COOK 8 NE, MN US',
#   'datacoverage': 0.8023,
#   'id': 'COOP:211773',
#   'elevationUnit': 'METERS',
#   'longitude': -92.5337},
#  {'elevation': 400.8,
#   'mindate': '1959-09-01',
#   'maxdate': '1995-09-01',
#   'latitude': 47.86667,
#   'name': 'COOK 18 W, MN US',
#   'datacoverage': 0.9446,
#   'id': 'COOP:211776',
#   'elevationUnit': 'METERS',
#   'longitude': -93.06667},
#  {'elevation': 299,
#   'mindate': '1948-08-01',
#   'maxdate': '1981-06-01',
#   'latitude': 45.23333,
#   'name': 'CORRELL, MN US',
#   'datacoverage': 0.8928,
#   'id': 'COOP:211812',
#   'elevationUnit': 'METERS',
#   'longitude': -96.16667},
#  {'elevation': 403.3,
#   'mindate': '1962-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.1687,
#   'name': 'COTTON, MN US',
#   'datacoverage': 0.7262,
#   'id': 'COOP:211840',
#   'elevationUnit': 'METERS',
#   'longitude': -92.4629},
#  {'elevation': 342,
#   'mindate': '1948-08-01',
#   'maxdate': '1978-06-01',
#   'latitude': 48.26667,
#   'name': 'CRANE LAKE RANGER ST, MN US',
#   'datacoverage': 0.6212,
#   'id': 'COOP:211857',
#   'elevationUnit': 'METERS',
#   'longitude': -92.46667},
#  {'elevation': 271.6,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.8186,
#   'name': 'CROOKSTON NW EXPERIMENTAL STATION, MN US',
#   'datacoverage': 0.9912,
#   'id': 'COOP:211891',
#   'elevationUnit': 'METERS',
#   'longitude': -96.6139},
#  {'elevation': 396.8,
#   'mindate': '1948-08-01',
#   'maxdate': '1951-08-01',
#   'latitude': 47.51667,
#   'name': 'CUT FOOT SIOUX RANGE, MN US',
#   'datacoverage': 0.3244,
#   'id': 'COOP:211963',
#   'elevationUnit': 'METERS',
#   'longitude': -94.01667},
#  {'elevation': 402.3,
#   'mindate': '2007-02-01',
#   'maxdate': '2010-09-01',
#   'latitude': 46.125,
#   'name': 'DALTON 3 S, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:212015',
#   'elevationUnit': 'METERS',
#   'longitude': -95.90889},
#  {'elevation': 324.6,
#   'mindate': '2003-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.04181,
#   'name': 'DASSEL 3 SE, MN US',
#   'datacoverage': 0.9391,
#   'id': 'COOP:212023',
#   'elevationUnit': 'METERS',
#   'longitude': -94.27818},
#  {'elevation': 321.6,
#   'mindate': '1941-12-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.9318,
#   'name': 'DAWSON, MN US',
#   'datacoverage': 0.9302,
#   'id': 'COOP:212038',
#   'elevationUnit': 'METERS',
#   'longitude': -96.045},
#  {'elevation': 448.4,
#   'mindate': '1982-11-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.8998,
#   'name': 'DEEP PORTAGE, MN US',
#   'datacoverage': 0.922,
#   'id': 'COOP:212050',
#   'elevationUnit': 'METERS',
#   'longitude': -94.3873},
#  {'elevation': 297.2,
#   'mindate': '1977-12-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.04698,
#   'name': 'DELANO, MN US',
#   'datacoverage': 0.8838,
#   'id': 'COOP:212088',
#   'elevationUnit': 'METERS',
#   'longitude': -93.77717},
#  {'elevation': 413,
#   'mindate': '1895-12-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.8373,
#   'name': 'DETROIT LAKES 1 NNE, MN US',
#   'datacoverage': 0.9563,
#   'id': 'COOP:212142',
#   'elevationUnit': 'METERS',
#   'longitude': -95.8375},
#  {'elevation': 470,
#   'mindate': '2009-11-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.8576,
#   'name': 'DETROIT LAKES 12 E, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:212146',
#   'elevationUnit': 'METERS',
#   'longitude': -95.6068},
#  {'elevation': 386.8,
#   'mindate': '1948-08-01',
#   'maxdate': '2014-01-01',
#   'latitude': 44.0317,
#   'name': 'DODGE CENTER, MN US',
#   'datacoverage': 0.3892,
#   'id': 'COOP:212166',
#   'elevationUnit': 'METERS',
#   'longitude': -92.8691},
#  {'elevation': 244.1,
#   'mindate': '1956-04-01',
#   'maxdate': '1966-12-01',
#   'latitude': 48.56667,
#   'name': 'DRAYTON N DAK 2 NE, MN US',
#   'datacoverage': 0.8293,
#   'id': 'COOP:212222',
#   'elevationUnit': 'METERS',
#   'longitude': -97.15},
#  {'elevation': 185.9,
#   'mindate': '1960-03-01',
#   'maxdate': '2004-09-01',
#   'latitude': 46.7681,
#   'name': 'DULUTH HARBOR STATION, MN US',
#   'datacoverage': 0.9644,
#   'id': 'COOP:212246',
#   'elevationUnit': 'METERS',
#   'longitude': -92.0903},
#  {'elevation': 433.4,
#   'mindate': '1948-04-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.8436,
#   'name': 'DULUTH INTERNATIONAL AIRPORT, MN US',
#   'datacoverage': 0.9939,
#   'id': 'COOP:212248',
#   'elevationUnit': 'METERS',
#   'longitude': -92.18658},
#  {'elevation': 436.8,
#   'mindate': '2011-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.8368,
#   'name': 'DULUTH NWS, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:212250',
#   'elevationUnit': 'METERS',
#   'longitude': -92.2108},
#  {'elevation': 353.9,
#   'mindate': '1948-08-01',
#   'maxdate': '1959-09-01',
#   'latitude': 46.78333,
#   'name': 'DULUTH, MN US',
#   'datacoverage': 0.9063,
#   'id': 'COOP:212253',
#   'elevationUnit': 'METERS',
#   'longitude': -92.1},
#  {'elevation': 274.3,
#   'mindate': '1948-08-01',
#   'maxdate': '1948-11-25',
#   'latitude': 44.08333,
#   'name': 'ELBA, MN US',
#   'datacoverage': 0.9819,
#   'id': 'COOP:212468',
#   'elevationUnit': 'METERS',
#   'longitude': -92.01667},
#  {'elevation': 405.4,
#   'mindate': '1948-08-01',
#   'maxdate': '1988-12-01',
#   'latitude': 46.01083,
#   'name': 'ELBOW LAKE, MN US',
#   'datacoverage': 0.9711,
#   'id': 'COOP:212476',
#   'elevationUnit': 'METERS',
#   'longitude': -95.87556},
#  {'elevation': 338.3,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.0969,
#   'name': 'ELGIN 2 SSW, MN US',
#   'datacoverage': 0.9641,
#   'id': 'COOP:212486',
#   'elevationUnit': 'METERS',
#   'longitude': -92.2702},
#  {'elevation': 274.3,
#   'mindate': '1949-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.30565,
#   'name': 'ELK RIVER, MN US',
#   'datacoverage': 0.9824,
#   'id': 'COOP:212500',
#   'elevationUnit': 'METERS',
#   'longitude': -93.58253},
#  {'elevation': 421.2,
#   'mindate': '1997-11-01',
#   'maxdate': '2010-03-31',
#   'latitude': 47.9239,
#   'name': 'ELY, MN US',
#   'datacoverage': 0.9868,
#   'id': 'COOP:212543',
#   'elevationUnit': 'METERS',
#   'longitude': -91.8586},
#  {'elevation': 437.4,
#   'mindate': '1998-06-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.97463,
#   'name': 'ELY 25 E, MN US',
#   'datacoverage': 0.9809,
#   'id': 'COOP:212555',
#   'elevationUnit': 'METERS',
#   'longitude': -91.44953},
#  {'elevation': 449.6,
#   'mindate': '2011-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.9056,
#   'name': 'ELY, MN US',
#   'datacoverage': 0.9835,
#   'id': 'COOP:212561',
#   'elevationUnit': 'METERS',
#   'longitude': -91.8283},
#  {'elevation': 434.3,
#   'mindate': '1994-11-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.64317,
#   'name': 'EMBARRASS, MN US',
#   'datacoverage': 0.9843,
#   'id': 'COOP:212576',
#   'elevationUnit': 'METERS',
#   'longitude': -92.22648},
#  {'elevation': 440.4,
#   'mindate': '1986-10-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.4581,
#   'name': 'EVELETH WASTE WATER PLANT, MN US',
#   'datacoverage': 0.9914,
#   'id': 'COOP:212645',
#   'elevationUnit': 'METERS',
#   'longitude': -92.5303},
#  {'elevation': 361.8,
#   'mindate': '1931-01-01',
#   'maxdate': '2012-12-01',
#   'latitude': 43.6447,
#   'name': 'FAIRMONT, MN US',
#   'datacoverage': 0.9908,
#   'id': 'COOP:212698',
#   'elevationUnit': 'METERS',
#   'longitude': -94.4656},
#  {'elevation': 295.7,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.3092,
#   'name': 'FARIBAULT, MN US',
#   'datacoverage': 0.9902,
#   'id': 'COOP:212721',
#   'elevationUnit': 'METERS',
#   'longitude': -93.266},
#  {'elevation': 292.6,
#   'mindate': '1931-01-01',
#   'maxdate': '2010-10-01',
#   'latitude': 44.666,
#   'name': 'FARMINGTON 3 NW, MN US',
#   'datacoverage': 0.975,
#   'id': 'COOP:212737',
#   'elevationUnit': 'METERS',
#   'longitude': -93.17559},
#  {'elevation': 286.5,
#   'mindate': '2010-12-01',
#   'maxdate': '2010-12-01',
#   'latitude': 44.61167,
#   'name': 'FARMINGTON 3 SW, MN US',
#   'datacoverage': 0.9819,
#   'id': 'COOP:212738',
#   'elevationUnit': 'METERS',
#   'longitude': -93.18583},
#  {'elevation': 281,
#   'mindate': '1957-04-01',
#   'maxdate': '1970-07-01',
#   'latitude': 44.63333,
#   'name': 'FARMINGTON 1 W, MN US',
#   'datacoverage': 0.9875,
#   'id': 'COOP:212742',
#   'elevationUnit': 'METERS',
#   'longitude': -93.16667},
#  {'elevation': 381,
#   'mindate': '1931-01-01',
#   'maxdate': '2006-12-01',
#   'latitude': 46.2919,
#   'name': 'FERGUS FALLS, MN US',
#   'datacoverage': 0.9803,
#   'id': 'COOP:212768',
#   'elevationUnit': 'METERS',
#   'longitude': -96.1172},
#  {'elevation': 384,
#   'mindate': '1986-07-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.9728,
#   'name': 'FLOODWOOD 3 NE, MN US',
#   'datacoverage': 0.9943,
#   'id': 'COOP:212842',
#   'elevationUnit': 'METERS',
#   'longitude': -92.87},
#  {'elevation': 275.8,
#   'mindate': '1958-10-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.33159,
#   'name': 'FOREST LAKE 5 NE, MN US',
#   'datacoverage': 0.9942,
#   'id': 'COOP:212881',
#   'elevationUnit': 'METERS',
#   'longitude': -92.89824},
#  {'elevation': 301.8,
#   'mindate': '2011-01-01',
#   'maxdate': '2012-12-01',
#   'latitude': 44.456,
#   'name': 'FORT RIDGELY STATE PARK, MN US',
#   'datacoverage': 0.9993,
#   'id': 'COOP:212900',
#   'elevationUnit': 'METERS',
#   'longitude': -94.735},
#  {'elevation': 345.6,
#   'mindate': '1948-04-01',
#   'maxdate': '1990-06-01',
#   'latitude': 46.18056,
#   'name': 'FORT RIPLEY, MN US',
#   'datacoverage': 0.9448,
#   'id': 'COOP:212904',
#   'elevationUnit': 'METERS',
#   'longitude': -94.36556},
#  {'elevation': 396.2,
#   'mindate': '1909-07-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.5639,
#   'name': 'FOSSTON 1 E, MN US',
#   'datacoverage': 0.9005,
#   'id': 'COOP:212916',
#   'elevationUnit': 'METERS',
#   'longitude': -95.7246},
#  {'elevation': 427.6,
#   'mindate': '1940-01-01',
#   'maxdate': '2014-01-01',
#   'latitude': 46.7336,
#   'name': 'FRAZEE, MN US',
#   'datacoverage': 0.8944,
#   'id': 'COOP:212964',
#   'elevationUnit': 'METERS',
#   'longitude': -95.7066},
#  {'elevation': 368.8,
#   'mindate': '1991-09-01',
#   'maxdate': '1996-11-01',
#   'latitude': 46.33056,
#   'name': 'GARRISON 4 NE, MN US',
#   'datacoverage': 0.9204,
#   'id': 'COOP:213051',
#   'elevationUnit': 'METERS',
#   'longitude': -93.7675},
#  {'elevation': 310.9,
#   'mindate': '1956-10-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.55647,
#   'name': 'GAYLORD, MN US',
#   'datacoverage': 0.9874,
#   'id': 'COOP:213076',
#   'elevationUnit': 'METERS',
#   'longitude': -94.22077},
#  {'elevation': 269.7,
#   'mindate': '1962-11-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.0792,
#   'name': 'GEORGETOWN 1 E, MN US',
#   'datacoverage': 0.909,
#   'id': 'COOP:213104',
#   'elevationUnit': 'METERS',
#   'longitude': -96.7758},
#  {'elevation': 365.2,
#   'mindate': '1940-06-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.6584,
#   'name': 'GLENWOOD 2 WNW, MN US',
#   'datacoverage': 0.9437,
#   'id': 'COOP:213174',
#   'elevationUnit': 'METERS',
#   'longitude': -95.4392},
#  {'elevation': 272.8,
#   'mindate': '1963-04-01',
#   'maxdate': '2014-01-01',
#   'latitude': 44.9907,
#   'name': 'GOLDEN VALLEY, MN US',
#   'datacoverage': 0.0225,
#   'id': 'COOP:213202',
#   'elevationUnit': 'METERS',
#   'longitude': -93.3989},
#  {'elevation': 437.7,
#   'mindate': '1921-07-01',
#   'maxdate': '1990-10-01',
#   'latitude': 47.73333,
#   'name': 'GONVICK 2 W, MN US',
#   'datacoverage': 0.8834,
#   'id': 'COOP:213206',
#   'elevationUnit': 'METERS',
#   'longitude': -95.51667},
#  {'elevation': 186.5,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.7518,
#   'name': 'GRAND MARAIS, MN US',
#   'datacoverage': 0.9814,
#   'id': 'COOP:213282',
#   'elevationUnit': 'METERS',
#   'longitude': -90.3282},
#  {'elevation': 411.5,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.7047,
#   'name': 'GRAND MEADOW, MN US',
#   'datacoverage': 0.9932,
#   'id': 'COOP:213290',
#   'elevationUnit': 'METERS',
#   'longitude': -92.5644},
#  {'elevation': 222.5,
#   'mindate': '1950-07-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.9711,
#   'name': 'GRAND PORTAGE RANGER STATION, MN US',
#   'datacoverage': 0.6586,
#   'id': 'COOP:213296',
#   'elevationUnit': 'METERS',
#   'longitude': -89.6908},
#  {'elevation': 399.3,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.2436,
#   'name': 'GRAND RAPIDS FRS LAB, MN US',
#   'datacoverage': 0.9941,
#   'id': 'COOP:213303',
#   'elevationUnit': 'METERS',
#   'longitude': -93.4975},
#  {'elevation': 283.5,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.81346,
#   'name': 'GRANITE FALLS, MN US',
#   'datacoverage': 0.3626,
#   'id': 'COOP:213311',
#   'elevationUnit': 'METERS',
#   'longitude': -95.55172},
#  {'elevation': 370.3,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.4119,
#   'name': 'GULL LAKE DAM, MN US',
#   'datacoverage': 0.9882,
#   'id': 'COOP:213411',
#   'elevationUnit': 'METERS',
#   'longitude': -94.3608},
#  {'elevation': 443.5,
#   'mindate': '1951-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 48.1603,
#   'name': 'GUNFLINT LAKE 10 NW, MN US',
#   'datacoverage': 0.7276,
#   'id': 'COOP:213417',
#   'elevationUnit': 'METERS',
#   'longitude': -90.8842},
#  {'elevation': 476.1,
#   'mindate': '1948-08-01',
#   'maxdate': '1951-09-01',
#   'latitude': 48.08333,
#   'name': 'GUNFLINT LAKE, MN US',
#   'datacoverage': 0.3532,
#   'id': 'COOP:213419',
#   'elevationUnit': 'METERS',
#   'longitude': -90.7},
#  {'elevation': 248.4,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 48.7715,
#   'name': 'HALLOCK, MN US',
#   'datacoverage': 0.8253,
#   'id': 'COOP:213455',
#   'elevationUnit': 'METERS',
#   'longitude': -96.9406},
#  {'elevation': 260,
#   'mindate': '1956-04-01',
#   'maxdate': '2015-07-01',
#   'latitude': 47.3522,
#   'name': 'HALSTAD, MN US',
#   'datacoverage': 0.8371,
#   'id': 'COOP:213463',
#   'elevationUnit': 'METERS',
#   'longitude': -96.8332},
#  {'elevation': 304.5,
#   'mindate': '2008-06-01',
#   'maxdate': '2012-12-01',
#   'latitude': 44.7341,
#   'name': 'HAMBURG, MN US',
#   'datacoverage': 0.9994,
#   'id': 'COOP:213470',
#   'elevationUnit': 'METERS',
#   'longitude': -93.9631},
#  {'elevation': 411.5,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.5458,
#   'name': 'HARMONY, MN US',
#   'datacoverage': 0.9827,
#   'id': 'COOP:213520',
#   'elevationUnit': 'METERS',
#   'longitude': -92.0122},
#  {'mindate': '1950-02-01',
#   'maxdate': '1950-02-01',
#   'latitude': 44.76667,
#   'name': 'HASTINGS LOCK 2, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:213562',
#   'longitude': -92.86667},
#  {'elevation': 207.3,
#   'mindate': '1932-10-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.7597,
#   'name': 'HASTINGS DAM 2, MN US',
#   'datacoverage': 0.981,
#   'id': 'COOP:213567',
#   'elevationUnit': 'METERS',
#   'longitude': -92.8689},
#  {'elevation': 355.1,
#   'mindate': '1948-09-01',
#   'maxdate': '1989-12-01',
#   'latitude': 46.88333,
#   'name': 'HAWLEY 3 NE, MN US',
#   'datacoverage': 0.6296,
#   'id': 'COOP:213587',
#   'elevationUnit': 'METERS',
#   'longitude': -96.25},
#  {'elevation': 297.2,
#   'mindate': '2010-07-01',
#   'maxdate': '2010-12-01',
#   'latitude': 44.53556,
#   'name': 'HENDERSON 3 W, MN US',
#   'datacoverage': 0.9925,
#   'id': 'COOP:213678',
#   'elevationUnit': 'METERS',
#   'longitude': -93.97},
#  {'elevation': 328.9,
#   'mindate': '1948-08-01',
#   'maxdate': '1957-03-01',
#   'latitude': 45.8,
#   'name': 'HERMAN, MN US',
#   'datacoverage': 0.9425,
#   'id': 'COOP:213708',
#   'elevationUnit': 'METERS',
#   'longitude': -96.15},
#  {'elevation': 467,
#   'mindate': '1948-08-01',
#   'maxdate': '1981-09-01',
#   'latitude': 47.43333,
#   'name': 'HIBBING POWER SUBSTN, MN US',
#   'datacoverage': 0.9472,
#   'id': 'COOP:213727',
#   'elevationUnit': 'METERS',
#   'longitude': -92.96667},
#  {'elevation': 408.2,
#   'mindate': '1962-11-01',
#   'maxdate': '2009-06-01',
#   'latitude': 47.38039,
#   'name': 'HIBBING CHISHOLM HIBBING AIRPORT, MN US',
#   'datacoverage': 0.9965,
#   'id': 'COOP:213730',
#   'elevationUnit': 'METERS',
#   'longitude': -92.83246},
#  {'elevation': 350.5,
#   'mindate': '1948-07-01',
#   'maxdate': '1993-12-01',
#   'latitude': 48.06667,
#   'name': 'HIGH LANDING 2 NW, MN US',
#   'datacoverage': 0.8388,
#   'id': 'COOP:213756',
#   'elevationUnit': 'METERS',
#   'longitude': -95.85},
#  {'elevation': 371.9,
#   'mindate': '1948-08-01',
#   'maxdate': '1951-10-01',
#   'latitude': 46.98333,
#   'name': 'HILL CITY RANGER STATION, MN US',
#   'datacoverage': 0.359,
#   'id': 'COOP:213764',
#   'elevationUnit': 'METERS',
#   'longitude': -93.6},
#  {'elevation': 315.5,
#   'mindate': '1937-06-01',
#   'maxdate': '2010-12-01',
#   'latitude': 45.9919,
#   'name': 'HINCKLEY, MN US',
#   'datacoverage': 0.9603,
#   'id': 'COOP:213793',
#   'elevationUnit': 'METERS',
#   'longitude': -92.9927},
#  {'elevation': 317,
#   'mindate': '1951-03-01',
#   'maxdate': '1960-05-30',
#   'latitude': 46.01667,
#   'name': 'HINCKLEY, MN US',
#   'datacoverage': 0.9956,
#   'id': 'COOP:213795',
#   'elevationUnit': 'METERS',
#   'longitude': -92.95},
#  {'elevation': 197.2,
#   'mindate': '1948-07-01',
#   'maxdate': '2010-05-01',
#   'latitude': 43.7637,
#   'name': 'HOKAH WWTP, MN US',
#   'datacoverage': 0.4926,
#   'id': 'COOP:213808',
#   'elevationUnit': 'METERS',
#   'longitude': -91.34815},
#  {'elevation': 209.1,
#   'mindate': '2005-02-01',
#   'maxdate': '2014-12-01',
#   'latitude': 43.79529,
#   'name': 'HOKAH 4 NW, MN US',
#   'datacoverage': 0.4959,
#   'id': 'COOP:213812',
#   'elevationUnit': 'METERS',
#   'longitude': -91.42694},
#  {'elevation': 315.2,
#   'mindate': '1948-09-01',
#   'maxdate': '2014-01-01',
#   'latitude': 46.4675,
#   'name': 'HOLYOKE, MN US',
#   'datacoverage': 0.2289,
#   'id': 'COOP:213863',
#   'elevationUnit': 'METERS',
#   'longitude': -92.3903},
#  {'elevation': 240.8,
#   'mindate': '2000-10-01',
#   'maxdate': '2003-09-01',
#   'latitude': 43.82028,
#   'name': 'HOUSTON 5 NW, MN US',
#   'datacoverage': 0.8895,
#   'id': 'COOP:213904',
#   'elevationUnit': 'METERS',
#   'longitude': -91.62417},
#  {'elevation': 463.9,
#   'mindate': '1958-03-01',
#   'maxdate': '1984-02-01',
#   'latitude': 47.58333,
#   'name': 'HOYT LAKES 5 N, MN US',
#   'datacoverage': 0.9615,
#   'id': 'COOP:213921',
#   'elevationUnit': 'METERS',
#   'longitude': -92.13333},
#  {'elevation': 333.8,
#   'mindate': '1948-09-01',
#   'maxdate': '2009-11-24',
#   'latitude': 44.909,
#   'name': 'HUTCHINSON 1 N, MN US',
#   'datacoverage': 0.8842,
#   'id': 'COOP:213962',
#   'elevationUnit': 'METERS',
#   'longitude': -94.3674},
#  {'elevation': 326.1,
#   'mindate': '2010-01-01',
#   'maxdate': '2014-12-01',
#   'latitude': 44.8978,
#   'name': 'HUTCHINSON 1 W, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:213965',
#   'elevationUnit': 'METERS',
#   'longitude': -94.3719},
#  {'elevation': 333.8,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 48.6236,
#   'name': 'INDUSTRIAL 3 W, MN US',
#   'datacoverage': 0.9629,
#   'id': 'COOP:214008',
#   'elevationUnit': 'METERS',
#   'longitude': -93.8992},
#  {'elevation': 352.6,
#   'mindate': '1948-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 48.55943,
#   'name': 'INTERNATIONAL FALLS INTERNATIONAL AIRPORT, MN US',
#   'datacoverage': 0.9939,
#   'id': 'COOP:214026',
#   'elevationUnit': 'METERS',
#   'longitude': -93.39554},
#  {'elevation': 612.6,
#   'mindate': '1957-09-01',
#   'maxdate': '2005-07-01',
#   'latitude': 47.6181,
#   'name': 'ISABELLA 1 W, MN US',
#   'datacoverage': 0.9252,
#   'id': 'COOP:214068',
#   'elevationUnit': 'METERS',
#   'longitude': -91.3753},
#  {'elevation': 530.4,
#   'mindate': '2009-11-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.59333,
#   'name': 'ISABELLA 14 W, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:214077',
#   'elevationUnit': 'METERS',
#   'longitude': -91.65139},
#  {'elevation': 429.8,
#   'mindate': '2009-10-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.02389,
#   'name': 'ISLAND LAKE 4 E, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:214093',
#   'elevationUnit': 'METERS',
#   'longitude': -92.07},
#  {'elevation': 418.2,
#   'mindate': '1948-08-01',
#   'maxdate': '1995-09-01',
#   'latitude': 46.98333,
#   'name': 'ISLAND LAKE RESERVOIR, MN US',
#   'datacoverage': 0.9806,
#   'id': 'COOP:214096',
#   'elevationUnit': 'METERS',
#   'longitude': -92.23333},
#  {'elevation': 384,
#   'mindate': '1936-04-01',
#   'maxdate': '1945-11-01',
#   'latitude': 46.13333,
#   'name': 'ISLE, MN US',
#   'datacoverage': 0.9051,
#   'id': 'COOP:214102',
#   'elevationUnit': 'METERS',
#   'longitude': -93.46667},
#  {'elevation': 391.7,
#   'mindate': '1959-10-01',
#   'maxdate': '2015-11-01',
#   'latitude': 46.3197,
#   'name': 'ISLE 12 N, MN US',
#   'datacoverage': 0.9125,
#   'id': 'COOP:214103',
#   'elevationUnit': 'METERS',
#   'longitude': -93.5013},
#  {'elevation': 454.2,
#   'mindate': '1911-05-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.2255,
#   'name': 'ITASCA UNIVERSITY OF MINN, MN US',
#   'datacoverage': 0.9896,
#   'id': 'COOP:214106',
#   'elevationUnit': 'METERS',
#   'longitude': -95.1919},
#  {'elevation': 274.3,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.6501,
#   'name': 'JORDAN 1 SSW, MN US',
#   'datacoverage': 0.8936,
#   'id': 'COOP:214176',
#   'elevationUnit': 'METERS',
#   'longitude': -93.6356},
#  {'elevation': 365.8,
#   'mindate': '1997-11-01',
#   'maxdate': '2015-11-01',
#   'latitude': 48.4088,
#   'name': 'KABETOGAMA, MN US',
#   'datacoverage': 0.8573,
#   'id': 'COOP:214191',
#   'elevationUnit': 'METERS',
#   'longitude': -93.0484},
#  {'elevation': 325.2,
#   'mindate': '1962-12-01',
#   'maxdate': '1992-11-01',
#   'latitude': 48.58333,
#   'name': 'KARLSTAD, MN US',
#   'datacoverage': 0.8555,
#   'id': 'COOP:214213',
#   'elevationUnit': 'METERS',
#   'longitude': -96.51667},
#  {'elevation': 311.5,
#   'mindate': '2002-08-01',
#   'maxdate': '2004-08-01',
#   'latitude': 48.5558,
#   'name': 'KARLSTAD 2 SE, MN US',
#   'datacoverage': 0.8788,
#   'id': 'COOP:214215',
#   'elevationUnit': 'METERS',
#   'longitude': -96.48},
#  {'elevation': 413.6,
#   'mindate': '1963-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.9422,
#   'name': 'KELLIHER, MN US',
#   'datacoverage': 0.8899,
#   'id': 'COOP:214233',
#   'elevationUnit': 'METERS',
#   'longitude': -94.4553},
#  {'elevation': 342,
#   'mindate': '1948-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 48.5011,
#   'name': 'KETTLE FALLS, MN US',
#   'datacoverage': 0.7596,
#   'id': 'COOP:214306',
#   'elevationUnit': 'METERS',
#   'longitude': -92.6444},
#  {'elevation': 353.6,
#   'mindate': '2008-11-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.3533,
#   'name': 'KIMBALL 3 N, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:214373',
#   'elevationUnit': 'METERS',
#   'longitude': -94.3056},
#  {'elevation': 320,
#   'mindate': '1948-07-01',
#   'maxdate': '1954-06-01',
#   'latitude': 45.01667,
#   'name': 'LAC QUI PARLE DAM, MN US',
#   'datacoverage': 0.7216,
#   'id': 'COOP:214410',
#   'elevationUnit': 'METERS',
#   'longitude': -95.86667},
#  {'elevation': 197.2,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.8657,
#   'name': 'LA CRESCENT DAM 7, MN US',
#   'datacoverage': 0.9839,
#   'id': 'COOP:214418',
#   'elevationUnit': 'METERS',
#   'longitude': -91.31},
#  {'elevation': 283.5,
#   'mindate': '1993-05-01',
#   'maxdate': '2000-04-01',
#   'latitude': 48.72444,
#   'name': 'LAKE BRONSON, MN US',
#   'datacoverage': 0.9285,
#   'id': 'COOP:214431',
#   'elevationUnit': 'METERS',
#   'longitude': -96.62139},
#  {'elevation': 213.4,
#   'mindate': '1946-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.4363,
#   'name': 'LAKE CITY, MN US',
#   'datacoverage': 0.8987,
#   'id': 'COOP:214438',
#   'elevationUnit': 'METERS',
#   'longitude': -92.2793},
#  {'elevation': 466.3,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.7022,
#   'name': 'LAKEFIELD 2 NE, MN US',
#   'datacoverage': 0.3036,
#   'id': 'COOP:214453',
#   'elevationUnit': 'METERS',
#   'longitude': -95.1519},
#  {'elevation': 503.8,
#   'mindate': '1973-05-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.99878,
#   'name': 'LAKE WILSON, MN US',
#   'datacoverage': 0.9726,
#   'id': 'COOP:214534',
#   'elevationUnit': 'METERS',
#   'longitude': -95.94908},
#  {'elevation': 347.5,
#   'mindate': '1961-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.2395,
#   'name': 'LAMBERTON SOUTHWEST RESEARCH AND OUTREACH CENTER, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:214546',
#   'elevationUnit': 'METERS',
#   'longitude': -95.3152},
#  {'elevation': 291.1,
#   'mindate': '1955-06-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.7203,
#   'name': 'LANESBORO, MN US',
#   'datacoverage': 0.9752,
#   'id': 'COOP:214563',
#   'elevationUnit': 'METERS',
#   'longitude': -91.9718},
#  {'elevation': 326.1,
#   'mindate': '1948-08-01',
#   'maxdate': '1991-08-01',
#   'latitude': 44.38333,
#   'name': 'LE CENTER 2 SE, MN US',
#   'datacoverage': 0.7505,
#   'id': 'COOP:214641',
#   'elevationUnit': 'METERS',
#   'longitude': -93.71667},
#  {'elevation': 396.8,
#   'mindate': '1893-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.2467,
#   'name': 'LEECH LAKE DAM, MN US',
#   'datacoverage': 0.9919,
#   'id': 'COOP:214652',
#   'elevationUnit': 'METERS',
#   'longitude': -94.2228},
#  {'elevation': 390.1,
#   'mindate': '1940-04-01',
#   'maxdate': '1957-05-01',
#   'latitude': 47.73333,
#   'name': 'LEONARD 8 NE, MN US',
#   'datacoverage': 0.9515,
#   'id': 'COOP:214688',
#   'elevationUnit': 'METERS',
#   'longitude': -95.21667},
#  {'elevation': 300.2,
#   'mindate': '2006-06-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.8593,
#   'name': 'LESTER PRAIRIE 2 S, MN US',
#   'datacoverage': 0.8859,
#   'id': 'COOP:214692',
#   'elevationUnit': 'METERS',
#   'longitude': -94.0503},
#  {'elevation': 253,
#   'mindate': '1948-08-01',
#   'maxdate': '2014-01-01',
#   'latitude': 44.4698,
#   'name': 'LE SUEUR, MN US',
#   'datacoverage': 0.8162,
#   'id': 'COOP:214721',
#   'elevationUnit': 'METERS',
#   'longitude': -93.9025},
#  {'elevation': 341.4,
#   'mindate': '1940-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.12794,
#   'name': 'LITCHFIELD, MN US',
#   'datacoverage': 0.9845,
#   'id': 'COOP:214778',
#   'elevationUnit': 'METERS',
#   'longitude': -94.53468},
#  {'elevation': 341.4,
#   'mindate': '1931-01-01',
#   'maxdate': '2013-06-01',
#   'latitude': 46.0039,
#   'name': 'LITTLE FALLS 2 NNE, MN US',
#   'datacoverage': 0.9847,
#   'id': 'COOP:214793',
#   'elevationUnit': 'METERS',
#   'longitude': -94.345},
#  {'elevation': 342,
#   'mindate': '1948-08-01',
#   'maxdate': '1972-11-01',
#   'latitude': 45.98333,
#   'name': 'LITTLE FALLS WATER W, MN US',
#   'datacoverage': 0.8162,
#   'id': 'COOP:214798',
#   'elevationUnit': 'METERS',
#   'longitude': -94.35},
#  {'elevation': 360,
#   'mindate': '1948-08-01',
#   'maxdate': '1952-12-01',
#   'latitude': 48.4,
#   'name': 'LITTLEFORK RANGER ST, MN US',
#   'datacoverage': 0.6789,
#   'id': 'COOP:214806',
#   'elevationUnit': 'METERS',
#   'longitude': -93.55},
#  {'elevation': 365.8,
#   'mindate': '1994-01-01',
#   'maxdate': '2009-09-01',
#   'latitude': 48.36806,
#   'name': 'LITTLEFORK 10 SW, MN US',
#   'datacoverage': 0.9842,
#   'id': 'COOP:214809',
#   'elevationUnit': 'METERS',
#   'longitude': -93.72139},
#  {'elevation': 408.4,
#   'mindate': '1937-03-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.9646,
#   'name': 'LONG PRAIRIE, MN US',
#   'datacoverage': 0.9534,
#   'id': 'COOP:214861',
#   'elevationUnit': 'METERS',
#   'longitude': -94.8892},
#  {'elevation': 229.8,
#   'mindate': '1991-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.9784,
#   'name': 'LOWER ST. ANTHONY FALLS, MN US',
#   'datacoverage': 0.9588,
#   'id': 'COOP:214884',
#   'elevationUnit': 'METERS',
#   'longitude': -93.2469},
#  {'elevation': 396.2,
#   'mindate': '1986-10-01',
#   'maxdate': '2006-03-01',
#   'latitude': 47.69806,
#   'name': 'LUTSEN 3 NNE, MN US',
#   'datacoverage': 0.9573,
#   'id': 'COOP:214918',
#   'elevationUnit': 'METERS',
#   'longitude': -90.66556},
#  {'elevation': 457.2,
#   'mindate': '1950-10-01',
#   'maxdate': '2014-01-01',
#   'latitude': 43.6658,
#   'name': 'LUVERNE, MN US',
#   'datacoverage': 0.8616,
#   'id': 'COOP:214937',
#   'elevationUnit': 'METERS',
#   'longitude': -96.2022},
#  {'elevation': 338.9,
#   'mindate': '2013-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 43.52433,
#   'name': 'MABEL, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:214990',
#   'elevationUnit': 'METERS',
#   'longitude': -91.76141},
#  {'elevation': 327.7,
#   'mindate': '1940-05-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.00236,
#   'name': 'MADISON WWTP, MN US',
#   'datacoverage': 0.9581,
#   'id': 'COOP:214994',
#   'elevationUnit': 'METERS',
#   'longitude': -96.16611},
#  {'elevation': 369.4,
#   'mindate': '1924-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 47.3169,
#   'name': 'MAHNOMEN, MN US',
#   'datacoverage': 0.7902,
#   'id': 'COOP:215012',
#   'elevationUnit': 'METERS',
#   'longitude': -95.9691},
#  {'elevation': 481.9,
#   'mindate': '1931-01-01',
#   'maxdate': '1962-04-01',
#   'latitude': 47.46667,
#   'name': 'MAHONING MINE, MN US',
#   'datacoverage': 0.9868,
#   'id': 'COOP:215020',
#   'elevationUnit': 'METERS',
#   'longitude': -92.98333},
#  {'elevation': 259.1,
#   'mindate': '1984-09-01',
#   'maxdate': '2010-10-01',
#   'latitude': 44.1543,
#   'name': 'MANKATO, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:215073',
#   'elevationUnit': 'METERS',
#   'longitude': -94.0212},
#  {'elevation': 259.1,
#   'mindate': '1931-01-01',
#   'maxdate': '1954-08-01',
#   'latitude': 44.1543,
#   'name': 'MANKATO, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:215088',
#   'elevationUnit': 'METERS',
#   'longitude': -94.0212},
#  {'elevation': 307.8,
#   'mindate': '2015-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.1673,
#   'name': 'MANKATO 4 E, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:215089',
#   'elevationUnit': 'METERS',
#   'longitude': -93.9102},
#  {'elevation': 295.7,
#   'mindate': '1931-01-01',
#   'maxdate': '1986-11-01',
#   'latitude': 45,
#   'name': 'MAPLE PLAIN, MN US',
#   'datacoverage': 0.9851,
#   'id': 'COOP:215136',
#   'elevationUnit': 'METERS',
#   'longitude': -93.65},
#  {'elevation': 422.8,
#   'mindate': '1981-08-01',
#   'maxdate': '2007-09-01',
#   'latitude': 47.6308,
#   'name': 'MARCELL 5 NE, MN US',
#   'datacoverage': 0.8859,
#   'id': 'COOP:215175',
#   'elevationUnit': 'METERS',
#   'longitude': -93.6522},
#  {'elevation': 350.2,
#   'mindate': '1935-04-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.4716,
#   'name': 'MARSHALL, MN US',
#   'datacoverage': 0.9907,
#   'id': 'COOP:215204',
#   'elevationUnit': 'METERS',
#   'longitude': -95.79019},
#  {'elevation': 386.8,
#   'mindate': '1931-01-01',
#   'maxdate': '1986-07-01',
#   'latitude': 46.98333,
#   'name': 'MEADOWLANDS 9 S, MN US',
#   'datacoverage': 0.9591,
#   'id': 'COOP:215298',
#   'elevationUnit': 'METERS',
#   'longitude': -92.73333},
#  {'elevation': 390.1,
#   'mindate': '1952-09-01',
#   'maxdate': '1954-09-01',
#   'latitude': 47.08333,
#   'name': 'MEADOWLANDS 1 N, MN US',
#   'datacoverage': 0.0509,
#   'id': 'COOP:215302',
#   'elevationUnit': 'METERS',
#   'longitude': -92.73333},
#  {'elevation': 362.7,
#   'mindate': '1954-12-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.6773,
#   'name': 'MELROSE, MN US',
#   'datacoverage': 0.9727,
#   'id': 'COOP:215325',
#   'elevationUnit': 'METERS',
#   'longitude': -94.80203},
#  {'elevation': 324.3,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.7532,
#   'name': 'MILACA, MN US',
#   'datacoverage': 0.951,
#   'id': 'COOP:215392',
#   'elevationUnit': 'METERS',
#   'longitude': -93.6617},
#  {'elevation': 310.9,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.1219,
#   'name': 'MILAN 1 NW, MN US',
#   'datacoverage': 0.9941,
#   'id': 'COOP:215400',
#   'elevationUnit': 'METERS',
#   'longitude': -95.9269},
#  {'elevation': 254.5,
#   'mindate': '1948-08-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.88523,
#   'name': 'MINNEAPOLIS ST. PAUL INTERNATIONAL AIRPORT, MN US',
#   'datacoverage': 0.9937,
#   'id': 'COOP:215435',
#   'elevationUnit': 'METERS',
#   'longitude': -93.23133},
#  {'elevation': 263.4,
#   'mindate': '2009-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 45.06222,
#   'name': 'MINNEAPOLIS CRYSTAL AIRPORT, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:215441',
#   'elevationUnit': 'METERS',
#   'longitude': -93.35107},
#  {'elevation': 275.7,
#   'mindate': '2009-09-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.83214,
#   'name': 'MINNEAPOLIS FLYING CLOUD AIRPORT, MN US',
#   'datacoverage': 1,
#   'id': 'COOP:215443',
#   'elevationUnit': 'METERS',
#   'longitude': -93.47051},
#  {'elevation': 369.1,
#   'mindate': '1948-07-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.563,
#   'name': 'MINNEOTA, MN US',
#   'datacoverage': 0.937,
#   'id': 'COOP:215482',
#   'elevationUnit': 'METERS',
#   'longitude': -95.9969},
#  {'elevation': 204.2,
#   'mindate': '1948-07-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.1601,
#   'name': 'MINNESOTA CITY DAM 5, MN US',
#   'datacoverage': 0.9839,
#   'id': 'COOP:215488',
#   'elevationUnit': 'METERS',
#   'longitude': -91.81247},
#  {'elevation': 430.1,
#   'mindate': '1932-01-01',
#   'maxdate': '1940-03-01',
#   'latitude': 47.95,
#   'name': 'MIZPAH, MN US',
#   'datacoverage': 0.8991,
#   'id': 'COOP:215533',
#   'elevationUnit': 'METERS',
#   'longitude': -94.21667},
#  {'elevation': 301.8,
#   'mindate': '1931-01-01',
#   'maxdate': '2015-11-01',
#   'latitude': 44.9341,
# ...
#   'name': 'PARK RAPIDS 5.2 ESE, MN US',
#   'datacoverage': 0.6935,
#   'id': 'GHCND:US1MNHB0017',
#   'elevationUnit': 'METERS',
#   'longitude': -94.958085},
#  {'elevation': 453.5,
#   'mindate': '2021-07-16',
#   'maxdate': '2023-11-09',
#   'latitude': 47.0236082,
#   'name': 'PARK RAPIDS 8.0 NNE, MN US',
#   'datacoverage': 0.5455,
#   'id': 'GHCND:US1MNHB0019',
#   'elevationUnit': 'METERS',
#   'longitude': -95.0007863},
#  {'elevation': 435.9,
#   'mindate': '2023-04-15',
#   'maxdate': '2023-12-28',
#   'latitude': 47.0378,
#   'name': 'PARK RAPIDS 9.8 NNE, MN US',
#   'datacoverage': 0.998,
#   'id': 'GHCND:US1MNHB0031',
#   'elevationUnit': 'METERS',
#   'longitude': -94.955},
#  {'elevation': 259.7,
#   'mindate': '2001-03-01',
#   'maxdate': '2016-09-25',
#   'latitude': 44.8717,
#   'name': 'RICHFIELD 1.2 WSW, MN US',
#   'datacoverage': 0.7808,
#   'id': 'GHCND:US1MNHN0003',
#   'elevationUnit': 'METERS',
#   'longitude': -93.305506},
#  {'elevation': 306.3,
#   'mindate': '2009-12-01',
#   'maxdate': '2024-01-29',
#   'latitude': 44.9829,
#   'name': 'LONG LAKE 0.2 WSW, MN US',
#   'datacoverage': 0.7869,
#   'id': 'GHCND:US1MNHN0006',
#   'elevationUnit': 'METERS',
#   'longitude': -93.57358},
#  {'elevation': 287.1,
#   'mindate': '2010-05-01',
#   'maxdate': '2023-10-27',
#   'latitude': 45.026942,
#   'name': 'SAINT ANTHONY 0.9 WNW, MN US',
#   'datacoverage': 0.9819,
#   'id': 'GHCND:US1MNHN0008',
#   'elevationUnit': 'METERS',
#   'longitude': -93.234568},
#  {'elevation': 272.2,
#   'mindate': '2009-12-01',
#   'maxdate': '2022-04-25',
#   'latitude': 45.0038728,
#   'name': 'MINNEAPOLIS 3.0 NNW, MN US',
#   'datacoverage': 0.8685,
#   'id': 'GHCND:US1MNHN0009',
#   'elevationUnit': 'METERS',
#   'longitude': -93.2894762},
#  {'elevation': 287.1,
#   'mindate': '2009-12-01',
#   'maxdate': '2024-01-29',
#   'latitude': 44.914467,
#   'name': 'MINNETRISTA 1.5 SSE, MN US',
#   'datacoverage': 1,
#   'id': 'GHCND:US1MNHN0014',
#   'elevationUnit': 'METERS',
#   'longitude': -93.699217},
#  {'elevation': 271.9,
#   'mindate': '2010-01-01',
#   'maxdate': '2011-09-21',
#   'latitude': 44.8482785,
#   'name': 'EDEN PRAIRIE 0.2 ESE, MN US',
#   'datacoverage': 1,
#   'id': 'GHCND:US1MNHN0015',
#   'elevationUnit': 'METERS',
#   'longitude': -93.4564268},
#  {'elevation': 280.1,
#   'mindate': '2010-04-01',
#   'maxdate': '2023-10-29',
#   'latitude': 44.829676,
#   'name': 'EDEN PRAIRIE 2.5 WSW, MN US',
#   'datacoverage': 0.6416,
#   'id': 'GHCND:US1MNHN0016',
#   'elevationUnit': 'METERS',
#   'longitude': -93.502792},
#  {'elevation': 275.8,
#   'mindate': '2010-05-01',
#   'maxdate': '2024-01-29',
#   'latitude': 44.8294022,
#   'name': 'EDEN PRAIRIE 3.3 WSW, MN US',
#   'datacoverage': 0.9996,
#   'id': 'GHCND:US1MNHN0017',
#   'elevationUnit': 'METERS',
#   'longitude': -93.5201406},
#  {'elevation': 292.6,
#   'mindate': '2010-02-01',
#   'maxdate': '2024-01-28',
#   'latitude': 44.8783,
#   'name': 'EDINA 1.3 SW, MN US',
#   'datacoverage': 1,
#   'id': 'GHCND:US1MNHN0019',
#   'elevationUnit': 'METERS',
#   'longitude': -93.3789},
#  {'elevation': 275.2,
#   'mindate': '2010-04-01',
#   'maxdate': '2011-07-16',
#   'latitude': 45.03641299,
#   'name': 'CRYSTAL 0.2 WSW, MN US',
#   'datacoverage': 0.9956,
#   'id': 'GHCND:US1MNHN0020',
#   'elevationUnit': 'METERS',
#   'longitude': -93.36424633},
#  {'elevation': 278.3,
#   'mindate': '2010-07-01',
#   'maxdate': '2024-01-06',
#   'latitude': 44.928866,
#   'name': 'MINNEAPOLIS 3.3 SW, MN US',
#   'datacoverage': 0.9996,
#   'id': 'GHCND:US1MNHN0022',
#   'elevationUnit': 'METERS',
#   'longitude': -93.316328},
#  {'elevation': 249.9,
#   'mindate': '2010-08-01',
#   'maxdate': '2017-10-03',
#   'latitude': 44.98166667,
#   'name': 'MINNEAPOLIS TARGET FIELD, MN US',
#   'datacoverage': 0.625,
#   'id': 'GHCND:US1MNHN0025',
#   'elevationUnit': 'METERS',
#   'longitude': -93.27833333},
#  {'elevation': 269.4,
#   'mindate': '2010-10-01',
#   'maxdate': '2023-10-06',
#   'latitude': 44.91,
#   'name': 'MINNEAPOLIS 3.8 SSW, MN US',
#   'datacoverage': 0.9999,
#   'id': 'GHCND:US1MNHN0028',
#   'elevationUnit': 'METERS',
#   'longitude': -93.289},
#  {'elevation': 290.8,
#   'mindate': '2011-04-01',
#   'maxdate': '2024-01-26',
#   'latitude': 45.040635,
#   'name': 'PLYMOUTH 2.4 ENE, MN US',
#   'datacoverage': 0.9996,
#   'id': 'GHCND:US1MNHN0030',
#   'elevationUnit': 'METERS',
#   'longitude': -93.419543},
#  {'elevation': 275.5,
#   'mindate': '2011-03-01',
#   'maxdate': '2024-01-29',
#   'latitude': 45.12260998,
#   'name': 'MAPLE GROVE 1.0 NNE, MN US',
#   'datacoverage': 0.9993,
#   'id': 'GHCND:US1MNHN0031',
#   'elevationUnit': 'METERS',
#   'longitude': -93.45792238},
#  {'elevation': 266.1,
#   'mindate': '2011-03-01',
#   'maxdate': '2013-10-16',
#   'latitude': 44.906719,
#   'name': 'MINNEAPOLIS 4.6 SSW, MN US',
#   'datacoverage': 0.8108,
#   'id': 'GHCND:US1MNHN0032',
#   'elevationUnit': 'METERS',
#   'longitude': -93.319189},
#  {'elevation': 264.3,
#   'mindate': '2011-03-01',
#   'maxdate': '2023-11-21',
#   'latitude': 45.2442726,
#   'name': 'DAYTON 0.4 NE, MN US',
#   'datacoverage': 0.688,
#   'id': 'GHCND:US1MNHN0033',
#   'elevationUnit': 'METERS',
#   'longitude': -93.5115319},
#  {'elevation': 272.5,
#   'mindate': '2011-03-01',
#   'maxdate': '2012-01-01',
#   'latitude': 45.009441,
#   'name': 'GOLDEN VALLEY 1.6 NNE, MN US',
#   'datacoverage': 0.9935,
#   'id': 'GHCND:US1MNHN0034',
#   'elevationUnit': 'METERS',
#   'longitude': -93.341116},
#  {'elevation': 252.7,
#   'mindate': '2011-03-01',
#   'maxdate': '2014-01-10',
#   'latitude': 44.940801,
#   'name': 'MINNEAPOLIS 2.9 ESE, MN US',
#   'datacoverage': 0.9405,
#   'id': 'GHCND:US1MNHN0035',
#   'elevationUnit': 'METERS',
#   'longitude': -93.216938},
#  {'elevation': 292.3,
#   'mindate': '2011-04-01',
#   'maxdate': '2023-10-31',
#   'latitude': 44.928368,
#   'name': 'MINNETONKA 0.7 WSW, MN US',
#   'datacoverage': 0.6427,
#   'id': 'GHCND:US1MNHN0036',
#   'elevationUnit': 'METERS',
#   'longitude': -93.475499},
#  {'elevation': 293.8,
#   'mindate': '2011-04-01',
#   'maxdate': '2023-10-31',
#   'latitude': 45.0109418,
#   'name': 'PLYMOUTH 0.8 SSE, MN US',
#   'datacoverage': 0.636,
#   'id': 'GHCND:US1MNHN0037',
#   'elevationUnit': 'METERS',
#   'longitude': -93.4577184},
#  {'elevation': 281,
#   'mindate': '2011-04-01',
#   'maxdate': '2012-07-02',
#   'latitude': 44.9533,
#   'name': 'SAINT LOUIS PARK 0.3 N, MN US',
#   'datacoverage': 0.6237,
#   'id': 'GHCND:US1MNHN0038',
#   'elevationUnit': 'METERS',
#   'longitude': -93.3653},
#  {'elevation': 296.3,
#   'mindate': '2011-04-01',
#   'maxdate': '2019-08-28',
#   'latitude': 45.093,
#   'name': 'ROCKFORD 0.5 NE, MN US',
#   'datacoverage': 0.6178,
#   'id': 'GHCND:US1MNHN0039',
#   'elevationUnit': 'METERS',
#   'longitude': -93.7359},
#  {'elevation': 287.4,
#   'mindate': '2011-04-01',
#   'maxdate': '2021-07-08',
#   'latitude': 44.9225,
#   'name': 'DEEPHAVEN 0.8 SW, MN US',
#   'datacoverage': 0.5815,
#   'id': 'GHCND:US1MNHN0040',
#   'elevationUnit': 'METERS',
#   'longitude': -93.5368},
#  {'elevation': 294.7,
#   'mindate': '2011-04-01',
#   'maxdate': '2012-10-31',
#   'latitude': 44.9228,
#   'name': 'MINNETRISTA 1.0 SSW, MN US',
#   'datacoverage': 0.6822,
#   'id': 'GHCND:US1MNHN0041',
#   'elevationUnit': 'METERS',
#   'longitude': -93.7198},
#  {'elevation': 265.2,
#   'mindate': '2011-04-01',
#   'maxdate': '2023-10-25',
#   'latitude': 44.845092,
#   'name': 'EDEN PRAIRIE 2.1 E, MN US',
#   'datacoverage': 0.6331,
#   'id': 'GHCND:US1MNHN0042',
#   'elevationUnit': 'METERS',
#   'longitude': -93.417115},
#  {'elevation': 258.2,
#   'mindate': '2011-04-01',
#   'maxdate': '2011-08-31',
#   'latitude': 44.9111,
#   'name': 'MINNEAPOLIS 4.1 SSE, MN US',
#   'datacoverage': 0.9947,
#   'id': 'GHCND:US1MNHN0044',
#   'elevationUnit': 'METERS',
#   'longitude': -93.2276},
#  {'elevation': 257.3,
#   'mindate': '2011-04-01',
#   'maxdate': '2015-11-11',
#   'latitude': 44.882948,
#   'name': 'RICHFIELD 1.2 ENE, MN US',
#   'datacoverage': 0.9462,
#   'id': 'GHCND:US1MNHN0045',
#   'elevationUnit': 'METERS',
#   'longitude': -93.258349},
#  {'elevation': 281.9,
#   'mindate': '2011-04-01',
#   'maxdate': '2018-09-19',
#   'latitude': 44.866464,
#   'name': 'EDEN PRAIRIE 2.3 WNW, MN US',
#   'datacoverage': 0.7087,
#   'id': 'GHCND:US1MNHN0047',
#   'elevationUnit': 'METERS',
#   'longitude': -93.500411},
#  {'elevation': 288.6,
#   'mindate': '2011-05-01',
#   'maxdate': '2022-08-01',
#   'latitude': 45.063793,
#   'name': 'PLYMOUTH 3.3 NNW, MN US',
#   'datacoverage': 0.6291,
#   'id': 'GHCND:US1MNHN0048',
#   'elevationUnit': 'METERS',
#   'longitude': -93.494675},
#  {'elevation': 274.3,
#   'mindate': '2011-04-01',
#   'maxdate': '2023-05-19',
#   'latitude': 45.114818,
#   'name': 'MAPLE GROVE 2.4 E, MN US',
#   'datacoverage': 0.636,
#   'id': 'GHCND:US1MNHN0049',
#   'elevationUnit': 'METERS',
#   'longitude': -93.414022},
#  {'elevation': 288.6,
#   'mindate': '1998-06-01',
#   'maxdate': '2022-11-30',
#   'latitude': 45.012542,
#   'name': 'PLYMOUTH 2.7 ESE, MN US',
#   'datacoverage': 0.4191,
#   'id': 'GHCND:US1MNHN0050',
#   'elevationUnit': 'METERS',
#   'longitude': -93.407929},
#  {'elevation': 303,
#   'mindate': '2011-05-01',
#   'maxdate': '2022-07-05',
#   'latitude': 45.087023,
#   'name': 'CORCORAN 3.3 ESE, MN US',
#   'datacoverage': 0.6291,
#   'id': 'GHCND:US1MNHN0051',
#   'elevationUnit': 'METERS',
#   'longitude': -93.524252},
#  {'elevation': 263.7,
#   'mindate': '2011-05-01',
#   'maxdate': '2023-05-19',
#   'latitude': 45.159328,
#   'name': 'CHAMPLIN 1.8 ESE, MN US',
#   'datacoverage': 0.6291,
#   'id': 'GHCND:US1MNHN0052',
#   'elevationUnit': 'METERS',
#   'longitude': -93.357627},
#  {'elevation': 284.1,
#   'mindate': '2011-05-01',
#   'maxdate': '2023-05-19',
#   'latitude': 45.198432,
#   'name': 'DAYTON 3.4 SSE, MN US',
#   'datacoverage': 0.6106,
#   'id': 'GHCND:US1MNHN0053',
#   'elevationUnit': 'METERS',
#   'longitude': -93.481254},
#  {'elevation': 281,
#   'mindate': '2011-04-01',
#   'maxdate': '2017-10-21',
#   'latitude': 45.003259,
#   'name': 'GOLDEN VALLEY 1.8 WNW, MN US',
#   'datacoverage': 0.9925,
#   'id': 'GHCND:US1MNHN0055',
#   'elevationUnit': 'METERS',
#   'longitude': -93.390075},
#  {'elevation': 271.9,
#   'mindate': '2011-04-01',
#   'maxdate': '2023-11-04',
#   'latitude': 45.129036,
#   'name': 'MAPLE GROVE 1.4 NNE, MN US',
#   'datacoverage': 0.6962,
#   'id': 'GHCND:US1MNHN0057',
#   'elevationUnit': 'METERS',
#   'longitude': -93.456522},
#  {'elevation': 260,
#   'mindate': '2011-04-01',
#   'maxdate': '2023-10-02',
#   'latitude': 45.158527,
#   'name': 'CHAMPLIN 1.5 ESE 118, MN US',
#   'datacoverage': 0.5815,
#   'id': 'GHCND:US1MNHN0058',
#   'elevationUnit': 'METERS',
#   'longitude': -93.365274},
#  {'elevation': 281,
#   'mindate': '2011-04-01',
#   'maxdate': '2018-06-30',
#   'latitude': 45.032386,
#   'name': 'PLYMOUTH 2.6 ENE 152, MN US',
#   'datacoverage': 0.5997,
#   'id': 'GHCND:US1MNHN0060',
#   'elevationUnit': 'METERS',
#   'longitude': -93.410418},
#  {'elevation': 268.2,
#   'mindate': '2011-06-01',
#   'maxdate': '2013-07-12',
#   'latitude': 44.845658,
#   'name': 'EDEN PRAIRIE 0.3 SE, MN US',
#   'datacoverage': 1,
#   'id': 'GHCND:US1MNHN0061',
#   'elevationUnit': 'METERS',
#   'longitude': -93.45486},
#  {'elevation': 276.1,
#   'mindate': '2011-06-01',
#   'maxdate': '2013-10-20',
#   'latitude': 45.16201,
#   'name': 'CHAMPLIN 1.3 WSW, MN US',
#   'datacoverage': 0.7575,
#   'id': 'GHCND:US1MNHN0062',
#   'elevationUnit': 'METERS',
#   'longitude': -93.41402},
#  {'elevation': 275.5,
#   'mindate': '2011-08-01',
#   'maxdate': '2014-11-11',
#   'latitude': 45.019488,
#   'name': 'CRYSTAL 1.7 SE, MN US',
#   'datacoverage': 0.4001,
#   'id': 'GHCND:US1MNHN0064',
#   'elevationUnit': 'METERS',
#   'longitude': -93.337883},
#  {'elevation': 266.4,
#   'mindate': '2011-07-01',
#   'maxdate': '2021-11-11',
#   'latitude': 45.008272,
#   'name': 'MINNEAPOLIS 2.4 NE, MN US',
#   'datacoverage': 0.9293,
#   'id': 'GHCND:US1MNHN0065',
#   'elevationUnit': 'METERS',
#   'longitude': -93.236255},
#  {'elevation': 251.5,
#   'mindate': '2011-07-01',
#   'maxdate': '2023-10-04',
#   'latitude': 44.8136719,
#   'name': 'BLOOMINGTON 1.2 SSE, MN US',
#   'datacoverage': 0.816,
#   'id': 'GHCND:US1MNHN0066',
#   'elevationUnit': 'METERS',
#   'longitude': -93.308578},
#  {'elevation': 280.4,
#   'mindate': '2012-03-01',
#   'maxdate': '2024-01-29',
#   'latitude': 45.13953,
#   'name': 'MAPLE GROVE 2.9 NE, MN US',
#   'datacoverage': 0.9999,
#   'id': 'GHCND:US1MNHN0072',
#   'elevationUnit': 'METERS',
#   'longitude': -93.42067},
#  {'elevation': 258.2,
#   'mindate': '2012-03-01',
#   'maxdate': '2012-11-22',
#   'latitude': 45.193083,
#   'name': 'CHAMPLIN 1.7 NNW, MN US',
#   'datacoverage': 0.9961,
#   'id': 'GHCND:US1MNHN0074',
#   'elevationUnit': 'METERS',
#   'longitude': -93.40398},
#  {'elevation': 271.9,
#   'mindate': '1998-06-01',
#   'maxdate': '2022-11-10',
#   'latitude': 44.891293,
#   'name': 'RICHFIELD 1.9 WNW, MN US',
#   'datacoverage': 0.9922,
#   'id': 'GHCND:US1MNHN0078',
#   'elevationUnit': 'METERS',
#   'longitude': -93.314089},
#  {'elevation': 276.5,
#   'mindate': '2011-12-01',
#   'maxdate': '2016-09-24',
#   'latitude': 44.911167,
#   'name': 'HOPKINS 1.2 SSW, MN US',
#   'datacoverage': 1,
#   'id': 'GHCND:US1MNHN0081',
#   'elevationUnit': 'METERS',
#   'longitude': -93.416376},
#  {'elevation': 273.7,
#   'mindate': '2011-12-01',
#   'maxdate': '2014-03-19',
#   'latitude': 45.0585669,
#   'name': 'CRYSTAL 1.7 NNW, MN US',
#   'datacoverage': 0.9646,
#   'id': 'GHCND:US1MNHN0082',
#   'elevationUnit': 'METERS',
#   'longitude': -93.377839},
#  {'elevation': 285.9,
#   'mindate': '2012-04-01',
#   'maxdate': '2024-01-28',
#   'latitude': 44.933417,
#   'name': 'SPRING PARK 0.2 SSE, MN US',
#   'datacoverage': 0.9375,
#   'id': 'GHCND:US1MNHN0083',
#   'elevationUnit': 'METERS',
#   'longitude': -93.6316},
#  {'elevation': 263.3,
#   'mindate': '2012-03-01',
#   'maxdate': '2018-11-07',
#   'latitude': 45.0349235534668,
#   'name': 'MINNEAPOLIS 4.4 NNW, MN US',
#   'datacoverage': 0.714,
#   'id': 'GHCND:US1MNHN0084',
#   'elevationUnit': 'METERS',
#   'longitude': -93.3127288818359},
#  {'elevation': 256.3,
#   'mindate': '2012-04-01',
#   'maxdate': '2023-10-27',
#   'latitude': 44.913096,
#   'name': 'MINNEAPOLIS 4.1 SSE, MN US',
#   'datacoverage': 0.7047,
#   'id': 'GHCND:US1MNHN0085',
#   'elevationUnit': 'METERS',
#   'longitude': -93.221943},
#  {'elevation': 264,
#   'mindate': '2012-04-01',
#   'maxdate': '2024-01-29',
#   'latitude': 44.828253,
#   'name': 'EDEN PRAIRIE 3.1 ESE, MN US',
#   'datacoverage': 1,
#   'id': 'GHCND:US1MNHN0086',
#   'elevationUnit': 'METERS',
#   'longitude': -93.404026},
#  {'elevation': 273.4,
#   'mindate': '2012-05-01',
#   'maxdate': '2020-07-15',
#   'latitude': 44.98461,
#   'name': 'GOLDEN VALLEY 0.8 WSW, MN US',
#   'datacoverage': 0.9997,
#   'id': 'GHCND:US1MNHN0088',
#   'elevationUnit': 'METERS',
#   'longitude': -93.37442},
#  {'elevation': 282.2,
#   'mindate': '2012-05-01',
#   'maxdate': '2020-06-08',
#   'latitude': 44.915392,
#   'name': 'EDINA 1.7 N, MN US',
#   'datacoverage': 0.9997,
#   'id': 'GHCND:US1MNHN0089',
#   'elevationUnit': 'METERS',
#   'longitude': -93.358479},
#  {'elevation': 256.9,
#   'mindate': '2011-04-01',
#   'maxdate': '2023-12-26',
#   'latitude': 44.9171706402584,
#   'name': 'MINNEAPOLIS 3.6 SSE, MN US',
#   'datacoverage': 0.357,
#   'id': 'GHCND:US1MNHN0090',
#   'elevationUnit': 'METERS',
#   'longitude': -93.2328826189041},
#  {'elevation': 298.1,
#   'mindate': '2012-05-01',
#   'maxdate': '2013-08-12',
#   'latitude': 44.986312,
#   'name': 'PLYMOUTH 2.6 SSW, MN US',
#   'datacoverage': 0.7958,
#   'id': 'GHCND:US1MNHN0091',
#   'elevationUnit': 'METERS',
#   'longitude': -93.472706},
#  {'elevation': 261.5,
#   'mindate': '2012-07-01',
#   'maxdate': '2015-07-02',
#   'latitude': 44.94173,
#   'name': 'MINNEAPOLIS 1.9 SE, MN US',
#   'datacoverage': 0.865,
#   'id': 'GHCND:US1MNHN0093',
#   'elevationUnit': 'METERS',
#   'longitude': -93.24182},
#  {'elevation': 253.3,
#   'mindate': '2012-09-01',
#   'maxdate': '2017-10-28',
#   'latitude': 44.9247,
#   'name': 'MINNEAPOLIS 2.8 SSE, MN US',
#   'datacoverage': 1,
#   'id': 'GHCND:US1MNHN0099',
#   'elevationUnit': 'METERS',
#   'longitude': -93.2494},
#  {'elevation': 297.8,
#   'mindate': '2013-04-01',
#   'maxdate': '2014-09-22',
#   'latitude': 44.8927192687988,
#   'name': 'SHOREWOOD 2.3 SW, MN US',
#   'datacoverage': 0.7776,
#   'id': 'GHCND:US1MNHN0103',
#   'elevationUnit': 'METERS',
#   'longitude': -93.6165771484375},
#  {'elevation': 267.9,
#   'mindate': '2013-07-01',
#   'maxdate': '2018-09-17',
#   'latitude': 44.9024772644043,
#   'name': 'MINNEAPOLIS 4.2 S, MN US',
#   'datacoverage': 0.7776,
#   'id': 'GHCND:US1MNHN0107',
#   'elevationUnit': 'METERS',
#   'longitude': -93.2841033935547},
#  ...]

# %%
#Test downloading data from all stations
endpoint = '/data/'

#Get list of station codes for the Minnesota stations
parameters = {
    'datasetid': 'GHCND',
    'locationid': 'FIPS:27',
    'datatypeid' : 'PRCP,TAVG',
    'limit': 1000, # max is 1000 for a single request
    'offset': 1,
    'startdate': '2023-12-30',
    'enddate': '2023-12-31'
}

data = api_call(url, endpoint, headers, parameters)
#data
# Out:
# API Called

# %%
data
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 1353, 'limit': 1000}},
#  'results': [{'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:CA006020559',
#    'attributes': ',,C,',
#    'value': 10},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:CA006020559',
#    'attributes': ',,C,',
#    'value': -40},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0031',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0073',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0074',
#    'attributes': ',,N,0433',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0075',
#    'attributes': ',,N,1615',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0076',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0084',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0090',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0092',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0093',
#    'attributes': ',,N,0813',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0110',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0113',
#    'attributes': ',,N,0900',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0116',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0121',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0129',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0130',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0131',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0140',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0151',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0161',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0169',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAA0175',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAT0004',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAT0005',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAT0017',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAT0022',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAT0024',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAT0027',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNAT0032',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBK0006',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBK0010',
#    'attributes': ',,N,0530',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBK0015',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBK0025',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBK0028',
#    'attributes': 'T,,N,1000',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBM0011',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBM0014',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBM0015',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBM0021',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBN0006',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBN0007',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBN0012',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBN0013',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBU0023',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBU0031',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBU0034',
#    'attributes': ',,N,0730',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBU0036',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBU0041',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBU0047',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBU0049',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBU0055',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBU0062',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBW0001',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBW0002',
#    'attributes': ',,N,0500',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBW0008',
#    'attributes': ',,N,1030',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBW0011',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBW0017',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNBW0020',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0001',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0007',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0016',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0027',
#    'attributes': 'T,,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0028',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0043',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0050',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0055',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0061',
#    'attributes': ',,N,0945',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0066',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0068',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0074',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCG0075',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCK0003',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCK0006',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCK0007',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCK0013',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCK0018',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCK0029',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCK0031',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCK0032',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCK0039',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCK0043',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCK0051',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCL0002',
#    'attributes': ',,N,0830',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCN0001',
#    'attributes': ',,N,0900',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCN0023',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCN0036',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCN0050',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCN0054',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCN0056',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCS0001',
#    'attributes': ',,N,0630',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCS0023',
#    'attributes': 'T,,N,0753',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCS0025',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCS0034',
#    'attributes': ',,N,0645',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCS0036',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCS0038',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCS0042',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCV0008',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCV0022',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCV0025',
#    'attributes': ',,N,0730',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCV0027',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCV0040',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCV0066',
#    'attributes': ',,N,0740',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCV0071',
#    'attributes': ',,N,0712',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCW0008',
#    'attributes': ',,N,0740',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCW0016',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCW0022',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCW0028',
#    'attributes': ',,N,0500',
#    'value': 15},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCW0029',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCW0031',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCW0044',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCW0077',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCW0088',
#    'attributes': ',,N,0900',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCW0097',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCY0001',
#    'attributes': 'T,L,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCY0020',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCY0029',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNCY0037',
#    'attributes': ',,N,1700',
#    'value': 5},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDD0003',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDD0024',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0011',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0034',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0053',
#    'attributes': ',,N,0745',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0063',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0082',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0083',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0092',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0104',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0112',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0118',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0119',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0129',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0151',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0152',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0170',
#    'attributes': ',,N,0900',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0174',
#    'attributes': ',,N,0630',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0179',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0183',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0188',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0209',
#    'attributes': ',,N,0709',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0216',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDK0218',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDS0006',
#    'attributes': ',,N,0815',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDS0029',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDS0038',
#    'attributes': ',,N,0842',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDS0040',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDS0046',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNDS0048',
#    'attributes': ',,N,0730',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNFM0010',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNFM0018',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNFN0011',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNFT0005',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0003',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0004',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0015',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0017',
#    'attributes': ',,N,0620',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0021',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0028',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0033',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0035',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0041',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0045',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0049',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGH0053',
#    'attributes': ',,N,1145',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNGR0004',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHB0011',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHB0016',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0006',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0014',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0019',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0030',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0031',
#    'attributes': ',,N,0900',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0072',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0083',
#    'attributes': ',,N,0631',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0086',
#    'attributes': ',,N,0923',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0110',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0128',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0134',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0148',
#    'attributes': ',,N,0900',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0169',
#    'attributes': ',,N,0900',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0178',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0186',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0191',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0239',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0241',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0251',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0267',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0278',
#    'attributes': ',,N,0830',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0281',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0285',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0298',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0306',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0307',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0311',
#    'attributes': ',,N,0530',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0328',
#    'attributes': ',,N,0915',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0329',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0331',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0338',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0354',
#    'attributes': ',,N,0723',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0363',
#    'attributes': ',,N,0700',
#    'value': 13},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0365',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0375',
#    'attributes': ',,N,0820',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0378',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0379',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0383',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0384',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0405',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0417',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0418',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0421',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0425',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0457',
#    'attributes': 'T,,N,1700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0460',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0493',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0499',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0501',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0521',
#    'attributes': ',,N,0430',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0530',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHS0017',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0018',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0022',
#    'attributes': ',,N,0900',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0028',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0035',
#    'attributes': ',,N,0725',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0044',
#    'attributes': ',,N,0900',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0045',
#    'attributes': ',,N,0830',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0007',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0017',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0019',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0023',
#    'attributes': 'T,,N,0645',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0037',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0038',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0039',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0047',
#    'attributes': 'T,,N,0830',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0052',
#    'attributes': 'T,,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0055',
#    'attributes': 'T,,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0057',
#    'attributes': 'T,,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0060',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0062',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0070',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKB0017',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKB0020',
#    'attributes': 'T,,N,0849',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKC0006',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKC0009',
#    'attributes': ',,N,0600',
#    'value': 3},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKC0010',
#    'attributes': ',,N,0700',
#    'value': 3},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKC0014',
#    'attributes': ',,N,0700',
#    'value': 3},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKD0001',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKD0013',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKD0020',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKD0024',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKD0033',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0004',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0005',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0031',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0032',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0034',
#    'attributes': 'T,,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0035',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0041',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0043',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0012',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0013',
#    'attributes': ',,N,1000',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0023',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0024',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0026',
#    'attributes': ',,N,0730',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0032',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0033',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLW0003',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLY0015',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0005',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0006',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0007',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0012',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0017',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0036',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMK0011',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMK0018',
#    'attributes': ',,N,0640',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMK0023',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMK0027',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMK0028',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNML0001',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNML0012',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0004',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0012',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0013',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0020',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0021',
#    'attributes': ',,N,0730',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0025',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0029',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMT0006',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMT0012',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMW0003',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMW0011',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMW0013',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMY0011',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMY0013',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNB0007',
#    'attributes': ',,N,0636',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNB0008',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNB0010',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNB0011',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNC0003',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNC0012',
#    'attributes': ',,N,0807',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNC0023',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNC0024',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNC0031',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNR0001',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0018',
#    'attributes': ',,N,0530',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0027',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0029',
#    'attributes': ',,N,0630',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0030',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0032',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0039',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0042',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0048',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0049',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0050',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0065',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0072',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0079',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0991',
#    'attributes': ',,N,2200',
#    'value': 3},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOT0005',
#    'attributes': ',,N,1700',
#    'value': 8},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOT0006',
#    'attributes': ',,N,0607',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOT0013',
#    'attributes': 'T,,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOT0018',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOT0036',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOT0042',
#    'attributes': ',,N,1100',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOT0056',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPG0003',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPG0004',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPK0002',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPK0015',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPK0022',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPN0033',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPN0035',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPN0037',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPN0041',
#    'attributes': ',,N,0601',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPN0045',
#    'attributes': ',,N,0700',
#    'value': 8},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPP0011',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNPS0006',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRC0001',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRC0038',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRC0050',
#    'attributes': ',,N,0900',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRC0057',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRC0060',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRC0074',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRK0005',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRM0002',
#    'attributes': ',,N,0000',
#    'value': 10},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRM0015',
#    'attributes': ',,N,0600',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRM0017',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRM0054',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRM0056',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNRM0059',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-30T00:00:00',
#    'datatype': 'PRCP',
# ...
#    'value': 10},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0331',
#    'attributes': ',,N,0700',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0338',
#    'attributes': ',,N,0900',
#    'value': 15},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0354',
#    'attributes': ',,N,0713',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0363',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0365',
#    'attributes': ',,N,0700',
#    'value': 15},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0378',
#    'attributes': ',,N,0800',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0379',
#    'attributes': ',,N,0700',
#    'value': 15},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0405',
#    'attributes': ',,N,0800',
#    'value': 15},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0418',
#    'attributes': ',,N,0745',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0421',
#    'attributes': ',,N,0700',
#    'value': 15},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0425',
#    'attributes': ',,N,0802',
#    'value': 10},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0457',
#    'attributes': 'T,,N,1700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0460',
#    'attributes': ',,N,0641',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0493',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0501',
#    'attributes': ',,N,0800',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHN0530',
#    'attributes': ',,N,0700',
#    'value': 23},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHS0006',
#    'attributes': ',,N,0845',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNHS0017',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0021',
#    'attributes': ',,N,0800',
#    'value': 15},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0022',
#    'attributes': ',,N,0900',
#    'value': 28},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0028',
#    'attributes': ',,N,0700',
#    'value': 28},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0035',
#    'attributes': ',,N,0735',
#    'value': 18},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0044',
#    'attributes': ',,N,0900',
#    'value': 28},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIS0045',
#    'attributes': ',,N,0800',
#    'value': 20},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0006',
#    'attributes': ',,N,0800',
#    'value': 25},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0007',
#    'attributes': ',,N,0600',
#    'value': 10},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0017',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0023',
#    'attributes': ',,N,0645',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0037',
#    'attributes': ',,N,0800',
#    'value': 20},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0038',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0039',
#    'attributes': ',,N,0800',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0047',
#    'attributes': ',,N,0830',
#    'value': 20},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0052',
#    'attributes': ',,N,0800',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0055',
#    'attributes': ',,N,0800',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0057',
#    'attributes': ',,N,0830',
#    'value': 20},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0060',
#    'attributes': ',,N,0700',
#    'value': 18},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0062',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNIT0070',
#    'attributes': ',,N,0700',
#    'value': 10},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKB0017',
#    'attributes': ',,N,0700',
#    'value': 25},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKB0020',
#    'attributes': ',,N,0927',
#    'value': 28},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKC0006',
#    'attributes': ',,N,0800',
#    'value': 10},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKC0009',
#    'attributes': ',,N,0600',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKC0010',
#    'attributes': ',,N,0700',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKC0014',
#    'attributes': ',,N,0700',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKD0001',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKD0020',
#    'attributes': ',,N,0800',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKD0024',
#    'attributes': 'T,,N,0000',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNKD0033',
#    'attributes': ',,N,0700',
#    'value': 3},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0004',
#    'attributes': ',,N,0700',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0005',
#    'attributes': ',,N,0700',
#    'value': 3},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0019',
#    'attributes': ',,N,0718',
#    'value': 18},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0031',
#    'attributes': ',,N,0700',
#    'value': 33},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0032',
#    'attributes': ',,N,0800',
#    'value': 46},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0034',
#    'attributes': ',,N,0800',
#    'value': 20},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0035',
#    'attributes': ',,N,0700',
#    'value': 20},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLK0041',
#    'attributes': ',,N,0700',
#    'value': 10},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0012',
#    'attributes': ',,N,0800',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0023',
#    'attributes': ',,N,0800',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0024',
#    'attributes': ',,N,0800',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0026',
#    'attributes': ',,N,0800',
#    'value': 18},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0029',
#    'attributes': 'T,,N,0730',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0032',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLS0033',
#    'attributes': ',,N,0900',
#    'value': 3},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLW0003',
#    'attributes': ',,N,0800',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNLY0015',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0005',
#    'attributes': ',,N,0800',
#    'value': 3},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0006',
#    'attributes': ',,N,0700',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0007',
#    'attributes': ',,N,0700',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0012',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0017',
#    'attributes': ',,N,0600',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0026',
#    'attributes': 'T,,N,0730',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMC0036',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMK0011',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMK0018',
#    'attributes': ',,N,0610',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMK0023',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMK0027',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMK0028',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNML0001',
#    'attributes': ',,N,0800',
#    'value': 23},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNML0012',
#    'attributes': ',,N,0800',
#    'value': 18},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0004',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0012',
#    'attributes': ',,N,0700',
#    'value': 15},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0013',
#    'attributes': ',,N,0700',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0020',
#    'attributes': ',,N,0700',
#    'value': 20},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0021',
#    'attributes': ',,N,0730',
#    'value': 13},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0025',
#    'attributes': ',,N,0700',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMR0029',
#    'attributes': ',,N,0800',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMT0006',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMT0012',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMW0011',
#    'attributes': ',,N,0700',
#    'value': 3},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMW0013',
#    'attributes': 'T,,N,0800',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMY0011',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNMY0013',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNB0007',
#    'attributes': 'T,,N,0737',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNB0008',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNB0010',
#    'attributes': 'T,,N,0800',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNB0011',
#    'attributes': ',,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNC0003',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNC0012',
#    'attributes': 'T,,N,0703',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNC0023',
#    'attributes': 'T,,N,0700',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNC0024',
#    'attributes': ',,N,0800',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNC0031',
#    'attributes': ',,N,0700',
#    'value': 3},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNNR0001',
#    'attributes': ',,N,0800',
#    'value': 3},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0018',
#    'attributes': ',,N,0530',
#    'value': 3},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0027',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0029',
#    'attributes': ',,N,0630',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0030',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0032',
#    'attributes': ',,N,0700',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0039',
#    'attributes': ',,N,0700',
#    'value': 10},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0042',
#    'attributes': 'T,,N,0600',
#    'value': 0},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0048',
#    'attributes': ',,N,0600',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0049',
#    'attributes': ',,N,0800',
#    'value': 8},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0050',
#    'attributes': ',,N,0600',
#    'value': 3},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0065',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0072',
#    'attributes': ',,N,0700',
#    'value': 5},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0079',
#    'attributes': ',,N,0800',
#    'value': 10},
#   {'date': '2023-12-31T00:00:00',
#    'datatype': 'PRCP',
#    'station': 'GHCND:US1MNOL0991',
#    'attributes': 'T,,N,1600',
#    'value': 0}]}

# %%
#Test downloading data from all stations
endpoint = '/data/'

# Specify the dataset, station ID, and date range
parameters = {
    'datasetid': 'GHCND',
    'locationid': 'FIPS:27',
    'limit': 1000, # max is 1000 for a single request
    'offset': 1,
    'startdate': '2023-12-20',
    'enddate': '2023-12-20',
    'stationid': 'COOP:211065,COOP:218025,GHCND:US1MNMC0020,GHCND:USC00211065,GHCND:USC00218025'
}

data = api_call(url, endpoint, headers, parameters)
print(data)

all_results = []  # List to store all results

while True:
    data = api_call(url, endpoint, headers, parameters)
    if data is not None and 'results' in data:
        all_results.extend(data['results'])  # Append results from current call
        
        # Check if more results are available
        if parameters['offset'] + parameters['limit'] - 1 < data['metadata']['resultset']['count']:
            parameters['offset'] += parameters['limit']
        else:
            break
    else:
        # Handle error or no data case
        print("No data returned or an error occurred")
        break

# At this point, `all_results` contains all the stations fetched from the API
# Out:
# API Called
# {'metadata': {'resultset': {'offset': 1, 'count': 6, 'limit': 1000}}, 'results': [{'date': '2023-12-20T00:00:00', 'datatype': 'PRCP', 'station': 'GHCND:USC00211065', 'attributes': ',,7,0800', 'value': 0}, {'date': '2023-12-20T00:00:00', 'datatype': 'SNOW', 'station': 'GHCND:USC00211065', 'attributes': ',,7,', 'value': 0}, {'date': '2023-12-20T00:00:00', 'datatype': 'SNWD', 'station': 'GHCND:USC00211065', 'attributes': ',,7,0800', 'value': 0}, {'date': '2023-12-20T00:00:00', 'datatype': 'TMAX', 'station': 'GHCND:USC00211065', 'attributes': ',,7,0800', 'value': 22}, {'date': '2023-12-20T00:00:00', 'datatype': 'TMIN', 'station': 'GHCND:USC00211065', 'attributes': ',,7,0800', 'value': -50}, {'date': '2023-12-20T00:00:00', 'datatype': 'TOBS', 'station': 'GHCND:USC00211065', 'attributes': ',,7,0800', 'value': -33}]}
# API Called
